# %%
# Imports and Setup
import os
import sys
import logging

# Add the grid_collector directory to Python path
grid_collector_path = os.path.dirname(os.getcwd())  # Go up one directory to grid_collector
if grid_collector_path not in sys.path:
    sys.path.insert(0, grid_collector_path)  # Insert at beginning of path for priority
    print(f"Added to path: {grid_collector_path}")

from dotenv import load_dotenv
from src.collector.grid_collector import GridCollector
import logging
import pandas as pd
from datetime import datetime, timedelta

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
# Out:
# Added to path: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector

# %%
# Configuration and Initialization
# Load configuration
load_dotenv()
api_key = os.getenv('GRID_API_KEY')
if not api_key:
    raise ValueError("GRID_API_KEY environment variable is not set")

try:
    # Initialize collector
    collector = GridCollector(api_key)
    logging.info("Successfully initialized GridCollector")
except Exception as e:
    logging.error(f"Error initializing collector: {str(e)}")
    raise
# Out:
# 2024-11-06 14:55:40,490 - INFO - Successfully initialized GridCollector

# %%
def verify_queries():
    # Get path to queries directory
    notebook_dir = os.getcwd()
    grid_collector_dir = os.path.dirname(notebook_dir)
    queries_dir = os.path.join(grid_collector_dir, 'queries')
    
    print(f"Checking queries directory: {queries_dir}")
    
    # List of required query files
    required_queries = [
        'tournaments.graphql',
        'matches.graphql',
        'players.graphql',
        'statistics.graphql',
        'teams.graphql'
    ]
    
    # Check each file
    print("\nChecking query files:")
    for query in required_queries:
        path = os.path.join(queries_dir, query)
        exists = os.path.exists(path)
        print(f"{'✓' if exists else '✗'} {query}")
        if not exists:
            print(f"  Missing file should be at: {path}")
            
    # If any files are missing, show how to create them
    if any(not os.path.exists(os.path.join(queries_dir, q)) for q in required_queries):
        print("\nMissing query files! Here's how to create them:")
        print(f"1. Create directory: {queries_dir}")
        print("2. Create the following files with their queries:")
        for query in required_queries:
            print(f"   - {query}")

# Run verification
verify_queries()
# Out:
# Checking queries directory: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries
#
# Checking query files:
# ✓ tournaments.graphql
# ✓ matches.graphql
# ✓ players.graphql
# ✓ statistics.graphql
# ✓ teams.graphql

# %%
# Collect Player Data
try:
    logging.info("Collecting player data...")
    players_df = collector.get_players()
    logging.info(f"Collected {len(players_df)} players")
    
    # Display sample of players
    print("\nPlayers Sample:")
    print(players_df.head())
    
except Exception as e:
    logging.error(f"Error collecting player data: {str(e)}")
    raise
# Out:
# 2024-11-06 14:55:45,848 - INFO - Collecting player data...
# 2024-11-06 14:55:45,849 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\players.graphql
# 2024-11-06 14:55:45,858 - INFO - >>> {"query": "query IntrospectionQuery {\n  __schema {\n    queryType {\n      name\n    }\n    mutationType {\n      name\n    }\n    subscriptionType {\n      name\n    }\n    types {\n      ...FullType\n    }\n    directives {\n      name\n      description\n      locations\n      args {\n        ...InputValue\n      }\n    }\n  }\n}\n\nfragment FullType on __Type {\n  kind\n  name\n  description\n  fields(includeDeprecated: true) {\n    name\n    description\n    args {\n      ...InputValue\n    }\n    type {\n      ...TypeRef\n    }\n    isDeprecated\n    deprecationReason\n  }\n  inputFields {\n    ...InputValue\n  }\n  interfaces {\n    ...TypeRef\n  }\n  enumValues(includeDeprecated: true) {\n    name\n    description\n    isDeprecated\n    deprecationReason\n  }\n  possibleTypes {\n    ...TypeRef\n  }\n}\n\nfragment InputValue on __InputValue {\n  name\n  description\n  type {\n    ...TypeRef\n  }\n  defaultValue\n}\n\nfragment TypeRef on __Type {\n  kind\n  name\n  ofType {\n    kind\n    name\n    ofType {\n      kind\n      name\n      ofType {\n        kind\n        name\n        ofType {\n          kind\n          name\n          ofType {\n            kind\n            name\n            ofType {\n              kind\n              name\n              ofType {\n                kind\n                name\n                ofType {\n                  kind\n                  name\n                  ofType {\n                    kind\n                    name\n                  }\n                }\n              }\n            }\n          }\n        }\n      }\n    }\n  }\n}"}
# 2024-11-06 14:55:46,809 - INFO - <<< {"data":{"__schema":{"queryType":{"name":"Query"},"types":[{"kind":"SCALAR","name":"Boolean","description":"Built-in Boolean"},{"kind":"INPUT_OBJECT","name":"BooleanFilter","description":"Boolean filter for true/false fields.","inputFields":[{"name":"equals","description":"Value to look for, can be nullable.","type":{"kind":"SCALAR","name":"Boolean"}}]},{"kind":"SCALAR","name":"Cursor","description":"Cursor value for pagination."},{"kind":"OBJECT","name":"DataProvider","fields":[{"name":"name","description":"The name of the external data provider.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"String"}},"isDeprecated":false},{"name":"description","description":"Description of the data provider.","args":[],"type":{"kind":"SCALAR","name":"String"},"isDeprecated":false}],"interfaces":[]},{"kind":"SCALAR","name":"Date","description":"Date formatted as ISO 8601"},{"kind":"SCALAR","name":"DateTime","description":"DateTime formatted as ISO 8601."},{"kind":"INPUT_OBJECT","name":"DateTimeFilter","description":"Filter by a datetime range.","inputFields":[{"name":"gte","description":"DateTime for the beginning of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}},{"name":"lte","description":"DateTime for the end of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}}]},{"kind":"SCALAR","name":"Decimal","description":"Decimal number representation."},{"kind":"ENUM","name":"ErrorDetail","enumValues":[{"name":"UNKNOWN","description":"Unknown error.\n\nThis error should only be returned when no other error detail applies.\nIf a client sees an unknown errorDetail, it will be interpreted as UNKNOWN.\n\nHTTP Mapping: 500 Internal Server Error","isDeprecated":false},{"name":"FIELD_NOT_FOUND","description":"The requested field is not found in the schema.\n\nThis differs from `NOT_FOUND` in that `NOT_FOUND` should be used when a\nquery is valid, but is unable to return a result (if, for example, a\nspecific video id doesn't exist). `FIELD_NOT_FOUND` is intended to be\nreturned by the server to signify that the requested field is not known to exist.\nThis may be returned in lieu of failing the entire query.\nSee also `PERMISSION_DENIED` for cases where the\nrequested field is invalid only for the given user or class of users.\n\nHTTP Mapping: 404 Not Found\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_CURSOR","description":"The provided cursor is not valid.\n\nThe most common usage for this error is when a client is paginating\nthrough a list that uses stateful cursors. In that case, the provided\ncursor may be expired.\n\nHTTP Mapping: 404 Not Found\nError Type: NOT_FOUND","isDeprecated":false},{"name":"UNIMPLEMENTED","description":"The operation is not implemented or is not currently supported/enabled.\n\nHTTP Mapping: 501 Not Implemented\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_ARGUMENT","description":"The client specified an invalid argument.\n\nNote that this differs from `FAILED_PRECONDITION`.\n`INVALID_ARGUMENT` indicates arguments that are problematic\nregardless of the state of the system (e.g., a malformed file name).\n\nHTTP Mapping: 400 Bad Request\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"DEADLINE_EXCEEDED","description":"The deadline expired before the operation could complete.\n\nFor operations that change the state of the system, this error\nmay be returned even if the operation has completed successfully.\nFor example, a successful response from a server could have been\ndelayed long enough for the deadline to expire.\n\nHTTP Mapping: 504 Gateway Timeout\nError Type: UNAVAILABLE","isDeprecated":false},{"name":"SERVICE_ERROR","description":"Service Error.\n\nThere is a problem with an upstream service.\n\nThis may be returned if a gateway re ...
# 2024-11-06 14:55:46,818 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": null}}
# 2024-11-06 14:55:47,104 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"3435","nickname":"Sapec","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3923","name":"Eyeballers"},"private":false}},{"node":{"id":"3436","nickname":"Svedjehed","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"7","name":"AGO"},"private":false}},{"node":{"id":"3437","nickname":"shiNe","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"49449","name":"IBV"},"private":false}},{"node":{"id":"3438","nickname":"flusha","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3923","name":"Eyeballers"},"private":false}},{"node":{"id":"3439","nickname":"PANIX","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1146","name":"Sangal"},"private":false}},{"node":{"id":"3440","nickname":"FreeZe","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47304","name":"ALTERNATE aTTaX"},"private":false}},{"node":{"id":"3441","nickname":"awzek","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47304","name":"ALTERNATE aTTaX"},"private":false}},{"node":{"id":"3442","nickname":"pdy","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47304","name":"ALTERNATE aTTaX"},"private":false}},{"node":{"id":"3443","nickname":"PerX","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47304","name":"ALTERNATE aTTaX"},"private":false}},{"node":{"id":"3446","nickname":"AdreN","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"911","name":"CSGO-2"},"private":false}},{"node":{"id":"3448","nickname":"SANJI","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"911","name":"CSGO-2"},"private":false}},{"node":{"id":"3449","nickname":"QQQ","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1697","name":"Into The Breach"},"private":false}},{"node":{"id":"3450","nickname":"Jame","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"92","name":"Virtus.Pro"},"private":false}},{"node":{"id":"3451","nickname":"Samuelsson","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"910","name":"CSGO-1"},"private":false}},{"node":{"id":"3452","nickname":"dupreeh","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"910","name":"CSGO-1"},"private":false}},{"node":{"id":"3453","nickname":"gla1ve","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"3454","nickname":"Xyp9x","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1","name":"Sprout"},"private":false}},{"node":{"id":"3455","nickname":"device","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"3457","nickname":"Magisk","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"910","name":"CSGO-1"},"private":false}},{"node":{"id":"3458","nickname":"EiZA","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20383","name":"GenOne"},"private":false}},{"node":{"id":"3459","nickname":"krii","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20612","name":"The Prodigies"},"private":false}},{"node":{"id":"3460","nickname":"keen","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20612","name":"The Prodigies"},"private":false}},{"node":{"id":"3461","nickname":"Independent","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48656","name":"ORKS"},"private":false}},{"node":{"id":"3462","nickname":"shield","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20612","name":"The Prodigies"},"private":false}},{"node":{"id":"3463","nickname":"HS","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48656","name":"ORKS"},"private":false}},{"node":{"id":"3464","nickname":"supra","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1733","name":"Benched"},"private":false}},{"node":{"id":"3466","nickname":"s ...
# 2024-11-06 14:55:47,105 - INFO - Processed page 1 - Got 50 items
# 2024-11-06 14:55:48,869 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RCR0QLC1oLCw=="}}
# 2024-11-06 14:55:49,534 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"3504","nickname":"Brooxsy","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"10","name":"LDLC"},"private":false}},{"node":{"id":"3505","nickname":"Snobling","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"10","name":"LDLC"},"private":false}},{"node":{"id":"3506","nickname":"Diviiii","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47253","name":"Arcadia"},"private":false}},{"node":{"id":"3507","nickname":"baljs","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48602","name":"lajtbitexe"},"private":false}},{"node":{"id":"3508","nickname":"darko","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1671","name":"PGE Turów"},"private":false}},{"node":{"id":"3509","nickname":"kadziu","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1671","name":"PGE Turów"},"private":false}},{"node":{"id":"3510","nickname":"noise","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47903","name":"UNGENTIUM"},"private":false}},{"node":{"id":"3511","nickname":"gRuChA","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1671","name":"PGE Turów"},"private":false}},{"node":{"id":"3512","nickname":"Woro2k","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3910","name":"Monte"},"private":false}},{"node":{"id":"3513","nickname":"Fessor","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48807","name":"WTC mix"},"private":false}},{"node":{"id":"3514","nickname":"DemQQ","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3910","name":"Monte"},"private":false}},{"node":{"id":"3515","nickname":"BOROS","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47850","name":"Falcons"},"private":false}},{"node":{"id":"3516","nickname":"kRaSnaL","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3910","name":"Monte"},"private":false}},{"node":{"id":"3517","nickname":"szejn","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47447","name":"Illuminar"},"private":false}},{"node":{"id":"3519","nickname":"TOAO","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47903","name":"UNGENTIUM"},"private":false}},{"node":{"id":"3520","nickname":"asran","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47903","name":"UNGENTIUM"},"private":false}},{"node":{"id":"3521","nickname":"morelz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"471","name":"Pompa"},"private":false}},{"node":{"id":"3526","nickname":"gh","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48566","name":"INTENSE GAME"},"private":false}},{"node":{"id":"3527","nickname":"Kurgan","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48566","name":"INTENSE GAME"},"private":false}},{"node":{"id":"3528","nickname":"DebornY","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3761","name":"AJF"},"private":false}},{"node":{"id":"3529","nickname":"Lukz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48316","name":"Looking4Org"},"private":false}},{"node":{"id":"3530","nickname":"Brnz1k","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46823","name":"dreamWorse GG"},"private":false}},{"node":{"id":"3531","nickname":"nicks","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3288","name":"MIBR Academy"},"private":false}},{"node":{"id":"3532","nickname":"lub","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1710","name":"O PLANO"},"private":false}},{"node":{"id":"3533","nickname":"phx","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"49498","name":"Cebolos"},"private":false}},{"node":{"id":"3534","nickname":"card","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3288","name":"MIBR Academy"},"private":false}},{"node":{"id":"3535","nickname":"insani", ...
# 2024-11-06 14:55:49,535 - INFO - Processed page 2 - Got 50 items
# 2024-11-06 14:55:51,882 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RCT0ULC1oLCw=="}}
# 2024-11-06 14:55:52,568 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"3583","nickname":"Patti","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3128","name":"ECSTATIC"},"private":false}},{"node":{"id":"3584","nickname":"hazart","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19848","name":"Hype E-sports"},"private":false}},{"node":{"id":"3585","nickname":"mid1","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19848","name":"Hype E-sports"},"private":false}},{"node":{"id":"3586","nickname":"fokiu","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48585","name":"W7M"},"private":false}},{"node":{"id":"3587","nickname":"kYOSHix","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19848","name":"Hype E-sports"},"private":false}},{"node":{"id":"3588","nickname":"MITHPUTTINI","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19848","name":"Hype E-sports"},"private":false}},{"node":{"id":"3589","nickname":"mxa","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48767","name":"Super Sangre Jovem"},"private":false}},{"node":{"id":"3590","nickname":"lilob0Y-","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48058","name":"ODDIK"},"private":false}},{"node":{"id":"3591","nickname":"sta1n__","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46823","name":"dreamWorse GG"},"private":false}},{"node":{"id":"3592","nickname":"bsd","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48566","name":"INTENSE GAME"},"private":false}},{"node":{"id":"3593","nickname":"cso","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47278","name":"Solid"},"private":false}},{"node":{"id":"3595","nickname":"Adam9130","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46217","name":"Into the Bin"},"private":false}},{"node":{"id":"3596","nickname":"dobbo","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46217","name":"Into the Bin"},"private":false}},{"node":{"id":"3597","nickname":"RuStY","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46364","name":"Metizport"},"private":false}},{"node":{"id":"3598","nickname":"CYPHER","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48759","name":"TSM"},"private":false}},{"node":{"id":"3600","nickname":"KEi_-","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"927","name":"9INE"},"private":false}},{"node":{"id":"3601","nickname":"mage","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"927","name":"9INE"},"private":false}},{"node":{"id":"3602","nickname":"SZPERO","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20711","name":"PACT"},"private":false}},{"node":{"id":"3603","nickname":"Rogue","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"927","name":"9INE"},"private":false}},{"node":{"id":"3604","nickname":"Kylar","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"927","name":"9INE"},"private":false}},{"node":{"id":"3609","nickname":"skooN","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"38992","name":"FH esports"},"private":false}},{"node":{"id":"3610","nickname":"ZeRq","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3049","name":"SAGA"},"private":false}},{"node":{"id":"3611","nickname":"ADHD","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3049","name":"SAGA"},"private":false}},{"node":{"id":"3612","nickname":"DOM","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3049","name":"SAGA"},"private":false}},{"node":{"id":"3613","nickname":"WZRD","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"38992","name":"FH esports"},"private":false}},{"node":{"id":"3614","nickname":"SVEITTUR","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20416","name":"Atlantic"},"private":false}},{"node":{"id":"3615","nickname":" ...
# 2024-11-06 14:55:52,569 - INFO - Processed page 3 - Got 50 items
# 2024-11-06 14:55:54,889 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RBQ0ALC1oLCw=="}}
# 2024-11-06 14:55:55,540 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"3649","nickname":"Kenz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"4324","name":"Team DNA"},"private":false}},{"node":{"id":"3650","nickname":"Ch1py","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"4324","name":"Team DNA"},"private":false}},{"node":{"id":"3651","nickname":"K1","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"4324","name":"Team DNA"},"private":false}},{"node":{"id":"3652","nickname":"Gank88","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"4324","name":"Team DNA"},"private":false}},{"node":{"id":"3653","nickname":"0K1N-","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"4324","name":"Team DNA"},"private":false}},{"node":{"id":"3654","nickname":"Andrew","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1977","name":"X13"},"private":false}},{"node":{"id":"3655","nickname":"austin","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"2654","name":"Detonate"},"private":false}},{"node":{"id":"3656","nickname":"Gonzo","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"14511","name":"Limitless"},"private":false}},{"node":{"id":"3657","nickname":"Drewtheshrew","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1977","name":"X13"},"private":false}},{"node":{"id":"3658","nickname":"Feral","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1977","name":"X13"},"private":false}},{"node":{"id":"3661","nickname":"TIKO","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47982","name":"Fusion"},"private":false}},{"node":{"id":"3662","nickname":"christO","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3805","name":"LRV Esports"},"private":false}},{"node":{"id":"3663","nickname":"★ ⑳ KUN","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48511","name":"MITOS"},"private":false}},{"node":{"id":"3664","nickname":"Guidomonster","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47982","name":"Fusion"},"private":false}},{"node":{"id":"3665","nickname":"naz1221","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1599","name":"RIVER PLATE GAMING"},"private":false}},{"node":{"id":"3666","nickname":"kauez","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"296","name":"paiN"},"private":false}},{"node":{"id":"3667","nickname":"mello","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1815","name":"FURIA Academy"},"private":false}},{"node":{"id":"3668","nickname":"drop","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3288","name":"MIBR Academy"},"private":false}},{"node":{"id":"3669","nickname":"Bruninho","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1815","name":"FURIA Academy"},"private":false}},{"node":{"id":"3670","nickname":"zmb","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1455","name":"Case Esports"},"private":false}},{"node":{"id":"3672","nickname":"cypress","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46315","name":"Noxious"},"private":false}},{"node":{"id":"3673","nickname":"Vulcan","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48694","name":"Badass"},"private":false}},{"node":{"id":"3675","nickname":"fame","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"92","name":"Virtus.Pro"},"private":false}},{"node":{"id":"3676","nickname":"Yuz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19822","name":"Magic School Bus"},"private":false}},{"node":{"id":"3677","nickname":"Supa","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46835","name":"Tsunami Esports"},"private":false}},{"node":{"id":"3678","nickname":"Ethex","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46835","name":"Tsunami Esports"},"private":false}},{"node":{" ...
# 2024-11-06 14:55:55,541 - INFO - Processed page 4 - Got 50 items
# 2024-11-06 14:55:57,898 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RARUILC1oLCw=="}}
# 2024-11-06 14:55:58,565 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"3726","nickname":"w1nt3r","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"89","name":"AVANGAR"},"private":false}},{"node":{"id":"3727","nickname":"ICY","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"89","name":"AVANGAR"},"private":false}},{"node":{"id":"3728","nickname":"sorrow","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48308","name":"ex-Rune Eaters"},"private":false}},{"node":{"id":"3729","nickname":"kade0","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"4209","name":"Forward"},"private":false}},{"node":{"id":"3736","nickname":"byali","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20711","name":"PACT"},"private":false}},{"node":{"id":"3745","nickname":"DiMKE","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48773","name":"Creeps"},"private":false}},{"node":{"id":"3746","nickname":"brutmonster","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48009","name":"Zero Tenacity"},"private":false}},{"node":{"id":"3747","nickname":"nEMANHA","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48009","name":"Zero Tenacity"},"private":false}},{"node":{"id":"3748","nickname":"Cjoffo","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48009","name":"Zero Tenacity"},"private":false}},{"node":{"id":"3749","nickname":"aVN","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48009","name":"Zero Tenacity"},"private":false}},{"node":{"id":"3750","nickname":"riskyb0b","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48714","name":"Cybershoke"},"private":false}},{"node":{"id":"3751","nickname":"YumsaN","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"521","name":"Juggernauts"},"private":false}},{"node":{"id":"3752","nickname":"sh1nejezzz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48714","name":"Cybershoke"},"private":false}},{"node":{"id":"3753","nickname":"sstiNiX","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47336","name":"forZe"},"private":false}},{"node":{"id":"3754","nickname":"FL4MUS","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"121","name":"Nemiga Gaming"},"private":false}},{"node":{"id":"3767","nickname":"eku","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46206","name":"sYnck"},"private":false}},{"node":{"id":"3768","nickname":"Wahtzz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46206","name":"sYnck"},"private":false}},{"node":{"id":"3769","nickname":"fejtZ","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46206","name":"sYnck"},"private":false}},{"node":{"id":"3770","nickname":"consss","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20612","name":"The Prodigies"},"private":false}},{"node":{"id":"3771","nickname":"aNdul0c066^6 :p","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46206","name":"sYnck"},"private":false}},{"node":{"id":"3772","nickname":"Cabbi","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48461","name":"Espionage"},"private":false}},{"node":{"id":"3773","nickname":"Queenix","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3128","name":"ECSTATIC"},"private":false}},{"node":{"id":"3774","nickname":"kraghen","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3128","name":"ECSTATIC"},"private":false}},{"node":{"id":"3775","nickname":"salazar","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3128","name":"ECSTATIC"},"private":false}},{"node":{"id":"3776","nickname":"maNkz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48601","name":"M80"},"private":false}},{"node":{"id":"3777","nickname":"nbqq","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1937","name":"Dynamo Eclot"},"private":fals ...
# 2024-11-06 14:55:58,567 - INFO - Processed page 5 - Got 50 items
# 2024-11-06 14:56:00,911 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RPR0MLC1oLCw=="}}
# 2024-11-06 14:56:01,591 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"3805","nickname":"Mikki","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1620","name":"777"},"private":false}},{"node":{"id":"3806","nickname":"PALM1","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1620","name":"777"},"private":false}},{"node":{"id":"3807","nickname":"akez","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1620","name":"777"},"private":false}},{"node":{"id":"3808","nickname":"sly","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"471","name":"Pompa"},"private":false}},{"node":{"id":"3809","nickname":"Trax","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"2834","name":"Apeks Rebels"},"private":false}},{"node":{"id":"3812","nickname":"moobatv003","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"515","name":"North Macedonia"},"private":false}},{"node":{"id":"3813","nickname":"IESF 1","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"515","name":"North Macedonia"},"private":false}},{"node":{"id":"3814","nickname":"4","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48030","name":"China"},"private":false}},{"node":{"id":"3815","nickname":"moobatv005","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48030","name":"China"},"private":false}},{"node":{"id":"3816","nickname":"MKV Gaming","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48030","name":"China"},"private":false}},{"node":{"id":"3817","nickname":"IESF#1","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"515","name":"North Macedonia"},"private":false}},{"node":{"id":"3819","nickname":"PR1mE","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3924","name":"Sashi"},"private":false}},{"node":{"id":"3820","nickname":"Lucky","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48461","name":"Espionage"},"private":false}},{"node":{"id":"3821","nickname":"kwezz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48461","name":"Espionage"},"private":false}},{"node":{"id":"3822","nickname":"Nodios","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3128","name":"ECSTATIC"},"private":false}},{"node":{"id":"3823","nickname":"IceBerg","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48461","name":"Espionage"},"private":false}},{"node":{"id":"3828","nickname":"Stev0se","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1574","name":"EC Brugge"},"private":false}},{"node":{"id":"3829","nickname":"ritchiEE","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"20612","name":"The Prodigies"},"private":false}},{"node":{"id":"3830","nickname":"matty","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1574","name":"EC Brugge"},"private":false}},{"node":{"id":"3831","nickname":"n0tice","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1574","name":"EC Brugge"},"private":false}},{"node":{"id":"3832","nickname":"simixkG","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1574","name":"EC Brugge"},"private":false}},{"node":{"id":"3833","nickname":"Lester","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"3834","nickname":"Frank","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"3835","nickname":"Harvey","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"3836","nickname":"Cecil","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"3837","nickname":"Elliot","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"3838", ...
# 2024-11-06 14:56:01,591 - INFO - Processed page 6 - Got 50 items
# 2024-11-06 14:56:03,920 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0ROR0ULC1oLCw=="}}
# 2024-11-06 14:56:04,639 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"3903","nickname":"nero","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48480","name":"Rocket"},"private":false}},{"node":{"id":"3904","nickname":"aleph","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48480","name":"Rocket"},"private":false}},{"node":{"id":"3905","nickname":"shade","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48182","name":"Team Mystique"},"private":false}},{"node":{"id":"3906","nickname":"Elk","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48480","name":"Rocket"},"private":false}},{"node":{"id":"3907","nickname":"Momo","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47475","name":"Evil Geniuses"},"private":false}},{"node":{"id":"3908","nickname":"jonji","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"104","name":"Bad News Bears"},"private":false}},{"node":{"id":"3909","nickname":"viz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"228","name":"Party Astronauts"},"private":false}},{"node":{"id":"3910","nickname":"ben1337","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"228","name":"Party Astronauts"},"private":false}},{"node":{"id":"3911","nickname":"PwnAlone","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"228","name":"Party Astronauts"},"private":false}},{"node":{"id":"3913","nickname":"Cryptic","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48599","name":"Wildcard Gaming"},"private":false}},{"node":{"id":"3914","nickname":"freshie","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48599","name":"Wildcard Gaming"},"private":false}},{"node":{"id":"3915","nickname":"micro","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"2654","name":"Detonate"},"private":false}},{"node":{"id":"3916","nickname":"Florence","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46668","name":"yur"},"private":false}},{"node":{"id":"3917","nickname":"brett","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48599","name":"Wildcard Gaming"},"private":false}},{"node":{"id":"3918","nickname":"TRK","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48683","name":"Projetinho"},"private":false}},{"node":{"id":"3919","nickname":"Maluk3","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48774","name":"AGE SPORTS"},"private":false}},{"node":{"id":"3920","nickname":"iDk","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48774","name":"AGE SPORTS"},"private":false}},{"node":{"id":"3921","nickname":"pesadelo ;)","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48774","name":"AGE SPORTS"},"private":false}},{"node":{"id":"3922","nickname":"malbsMd","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48601","name":"M80"},"private":false}},{"node":{"id":"3937","nickname":"vHw","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"2834","name":"Apeks Rebels"},"private":false}},{"node":{"id":"3941","nickname":"berzerk","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"2834","name":"Apeks Rebels"},"private":false}},{"node":{"id":"3943","nickname":"Tapewaare","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"2834","name":"Apeks Rebels"},"private":false}},{"node":{"id":"3945","nickname":"sense","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47628","name":"Apeks"},"private":false}},{"node":{"id":"3964","nickname":"Tudson","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46990","name":"Seychelles"},"private":false}},{"node":{"id":"3966","nickname":"M1key","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48245","name":"UNiTY"},"private":false}},{"node":{"id":"3967","nickname":"Levi","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48245","name": ...
# 2024-11-06 14:56:04,641 - INFO - Processed page 7 - Got 50 items
# 2024-11-06 14:56:06,930 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0NHREcLC1oLCw=="}}
# 2024-11-06 14:56:07,689 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"4031","nickname":"iso","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48248","name":"Ignis Serpens"},"private":false}},{"node":{"id":"4032","nickname":"Layner","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48248","name":"Ignis Serpens"},"private":false}},{"node":{"id":"4035","nickname":"Jackinho","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46364","name":"Metizport"},"private":false}},{"node":{"id":"4036","nickname":"bq","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"957","name":"Lilmix"},"private":false}},{"node":{"id":"4037","nickname":"quix","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"957","name":"Lilmix"},"private":false}},{"node":{"id":"4038","nickname":"robiin","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47313","name":"Alliance"},"private":false}},{"node":{"id":"4040","nickname":"hns","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"46364","name":"Metizport"},"private":false}},{"node":{"id":"4044","nickname":"Yuri","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4045","nickname":"Toby","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4046","nickname":"Frasier","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4048","nickname":"Waldo","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4051","nickname":"Opie","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"4052","nickname":"George","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"4053","nickname":"Oliver","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4055","nickname":"Allen","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4056","nickname":"Bert","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"4058","nickname":"Ernie","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4060","nickname":"Irwin","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"4062","nickname":"Ferris","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"4063","nickname":"Yogi","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4065","nickname":"Walt","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4066","nickname":"Fergus","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4068","nickname":"Neil","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4069","nickname":"Larry","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"78","name":"Astralis"},"private":false}},{"node":{"id":"4070","nickname":"Wally","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47355","name":"FaZe Clan"},"private":false}},{"node":{"id":"4079","nickname":"snatchie","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3325","name":"PGE Turów Zgorzelec"},"private":false}},{"node":{"id":"4081","nickn ...
# 2024-11-06 14:56:07,690 - INFO - Processed page 8 - Got 50 items
# 2024-11-06 14:56:09,975 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0NGREULC1oLCw=="}}
# 2024-11-06 14:56:10,671 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"4134","nickname":"RICIOLI","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3371","name":"UNO MILLE"},"private":false}},{"node":{"id":"4136","nickname":"Vla","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"48566","name":"INTENSE GAME"},"private":false}},{"node":{"id":"4137","nickname":"xeNyy","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19755","name":"Viðstöðu"},"private":false}},{"node":{"id":"4139","nickname":"blazter","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"38992","name":"FH esports"},"private":false}},{"node":{"id":"4141","nickname":"allee**","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1702","name":"Þór"},"private":false}},{"node":{"id":"4143","nickname":"klassy","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19755","name":"Viðstöðu"},"private":false}},{"node":{"id":"4145","nickname":"mozar7","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"38992","name":"FH esports"},"private":false}},{"node":{"id":"4147","nickname":"Criis","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3050","name":"Armann"},"private":false}},{"node":{"id":"4148","nickname":"Polishw0nder","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3050","name":"Armann"},"private":false}},{"node":{"id":"4150","nickname":"kraKen_","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3050","name":"Armann"},"private":false}},{"node":{"id":"4152","nickname":"ofvirkur","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3050","name":"Armann"},"private":false}},{"node":{"id":"4153","nickname":"HUNDZi *","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"3050","name":"Armann"},"private":false}},{"node":{"id":"4160","nickname":"togs","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"127","name":"Sharks"},"private":false}},{"node":{"id":"4162","nickname":"drg","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"127","name":"Sharks"},"private":false}},{"node":{"id":"4164","nickname":"⑳ chayJESUS","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"127","name":"Sharks"},"private":false}},{"node":{"id":"4166","nickname":"⑳ jnt","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"47950","name":"The Union"},"private":false}},{"node":{"id":"4167","nickname":"n1ssim","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"422","name":"Flamengo eSports"},"private":false}},{"node":{"id":"4169","nickname":"viRuz","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19756","name":"Breiðablik"},"private":false}},{"node":{"id":"4171","nickname":"wNkr","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19756","name":"Breiðablik"},"private":false}},{"node":{"id":"4172","nickname":"furri","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19756","name":"Breiðablik"},"private":false}},{"node":{"id":"4174","nickname":"Sax","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19756","name":"Breiðablik"},"private":false}},{"node":{"id":"4175","nickname":"LiLLehhhh","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"19756","name":"Breiðablik"},"private":false}},{"node":{"id":"4177","nickname":"EddezeNNN","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1243","name":"DUSTY"},"private":false}},{"node":{"id":"4178","nickname":"b0ndi","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1243","name":"DUSTY"},"private":false}},{"node":{"id":"4179","nickname":"StebbiC0C0","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1243","name":"DUSTY"},"private":false}},{"node":{"id":"4180","nickname":"TH0R","title":{"name":"Counter Strike: Global Offensive"},"team":{"id":"1243","name":"DUSTY"},"private":false}},{"node":{"id":"4181","ni ...
# 2024-11-06 14:56:10,672 - INFO - Processed page 9 - Got 50 items
# 2024-11-06 14:56:12,946 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0NFQkYLC1oLCw=="}}
# ...
# 2024-11-06 15:00:59,420 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"118479","nickname":"Pretzel","title":{"name":"Counter Strike 2"},"team":{"id":"54098","name":"TSM 2.0"},"private":false}},{"node":{"id":"118480","nickname":"Lx","title":{"name":"Counter Strike 2"},"team":{"id":"54098","name":"TSM 2.0"},"private":false}},{"node":{"id":"118482","nickname":"Syyko","title":{"name":"Counter Strike 2"},"team":{"id":"54097","name":"Sedated"},"private":false}},{"node":{"id":"118484","nickname":"Darthkaechi","title":{"name":"Counter Strike 2"},"team":{"id":"54097","name":"Sedated"},"private":false}},{"node":{"id":"118485","nickname":"Ash_Red","title":{"name":"Counter Strike 2"},"team":{"id":"54097","name":"Sedated"},"private":false}},{"node":{"id":"118487","nickname":"Kolsy","title":{"name":"Counter Strike 2"},"team":{"id":"54097","name":"Sedated"},"private":false}},{"node":{"id":"118488","nickname":"Monstr","title":{"name":"Counter Strike 2"},"team":{"id":"54097","name":"Sedated"},"private":false}},{"node":{"id":"118490","nickname":"Dolphin","title":{"name":"Counter Strike 2"},"team":{"id":"54100","name":"Brain Destroyer"},"private":false}},{"node":{"id":"118492","nickname":"soda man 28","title":{"name":"Counter Strike 2"},"team":{"id":"54100","name":"Brain Destroyer"},"private":false}},{"node":{"id":"118493","nickname":"DuGGz","title":{"name":"Counter Strike 2"},"team":{"id":"54100","name":"Brain Destroyer"},"private":false}},{"node":{"id":"118495","nickname":"GLB118","title":{"name":"Counter Strike 2"},"team":{"id":"54100","name":"Brain Destroyer"},"private":false}},{"node":{"id":"118497","nickname":"HUH","title":{"name":"Counter Strike 2"},"team":{"id":"54100","name":"Brain Destroyer"},"private":false}},{"node":{"id":"118499","nickname":"djay","title":{"name":"Counter Strike 2"},"team":{"id":"54099","name":"Might x Gripgel"},"private":false}},{"node":{"id":"118501","nickname":"pwnalone","title":{"name":"Counter Strike 2"},"team":{"id":"54099","name":"Might x Gripgel"},"private":false}},{"node":{"id":"118502","nickname":"snakes","title":{"name":"Counter Strike 2"},"team":{"id":"54099","name":"Might x Gripgel"},"private":false}},{"node":{"id":"118504","nickname":"jonji","title":{"name":"Counter Strike 2"},"team":{"id":"54099","name":"Might x Gripgel"},"private":false}},{"node":{"id":"118506","nickname":"BATSPEED","title":{"name":"Counter Strike 2"},"team":{"id":"53538","name":"Revel"},"private":false}},{"node":{"id":"118508","nickname":"tripp","title":{"name":"Counter Strike 2"},"team":{"id":"53538","name":"Revel"},"private":false}},{"node":{"id":"118512","nickname":"Outback","title":{"name":"Counter Strike 2"},"team":{"id":"54101","name":"Penance"},"private":false}},{"node":{"id":"118514","nickname":"REKMEISTER","title":{"name":"Counter Strike 2"},"team":{"id":"54101","name":"Penance"},"private":false}},{"node":{"id":"118517","nickname":"doltn","title":{"name":"Counter Strike 2"},"team":{"id":"54107","name":"Alter Iron Club"},"private":false}},{"node":{"id":"118519","nickname":"toasty","title":{"name":"Counter Strike 2"},"team":{"id":"54102","name":"Dumb Dogs"},"private":false}},{"node":{"id":"118521","nickname":"GKaay","title":{"name":"Counter Strike 2"},"team":{"id":"54102","name":"Dumb Dogs"},"private":false}},{"node":{"id":"118523","nickname":"TeXaSs^","title":{"name":"Counter Strike 2"},"team":{"id":"54102","name":"Dumb Dogs"},"private":false}},{"node":{"id":"118525","nickname":"sathsea","title":{"name":"Counter Strike 2"},"team":{"id":"54102","name":"Dumb Dogs"},"private":false}},{"node":{"id":"118526","nickname":"Clutch","title":{"name":"Counter Strike 2"},"team":{"id":"54105","name":"Not My IGL"},"private":false}},{"node":{"id":"118528","nickname":"Tyler_","title":{"name":"Counter Strike 2"},"team":{"id":"54105","name":"Not My IGL"},"private":false}},{"node":{"id":"118530","nickname":"JAMEStheGREAT3","title":{"name":"Counter Strike 2"},"team":{"id":"54105","name":"Not My IGL"},"private":false}},{"node":{"id":"11 ...
# 2024-11-06 15:00:59,421 - INFO - Processed page 105 - Got 50 items
# 2024-11-06 15:01:01,696 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0ZGT0JARgsLWgsL"}}
# 2024-11-06 15:01:02,386 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"118573","nickname":"Galact","title":{"name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"118574","nickname":"dirtydan","title":{"name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"118576","nickname":"Xirt","title":{"name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"118578","nickname":"Trick","title":{"name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"118579","nickname":"Ravenzs","title":{"name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"118581","nickname":"RECKLESS","title":{"name":"Counter Strike 2"},"team":{"id":"54111","name":"Fisher Tsunami"},"private":false}},{"node":{"id":"118583","nickname":"pecan50","title":{"name":"Counter Strike 2"},"team":{"id":"54111","name":"Fisher Tsunami"},"private":false}},{"node":{"id":"118585","nickname":"leae","title":{"name":"Counter Strike 2"},"team":{"id":"54111","name":"Fisher Tsunami"},"private":false}},{"node":{"id":"118587","nickname":"borb_","title":{"name":"Counter Strike 2"},"team":{"id":"54111","name":"Fisher Tsunami"},"private":false}},{"node":{"id":"118589","nickname":"Huntxr","title":{"name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"118620","nickname":"HAMBOOGA","title":{"name":"Counter Strike 2"},"team":{"id":"54122","name":"Take Flyte Frauds"},"private":false}},{"node":{"id":"118622","nickname":"Ink","title":{"name":"Counter Strike 2"},"team":{"id":"54122","name":"Take Flyte Frauds"},"private":false}},{"node":{"id":"118623","nickname":"jwb","title":{"name":"Counter Strike 2"},"team":{"id":"54122","name":"Take Flyte Frauds"},"private":false}},{"node":{"id":"118625","nickname":"cutedog","title":{"name":"Counter Strike 2"},"team":{"id":"54122","name":"Take Flyte Frauds"},"private":false}},{"node":{"id":"118627","nickname":"noahhh","title":{"name":"Counter Strike 2"},"team":{"id":"54122","name":"Take Flyte Frauds"},"private":false}},{"node":{"id":"118629","nickname":"JMZ","title":{"name":"Counter Strike 2"},"team":{"id":"54121","name":"Planet Express"},"private":false}},{"node":{"id":"118630","nickname":"Auser","title":{"name":"Counter Strike 2"},"team":{"id":"54121","name":"Planet Express"},"private":false}},{"node":{"id":"118632","nickname":"A1pha","title":{"name":"Counter Strike 2"},"team":{"id":"54121","name":"Planet Express"},"private":false}},{"node":{"id":"118634","nickname":"LittleBEER","title":{"name":"Counter Strike 2"},"team":{"id":"53848","name":"After Hours"},"private":false}},{"node":{"id":"118636","nickname":"CMitch","title":{"name":"Counter Strike 2"},"team":{"id":"53848","name":"After Hours"},"private":false}},{"node":{"id":"118638","nickname":"Swoozy","title":{"name":"Counter Strike 2"},"team":{"id":"54120","name":"Boiler Boyz"},"private":false}},{"node":{"id":"118639","nickname":"pawla","title":{"name":"Counter Strike 2"},"team":{"id":"54120","name":"Boiler Boyz"},"private":false}},{"node":{"id":"118641","nickname":"flow","title":{"name":"Counter Strike 2"},"team":{"id":"54120","name":"Boiler Boyz"},"private":false}},{"node":{"id":"118643","nickname":"Xner","title":{"name":"Counter Strike 2"},"team":{"id":"54120","name":"Boiler Boyz"},"private":false}},{"node":{"id":"118645","nickname":"dAVE","title":{"name":"Counter Strike 2"},"team":{"id":"54124","name":"Slugy's Shekel Squad"},"private":false}},{"node":{"id":"118647","nickname":"slugy","title":{"name":"Counter Strike 2"},"team":{"id":"54124","name":"Slugy's Shekel Squad"},"private":false}},{"node":{"id":"118649","nickname":"nguyen","title":{"name":"Counter Strike 2"},"team":{"id":"54124","name":"Slugy's Shekel Squad"},"private":false}},{"node":{"id":"118651","nickname":"JDubs","title":{"name":"Counter Strike 2"},"team":{"id":"54124","name":"Slugy's She ...
# 2024-11-06 15:01:02,387 - INFO - Processed page 106 - Got 50 items
# 2024-11-06 15:01:04,700 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0ZGT0BEQgsLWgsL"}}
# 2024-11-06 15:01:05,378 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"118739","nickname":"5-star","title":{"name":"Counter Strike 2"},"team":{"id":"52375","name":"FALKE ESPORTS"},"private":false}},{"node":{"id":"118741","nickname":"HeMan","title":{"name":"Counter Strike 2"},"team":{"id":"52375","name":"FALKE ESPORTS"},"private":false}},{"node":{"id":"118742","nickname":"Rafex78","title":{"name":"Counter Strike 2"},"team":{"id":"52375","name":"FALKE ESPORTS"},"private":false}},{"node":{"id":"118743","nickname":"Ag3NtK","title":{"name":"Counter Strike 2"},"team":{"id":"52375","name":"FALKE ESPORTS"},"private":false}},{"node":{"id":"118745","nickname":"Shn","title":{"name":"Counter Strike 2"},"team":{"id":"52375","name":"FALKE ESPORTS"},"private":false}},{"node":{"id":"118747","nickname":"akuma","title":{"name":"Counter Strike 2"},"team":{"id":"54129","name":"Coxos"},"private":false}},{"node":{"id":"118749","nickname":"lwh","title":{"name":"Counter Strike 2"},"team":{"id":"54126","name":"Talaintanse"},"private":false}},{"node":{"id":"118751","nickname":"bayon","title":{"name":"Counter Strike 2"},"team":{"id":"50400","name":"ICON"},"private":false}},{"node":{"id":"118753","nickname":"meskiii","title":{"name":"Counter Strike 2"},"team":{"id":"54126","name":"Talaintanse"},"private":false}},{"node":{"id":"118754","nickname":"pakitu","title":{"name":"Counter Strike 2"},"team":{"id":"54126","name":"Talaintanse"},"private":false}},{"node":{"id":"118756","nickname":"kaZzu","title":{"name":"Counter Strike 2"},"team":{"id":"54128","name":"SweetBonanzers"},"private":false}},{"node":{"id":"118758","nickname":"Werzaide","title":{"name":"Counter Strike 2"},"team":{"id":"54128","name":"SweetBonanzers"},"private":false}},{"node":{"id":"118760","nickname":"doon1k","title":{"name":"Counter Strike 2"},"team":{"id":"54128","name":"SweetBonanzers"},"private":false}},{"node":{"id":"118762","nickname":"YuRk0","title":{"name":"Counter Strike 2"},"team":{"id":"54127","name":"CarritoSpain"},"private":false}},{"node":{"id":"118768","nickname":"TeSeS","title":{"name":"Counter Strike 2"},"team":{"id":"49627","name":"Heroic"},"private":false}},{"node":{"id":"118770","nickname":"NertZ","title":{"name":"Counter Strike 2"},"team":{"id":"49627","name":"Heroic"},"private":false}},{"node":{"id":"118772","nickname":"kyxsan","title":{"name":"Counter Strike 2"},"team":{"id":"49627","name":"Heroic"},"private":false}},{"node":{"id":"118773","nickname":"sjuush","title":{"name":"Counter Strike 2"},"team":{"id":"49627","name":"Heroic"},"private":false}},{"node":{"id":"118775","nickname":"degster","title":{"name":"Counter Strike 2"},"team":{"id":"49627","name":"Heroic"},"private":false}},{"node":{"id":"118796","nickname":"MaThZ†","title":{"name":"Counter Strike 2"},"team":{"id":"51536","name":"GenOne"},"private":false}},{"node":{"id":"118901","nickname":"kreyn","title":{"name":"Counter Strike 2"},"team":{"id":"50400","name":"ICON"},"private":false}},{"node":{"id":"118903","nickname":"met","title":{"name":"Counter Strike 2"},"team":{"id":"50400","name":"ICON"},"private":false}},{"node":{"id":"118905","nickname":"Jarimba","title":{"name":"Counter Strike 2"},"team":{"id":"50400","name":"ICON"},"private":false}},{"node":{"id":"118907","nickname":"XICQQ","title":{"name":"Counter Strike 2"},"team":{"id":"50400","name":"ICON"},"private":false}},{"node":{"id":"118910","nickname":"Dvn666-_","title":{"name":"Counter Strike 2"},"team":{"id":"54129","name":"Coxos"},"private":false}},{"node":{"id":"118912","nickname":"niox","title":{"name":"Counter Strike 2"},"team":{"id":"54129","name":"Coxos"},"private":false}},{"node":{"id":"118949","nickname":"rocky","title":{"name":"Counter Strike 2"},"team":{"id":"52197","name":"SQUAD"},"private":false}},{"node":{"id":"119049","nickname":"pancc","title":{"name":"Counter Strike 2"},"team":{"id":"53712","name":"Vikings KR"},"private":false}},{"node":{"id":"119051","nickname":"talkzyn","title":{"name":"Counter Strike 2"},"team":{"id":"5395 ...
# 2024-11-06 15:01:05,381 - INFO - Processed page 107 - Got 50 items
# 2024-11-06 15:01:07,714 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor) {\n  players(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0ZGTkZEQgsLWgsL"}}
# 2024-11-06 15:01:08,410 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"119137","nickname":"vhs","title":{"name":"Counter Strike 2"},"team":{"id":"52162","name":"BeBold.gg"},"private":false}},{"node":{"id":"119138","nickname":"guH","title":{"name":"Counter Strike 2"},"team":{"id":"52162","name":"BeBold.gg"},"private":false}},{"node":{"id":"119309","nickname":"EddezeNNN","title":{"name":"Counter Strike 2"},"team":{"id":"49944","name":"DUSTY"},"private":false}},{"node":{"id":"119311","nickname":"th0rsteinnf","title":{"name":"Counter Strike 2"},"team":{"id":"49944","name":"DUSTY"},"private":false}},{"node":{"id":"119346","nickname":"Hippo","title":{"name":"Counter Strike 2"},"team":{"id":"53826","name":"ADEPTS"},"private":false}},{"node":{"id":"119403","nickname":"BALJS","title":{"name":"Counter Strike 2"},"team":{"id":"54068","name":"DevilsOne"},"private":false}},{"node":{"id":"119405","nickname":"H4RR3w0w","title":{"name":"Counter Strike 2"},"team":{"id":"50020","name":"777"},"private":false}},{"node":{"id":"119454","nickname":"doobs","title":{"name":"Counter Strike 2"},"team":{"id":"49873","name":"Lilmix"},"private":false}},{"node":{"id":"119496","nickname":"dobbo","title":{"name":"Counter Strike 2"},"team":{"id":"49506","name":"Verdant"},"private":false}},{"node":{"id":"119696","nickname":"MAT1-_-","title":{"name":"Counter Strike 2"},"team":{"id":"54139","name":"kubixPulse"},"private":false}}],"pageInfo":{"hasNextPage":false,"endCursor":"PjMLC1oLC0ZGTkFOQQsLWgsL"}}}}
# 2024-11-06 15:01:08,410 - INFO - Processed page 108 - Got 10 items
# 2024-11-06 15:01:08,421 - INFO - Collected 5360 players
# Players Sample:
#      id   nickname                             title team_id   team_name  \
# 0  3435      Sapec  Counter Strike: Global Offensive    3923  Eyeballers
# 1  3436  Svedjehed  Counter Strike: Global Offensive       7         AGO
# 2  3437      shiNe  Counter Strike: Global Offensive   49449         IBV
# 3  3438     flusha  Counter Strike: Global Offensive    3923  Eyeballers
# 4  3439      PANIX  Counter Strike: Global Offensive    1146      Sangal
#
#    private
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
# Collect Player Statistics
try:
    logging.info("Collecting player statistics...")
    player_stats_list = []
    total_players = len(players_df)
    
    for idx, player_id in enumerate(players_df['id']):
        try:
            logging.info(f"Collecting statistics for player {player_id} ({idx+1}/{total_players})")
            player_stats = collector.get_player_statistics(player_id)
            
            if player_stats is not None:
                # Extract game statistics
                game_stats = player_stats.get('game', {})
                segment_stats = player_stats.get('segment', [])
                
                kills = game_stats.get('kills', {}).get('sum', 0)
                deaths = game_stats.get('deaths', {}).get('sum', 0)
                assists = game_stats.get('killAssistsGiven', {}).get('sum', 0)
                damage_dealt = game_stats.get('damageDealt', {}).get('sum', 0)
                wins = sum([item.get('count', 0) for item in game_stats.get('won', []) if item.get('value')])
                games_played = game_stats.get('count', 0)
                
                first_kills = sum([item.get('count', 0) for item in game_stats.get('firstKill', []) if item.get('value')])
                first_kill_percentage = next((item.get('percentage', 0) for item in game_stats.get('firstKill', []) if item.get('value')), 0)
                
                # Extract rounds played from segments
                rounds_played = 0
                for segment in segment_stats:
                    if segment.get('type') == 'Round':
                        rounds_played = segment.get('count', 0)
                        break  # Assuming one segment of type 'Round'
                
                # Calculate K/D Ratio
                kd_ratio = kills / deaths if deaths != 0 else kills
                
                # Calculate Win Rate
                win_rate = (wins / games_played) * 100 if games_played != 0 else 0
                
                # Calculate ADR
                adr = damage_dealt / rounds_played if rounds_played != 0 else 0
                
                # Combine with player info
                player_stats_combined = {
                    'id': player_id,
                    'nickname': players_df.loc[players_df['id'] == player_id, 'nickname'].values[0],
                    'team_name': players_df.loc[players_df['id'] == player_id, 'team_name'].values[0],
                    'kills': kills,
                    'deaths': deaths,
                    'assists': assists,
                    'damage_dealt': damage_dealt,
                    'kd_ratio': kd_ratio,
                    'win_rate': win_rate,
                    'first_kills': first_kills,
                    'first_kill_percentage': first_kill_percentage,
                    'rounds_played': rounds_played,
                    'adr': adr,
                }
                player_stats_list.append(player_stats_combined)
            else:
                logging.warning(f"No statistics found for player {player_id}")
            
            # Be mindful of rate limits
            time.sleep(0.2)  # Adjust sleep time based on API rate limits

        except Exception as e:
            logging.error(f"Error collecting statistics for player {player_id}: {str(e)}")
            continue
    
    logging.info("Successfully collected player statistics")

except Exception as e:
    logging.error(f"Error during player statistics collection: {str(e)}")
    raise

# %%
# Collect Tournament Data
try:
    tournaments_df = collector.get_tournaments()
    print(f"\nCollected {len(tournaments_df)} tournaments")
    print("\nSample data:")
    print(tournaments_df.head())
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# 2024-11-06 14:44:55,031 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\tournaments.graphql
# 2024-11-06 14:44:55,036 - INFO - >>> {"query": "query IntrospectionQuery {\n  __schema {\n    queryType {\n      name\n    }\n    mutationType {\n      name\n    }\n    subscriptionType {\n      name\n    }\n    types {\n      ...FullType\n    }\n    directives {\n      name\n      description\n      locations\n      args {\n        ...InputValue\n      }\n    }\n  }\n}\n\nfragment FullType on __Type {\n  kind\n  name\n  description\n  fields(includeDeprecated: true) {\n    name\n    description\n    args {\n      ...InputValue\n    }\n    type {\n      ...TypeRef\n    }\n    isDeprecated\n    deprecationReason\n  }\n  inputFields {\n    ...InputValue\n  }\n  interfaces {\n    ...TypeRef\n  }\n  enumValues(includeDeprecated: true) {\n    name\n    description\n    isDeprecated\n    deprecationReason\n  }\n  possibleTypes {\n    ...TypeRef\n  }\n}\n\nfragment InputValue on __InputValue {\n  name\n  description\n  type {\n    ...TypeRef\n  }\n  defaultValue\n}\n\nfragment TypeRef on __Type {\n  kind\n  name\n  ofType {\n    kind\n    name\n    ofType {\n      kind\n      name\n      ofType {\n        kind\n        name\n        ofType {\n          kind\n          name\n          ofType {\n            kind\n            name\n            ofType {\n              kind\n              name\n              ofType {\n                kind\n                name\n                ofType {\n                  kind\n                  name\n                  ofType {\n                    kind\n                    name\n                  }\n                }\n              }\n            }\n          }\n        }\n      }\n    }\n  }\n}"}
# 2024-11-06 14:44:56,238 - INFO - <<< {"data":{"__schema":{"queryType":{"name":"Query"},"types":[{"kind":"SCALAR","name":"Boolean","description":"Built-in Boolean"},{"kind":"INPUT_OBJECT","name":"BooleanFilter","description":"Boolean filter for true/false fields.","inputFields":[{"name":"equals","description":"Value to look for, can be nullable.","type":{"kind":"SCALAR","name":"Boolean"}}]},{"kind":"SCALAR","name":"Cursor","description":"Cursor value for pagination."},{"kind":"OBJECT","name":"DataProvider","fields":[{"name":"name","description":"The name of the external data provider.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"String"}},"isDeprecated":false},{"name":"description","description":"Description of the data provider.","args":[],"type":{"kind":"SCALAR","name":"String"},"isDeprecated":false}],"interfaces":[]},{"kind":"SCALAR","name":"Date","description":"Date formatted as ISO 8601"},{"kind":"SCALAR","name":"DateTime","description":"DateTime formatted as ISO 8601."},{"kind":"INPUT_OBJECT","name":"DateTimeFilter","description":"Filter by a datetime range.","inputFields":[{"name":"gte","description":"DateTime for the beginning of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}},{"name":"lte","description":"DateTime for the end of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}}]},{"kind":"SCALAR","name":"Decimal","description":"Decimal number representation."},{"kind":"ENUM","name":"ErrorDetail","enumValues":[{"name":"UNKNOWN","description":"Unknown error.\n\nThis error should only be returned when no other error detail applies.\nIf a client sees an unknown errorDetail, it will be interpreted as UNKNOWN.\n\nHTTP Mapping: 500 Internal Server Error","isDeprecated":false},{"name":"FIELD_NOT_FOUND","description":"The requested field is not found in the schema.\n\nThis differs from `NOT_FOUND` in that `NOT_FOUND` should be used when a\nquery is valid, but is unable to return a result (if, for example, a\nspecific video id doesn't exist). `FIELD_NOT_FOUND` is intended to be\nreturned by the server to signify that the requested field is not known to exist.\nThis may be returned in lieu of failing the entire query.\nSee also `PERMISSION_DENIED` for cases where the\nrequested field is invalid only for the given user or class of users.\n\nHTTP Mapping: 404 Not Found\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_CURSOR","description":"The provided cursor is not valid.\n\nThe most common usage for this error is when a client is paginating\nthrough a list that uses stateful cursors. In that case, the provided\ncursor may be expired.\n\nHTTP Mapping: 404 Not Found\nError Type: NOT_FOUND","isDeprecated":false},{"name":"UNIMPLEMENTED","description":"The operation is not implemented or is not currently supported/enabled.\n\nHTTP Mapping: 501 Not Implemented\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_ARGUMENT","description":"The client specified an invalid argument.\n\nNote that this differs from `FAILED_PRECONDITION`.\n`INVALID_ARGUMENT` indicates arguments that are problematic\nregardless of the state of the system (e.g., a malformed file name).\n\nHTTP Mapping: 400 Bad Request\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"DEADLINE_EXCEEDED","description":"The deadline expired before the operation could complete.\n\nFor operations that change the state of the system, this error\nmay be returned even if the operation has completed successfully.\nFor example, a successful response from a server could have been\ndelayed long enough for the deadline to expire.\n\nHTTP Mapping: 504 Gateway Timeout\nError Type: UNAVAILABLE","isDeprecated":false},{"name":"SERVICE_ERROR","description":"Service Error.\n\nThere is a problem with an upstream service.\n\nThis may be returned if a gateway re ...
# 2024-11-06 14:44:56,247 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": null}}
# 2024-11-06 14:44:56,661 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0FBCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0YLC1oLCw==","node":{"id":"1","name":"United Masters League 2018-2019","nameShortened":"UML 1819","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ULC1oLCw==","node":{"id":"2","name":"Dota PIT 2019 Minor","nameShortened":"Dota PIT 2019 Minor","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0QLC1oLCw==","node":{"id":"3","name":"HotShot Series Season 2","nameShortened":"HotShot Series S2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0MLC1oLCw==","node":{"id":"4","name":"Blast Pro Series Miami 2019","nameShortened":"Blast Pro Miami 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ILC1oLCw==","node":{"id":"5","name":"Blast Pro Series Madrid 2019","nameShortened":"BP Madrid 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ELC1oLCw==","node":{"id":"6","name":"ECS Season 7","nameShortened":"ECS Season 7","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ALC1oLCw==","node":{"id":"7","name":"HotShot Series Season 3","nameShortened":"HotShot Season 3","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC08LC1oLCw==","node":{"id":"8","name":"StarLadder ImbaTV Dota 2 Minor Season 2","nameShortened":"StarLadder Minor S2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC04LC1oLCw==","node":{"id":"9","name":"StarLadder ImbaTV Dota 2 Minor Season 2 Finals","nameShortened":"StarLadder S2 Finals","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZHCwtaCws=","node":{"id":"10","name":"Blast Pro Series Los Angeles 2019","nameShortened":"BP Los Angeles 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZGCwtaCws=","node":{"id":"11","name":"Good Game League 2019","nameShortened":"GG League 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZFCwtaCws=","node":{"id":"12","name":"StarLadder Minor CS:GO","nameShortened":"SLTV CS:GO","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZECwtaCws=","node":{"id":"13","name":"Unknown","nameShortened":"UNKNOWN","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZDCwtaCws=","node":{"id":"14","name":"Loot.bet/dota Season 1 2019","nameShortened":"Loot.bet/dota","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZCCwtaCws=","node":{"id":"15","name":"CS.MONEY Asian Emperor","nameShortened":"CS.MONEY","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZBCwtaCws=","node":{"id":"16","name":"LOOT.BET/CS SEASON 3","nameShortened":"LOOT.BET/CS S3","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZACwtaCws=","node":{"id":"17","name":"CIS Esports Pro Championship","nameShortened":"CIS Esports Pro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZOCwtaCws=","node":{"id":"19","name":"Blast Pro Moscow Closed Qualifier","nameShortened":"BP Moscow CQ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VFCwtaCws=","node":{"id":"22","name":"ECS Season 8","nameShortened":"ECS S8","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VECwtaCws=","node":{"id":"23","name":"Star Laddar Berlin Major 2019","na ...
# 2024-11-06 14:44:56,662 - INFO - Processed page 1 - Got 50 items
# 2024-11-06 14:44:58,047 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0FBCwtaCws="}}
# 2024-11-06 14:44:58,712 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RFQ04LC1oLCw=="},"edges":[{"cursor":"PjMLC1oLC0FACwtaCws=","node":{"id":"67","name":"LOOT.BET Season 5","nameShortened":"LOOT.BET Season 5","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0FPCwtaCws=","node":{"id":"68","name":"WESG 2019 East Europe Closed Qualifier","nameShortened":"WESG 2019 East Europ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0FOCwtaCws=","node":{"id":"69","name":"ESL Brazil Premier League Season 11","nameShortened":"ESL Brazil Premier L","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BHCwtaCws=","node":{"id":"70","name":"ESEA Advanced Season 32 North America","nameShortened":"ESEA Advanced Season","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BGCwtaCws=","node":{"id":"71","name":"ESL Pro League Season 10 Finals","nameShortened":"ESL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BFCwtaCws=","node":{"id":"72","name":"ESEA MDL Season 32 Europe Climber Cup","nameShortened":"ESEA MDL Season 32 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BECwtaCws=","node":{"id":"73","name":"IEM Katowice 2020 Oceania Open Qualifier #1","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BDCwtaCws=","node":{"id":"74","name":"ESEA Open Season 32 Brazil","nameShortened":"ESEA Open Season 32 ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BCCwtaCws=","node":{"id":"75","name":"ESEA Open Season 32 South Africa","nameShortened":"ESEA Open Season 32 ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BBCwtaCws=","node":{"id":"76","name":"POWER Ligaen Season 12","nameShortened":"POWER Ligaen Season ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BACwtaCws=","node":{"id":"77","name":"SECTOR: MOSTBET","nameShortened":"SECTOR: MOSTBET","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BPCwtaCws=","node":{"id":"78","name":"Hainan Supreme Cup ","nameShortened":"Hainan Supreme Cup ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BOCwtaCws=","node":{"id":"79","name":"WESG 2019 North Europe Closed Qualifier","nameShortened":"WESG 2019 North Euro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09HCwtaCws=","node":{"id":"80","name":"Svenska Elitserien Fall 2019","nameShortened":"Svenska Elitserien F","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09GCwtaCws=","node":{"id":"81","name":"Conquerors Insignia 2019","nameShortened":"Conquerors Insignia ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09FCwtaCws=","node":{"id":"82","name":"IEM Katowice 2020 Oceania Open Qualifier #2","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09ECwtaCws=","node":{"id":"83","name":"WESG 2019 APAC Oceania Qualifier","nameShortened":"WESG 2019 APAC Ocean","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09DCwtaCws=","node":{"id":"84","name":"DreamHack Delhi Invitational 2019","nameShortened":"DreamHack Delhi Invi","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09CCwtaCws=","node":{"id":"8 ...
# 2024-11-06 14:44:58,713 - INFO - Processed page 2 - Got 50 items
# 2024-11-06 14:45:01,057 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RFQ04LC1oLCw=="}}
# 2024-11-06 14:45:01,811 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VAQE5FCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RATkALC1oLCw==","node":{"id":"3797","name":"IEM Katowice 2020 North America Open Qualifier 1","nameShortened":"IEM Katowice 2020 No","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZDRUJGCwtaCws=","node":{"id":"14251","name":"NEST Pro 2019 Female","nameShortened":"NEST Pro 2019 Female","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZOR05BCwtaCws=","node":{"id":"19096","name":"IEM Katowice 2020 North America Open Qualifier 2","nameShortened":"IEM Katowice 2020 No","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VERUVCCwtaCws=","node":{"id":"23225","name":"ESL Meisterschaft Winter 2019 Finals","nameShortened":"ESL Meisterschaft Wi","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VEQU9CCwtaCws=","node":{"id":"23685","name":"ESEA MDL Season 32 Global Challenge","nameShortened":"ESEA MDL Season 32 G","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCRUBGCwtaCws=","node":{"id":"25271","name":"NCS Grand Finals 2019 @ Fragadelphia 14","nameShortened":"NCS Grand Finals 201","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCQ0ZFCwtaCws=","node":{"id":"25412","name":"EPICENTER 2019","nameShortened":"EPICENTER 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCQUZECwtaCws=","node":{"id":"25613","name":"ESL Nationals CZSK Season 2 Finals","nameShortened":"ESL Nationals CZSK S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBR0BDCwtaCws=","node":{"id":"26074","name":"Dragon Spirit Cup 2019","nameShortened":"Dragon Spirit Cup 20","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBT0dDCwtaCws=","node":{"id":"26804","name":"Grosvenor CS:GO Championship Season 3","nameShortened":"Grosvenor CS:GO Cham","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBTkNDCwtaCws=","node":{"id":"26944","name":"Swiss Esports League Fall Season 2019 Finals","nameShortened":"Swiss Esports League","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJDCwtaCws=","node":{"id":"27754","name":"Champions Cup Finals","nameShortened":"Champions Cup Finals","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJCCwtaCws=","node":{"id":"27755","name":"Brasileirão Season 1","nameShortened":"Brasileirão Season ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJBCwtaCws=","node":{"id":"27756","name":"RES Season 1","nameShortened":"RES Season 1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJACwtaCws=","node":{"id":"27757","name":"99Damage League Season 13","nameShortened":"99Damage League Seas","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"},{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAQEJPCwtaCws=","node":{"id":"27758","name":"Aorus League 2019 #4 Finals","nameShortened":"Aorus League 2019 #4","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJOCwtaCws=","node":{"id":"27759","name":"RES Season 1 Finals","nameShortened":"RES Season 1 Finals","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEFHCwtaCws=","node":{"id":"27760","name":"Asian DOTA2 Gold Occupation Competition S9","nameSh ...
# 2024-11-06 14:45:01,812 - INFO - Processed page 3 - Got 50 items
# 2024-11-06 14:45:04,060 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VAQE5FCwtaCws="}}
# 2024-11-06 14:45:04,786 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VAT0NPCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VAQE5ECwtaCws=","node":{"id":"27793","name":"Aorus League 2019 #4 Northern Cone","nameShortened":"Aorus League 2019 #4","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5DCwtaCws=","node":{"id":"27794","name":"IEM Katowice 2020 Europe Closed Qualifier","nameShortened":"IEM Katowice 2020 Eu","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5CCwtaCws=","node":{"id":"27795","name":"WINNERS League Season 3 Europe","nameShortened":"WINNERS League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5BCwtaCws=","node":{"id":"27796","name":"Hot Price League","nameShortened":"Hot Price League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAQE5PCwtaCws=","node":{"id":"27798","name":"DreamHack Open Leipzig 2020 Europe Open Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5OCwtaCws=","node":{"id":"27799","name":"OMG BET Cup 2","nameShortened":"OMG BET Cup 2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0dHCwtaCws=","node":{"id":"27800","name":"WINNERS League Season 3 North America","nameShortened":"WINNERS League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dGCwtaCws=","node":{"id":"27801","name":"DreamHack Open Leipzig 2020 North America Open Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dFCwtaCws=","node":{"id":"27802","name":"WESG 2019 Brazil Open Qualifier","nameShortened":"WESG 2019 Brazil Ope","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dECwtaCws=","node":{"id":"27803","name":"DreamHack Open Leipzig 2020 Europe Closed Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dDCwtaCws=","node":{"id":"27804","name":"WESG 2019 Brazil","nameShortened":"WESG 2019 Brazil","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dCCwtaCws=","node":{"id":"27805","name":"DreamHack Open Leipzig 2020 North America Closed Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dBCwtaCws=","node":{"id":"27806","name":"ESEA MDL Season 33 Australia","nameShortened":"ESEA MDL Season 33 A","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dACwtaCws=","node":{"id":"27807","name":"FACEIT Pro League","nameShortened":"FPL","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dPCwtaCws=","node":{"id":"27808","name":"Great Universe Cup","nameShortened":"Great Universe Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dOCwtaCws=","node":{"id":"27809","name":"LEGENDS.bet L33T Cup","nameShortened":"LEGENDS.bet L33T Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0ZHCwtaCws=","node":{"id":"27810","name":"IEM Katowice 2020 Oceania Closed Qualifier","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0ZGCwtaCws=","node":{"id":"27811","name":"Masters Tournament Season 4","nameShortened":"Masters Tournament S","pr ...
# 2024-11-06 14:45:04,787 - INFO - Processed page 4 - Got 50 items
# 2024-11-06 14:45:07,064 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VAT0NPCwtaCws="}}
# 2024-11-06 14:45:07,723 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VPR0NGCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VAT0NOCwtaCws=","node":{"id":"27849","name":"Americas Minor North America Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Americas Minor North","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JHCwtaCws=","node":{"id":"27850","name":"Asia Minor Greater China Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Asia Minor Greater C","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JGCwtaCws=","node":{"id":"27851","name":"Asia Minor SEA Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Asia Minor SEA Open ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JFCwtaCws=","node":{"id":"27852","name":"Supreme Masters European Invitational 2020","nameShortened":"Supreme Masters Euro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JDCwtaCws=","node":{"id":"27854","name":"ESEA MDL Season 33 North America","nameShortened":"ESEA MDL Season 33 N","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JCCwtaCws=","node":{"id":"27855","name":"Asia Challenger League Season 6","nameShortened":"Asia Challenger Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0JBCwtaCws=","node":{"id":"27856","name":"Asia Minor SEA Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Asia Minor SEA Open ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JACwtaCws=","node":{"id":"27857","name":"ESEA MDL Season 33 Europe","nameShortened":"ESEA MDL Season 33 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JPCwtaCws=","node":{"id":"27858","name":"CIS Minor Open Qualifier 1 - ESL One Rio 2020","nameShortened":"CIS Minor Open Quali","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JOCwtaCws=","node":{"id":"27859","name":"Americas Minor South America Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Americas Minor South","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0FHCwtaCws=","node":{"id":"27860","name":"Brazilian Dota 2 Championships Season 2","nameShortened":"Brazilian Dota 2 Cha","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0FGCwtaCws=","node":{"id":"27861","name":"Red Star Cup Season 3","nameShortened":"Red Star Cup Season ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VATk5PCwtaCws=","node":{"id":"27998","name":"Europe Minor Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Europe Minor Open Qu","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VATk5OCwtaCws=","node":{"id":"27999","name":"Americas Minor North America Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Americas Minor North","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dHCwtaCws=","node":{"id":"28000","name":"Vietnam Pro League Season 3","nameShortened":"Vietnam Pro League S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dFCwtaCws=","node":{"id":"28002","name":"WESG 2019 Russia Closed Qualifier","nameShortened":"WESG 2019 Russia Clo","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dECwtaCws=","node":{"id":"28003","name":"CIS Minor Open Qualifier 2 - ESL One Rio 2020","nameShortened":"CIS Minor Open Quali","private" ...
# 2024-11-06 14:45:07,724 - INFO - Processed page 5 - Got 50 items
# 2024-11-06 14:45:10,071 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VPR0NGCwtaCws="}}
# 2024-11-06 14:45:10,766 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VPRkdECwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VPR0NFCwtaCws=","node":{"id":"28042","name":"WePlay! Dota2 Tug of War: Mad Moon","nameShortened":"WePlay! Dota2 Tug of","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NECwtaCws=","node":{"id":"28043","name":"CBDota - Brazilian Dota 2 Championships 2020","nameShortened":"CBDota - Brazilian D","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NDCwtaCws=","node":{"id":"28044","name":"Epic League Season 1","nameShortened":"Epic League Season 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NCCwtaCws=","node":{"id":"28045","name":"Hainan Master Spring Invitational","nameShortened":"Hainan Master Spring","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NBCwtaCws=","node":{"id":"28046","name":"GIRLGAMER World Finals 2020","nameShortened":"GIRLGAMER World Fina","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NACwtaCws=","node":{"id":"28047","name":"IEM Katowice 2020","nameShortened":"IEM Katowice 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NPCwtaCws=","node":{"id":"28048","name":"epic29","nameShortened":"epic29","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NOCwtaCws=","node":{"id":"28049","name":"Samsung GOEXANIMO CS:GO 5X5 #20","nameShortened":"Samsung GOEXANIMO CS","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JHCwtaCws=","node":{"id":"28050","name":"SIGUL Pro League","nameShortened":"SIGUL Pro League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JGCwtaCws=","node":{"id":"28051","name":"Elite Challenge Season 3","nameShortened":"Elite Challenge Seas","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JFCwtaCws=","node":{"id":"28052","name":"BashFest 2020","nameShortened":"BashFest 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JECwtaCws=","node":{"id":"28053","name":"Maxline Winter Madness","nameShortened":"Maxline Winter Madne","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JDCwtaCws=","node":{"id":"28054","name":"EGB Arena of Blood: Closed Qualifier","nameShortened":"EGB Arena of Blood: ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JCCwtaCws=","node":{"id":"28055","name":"LPL Pro Season 1","nameShortened":"LPL Pro Season 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JBCwtaCws=","node":{"id":"28056","name":"LanTrek 2020","nameShortened":"LanTrek 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JACwtaCws=","node":{"id":"28057","name":"Aorus League 2020 #1 Southern Cone","nameShortened":"Aorus League 2020 #1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JPCwtaCws=","node":{"id":"28058","name":"WESG 2019 Russia Finals","nameShortened":"WESG 2019 Russia Fin","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JOCwtaCws=","node":{"id":"28059","name":"LPL Pro League Season 4","nameShortened":"LPL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0FHCwtaCws=","node":{"id":"28060","name":"Masters Tournament Season 5 Group Stage","nameShortened":"Maste ...
# 2024-11-06 14:45:10,767 - INFO - Processed page 6 - Got 50 items
# 2024-11-06 14:45:13,080 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VPRkdECwtaCws="}}
# 2024-11-06 14:45:13,811 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RHT0VECwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VPRkdDCwtaCws=","node":{"id":"28104","name":"Asian Hero League Season 2","nameShortened":"Asian Hero League Se","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdCCwtaCws=","node":{"id":"28105","name":"Red Star Cup Season 4","nameShortened":"Red Star Cup Season ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdBCwtaCws=","node":{"id":"28106","name":"SECTOR: MOSTBET 2","nameShortened":"SECTOR: MOSTBET 2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkdACwtaCws=","node":{"id":"28107","name":"Flashpoint 1","nameShortened":"Flashpoint 1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkdPCwtaCws=","node":{"id":"28108","name":"Arena of Blood","nameShortened":"Arena of Blood","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdOCwtaCws=","node":{"id":"28109","name":"ESL Pro League Season 11","nameShortened":"ESL Pro League S11","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZHCwtaCws=","node":{"id":"28110","name":"ESL Pro League Season 11 Europe","nameShortened":"ESL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZGCwtaCws=","node":{"id":"28111","name":"eFire Master League Season 1 North America","nameShortened":"eFire Master League ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZFCwtaCws=","node":{"id":"28112","name":"ESL Australia & NZ Championship Season 10 Qualifier 3","nameShortened":"ESL Australia & NZ C","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZECwtaCws=","node":{"id":"28113","name":"GGBET Championship 2","nameShortened":"GGBET Championship 2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkZDCwtaCws=","node":{"id":"28114","name":"HardCup 6","nameShortened":"HardCup 6","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZCCwtaCws=","node":{"id":"28115","name":"SECTOR: MOSTBET Season 2","nameShortened":"SECTOR: MOSTBET Seas","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZBCwtaCws=","node":{"id":"28116","name":"META '20 Open","nameShortened":"META '20 Open","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZACwtaCws=","node":{"id":"28117","name":"eFire Master League North America","nameShortened":"eFire Master League ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZPCwtaCws=","node":{"id":"28118","name":"No Major No Problem","nameShortened":"No Major No Problem","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkZOCwtaCws=","node":{"id":"28119","name":"ESEA Advanced Season 33 Europe","nameShortened":"ESEA Advanced Season","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkVGCwtaCws=","node":{"id":"28121","name":"China Development League Season 2: Promotion","nameShortened":"China Dev League 2 Promotion","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkVFCwtaCws=","node":{"id":"28122","name":"WeSave! Charity Play","nameShortened":"WeSave! Charity Play","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPQEZGCwtaCws=","node":{"id":"28711","name":"Maxline League Sea ...
# 2024-11-06 14:45:13,812 - INFO - Processed page 7 - Got 50 items
# 2024-11-06 14:45:16,091 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RHT0VECwtaCws="}}
# 2024-11-06 14:45:16,791 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RHT0BBCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RHT0VDCwtaCws=","node":{"id":"30824","name":"Spring Championship","nameShortened":"Spring Championship","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VCCwtaCws=","node":{"id":"30825","name":"SECTOR DOTA 2 Season 2","nameShortened":"SECTOR DOTA 2 Season","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VACwtaCws=","node":{"id":"30827","name":"ESL One: Road To Rio - Europe","nameShortened":"ESL One: Road to Rio 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0VPCwtaCws=","node":{"id":"30828","name":"Saturnbet Spring Championship","nameShortened":"Saturnbet Spring Cha","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VOCwtaCws=","node":{"id":"30829","name":"Hot Price League Season 3","nameShortened":"Hot Price League Sea","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RHCwtaCws=","node":{"id":"30830","name":"BTS Pro Series","nameShortened":"BTS Pro Series","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RGCwtaCws=","node":{"id":"30831","name":"ESEA MDL Season 33 Europe Relegation","nameShortened":"ESEA MDL Season 33 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RFCwtaCws=","node":{"id":"30832","name":"Oceanic Esports League","nameShortened":"Oceanic Esports Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RECwtaCws=","node":{"id":"30833","name":"Play From Home","nameShortened":"Play From Home","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RDCwtaCws=","node":{"id":"30834","name":"Home Sweet Home Cup 2","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RCCwtaCws=","node":{"id":"30835","name":"Asian Hero League Season 3","nameShortened":"Asian Hero League Se","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RACwtaCws=","node":{"id":"30837","name":"Home Sweet Home Cup 3","nameShortened":"Home Sweet Home Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RPCwtaCws=","node":{"id":"30838","name":"Home Sweet Home Cup 4","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0ROCwtaCws=","node":{"id":"30839","name":"Home Sweet Home Cup 5","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NHCwtaCws=","node":{"id":"30840","name":"Home Sweet Home Cup 6","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NGCwtaCws=","node":{"id":"30841","name":"Home Sweet Home Cup 7","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NFCwtaCws=","node":{"id":"30842","name":"Home Sweet Home Cup 8","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NECwtaCws=","node":{"id":"30843","name":"ESL One: Road to Rio - CIS Play-in","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NDCwtaCws=","node":{"id":"30844","name":"ESL One: Road to Rio - South Ame ...
# 2024-11-06 14:45:16,793 - INFO - Processed page 8 - Got 50 items
# 2024-11-06 14:45:19,129 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RHT0BBCwtaCws="}}
# 2024-11-06 14:45:19,833 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RGRERPCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RHT0BPCwtaCws=","node":{"id":"30878","name":"Dota 2 BEAT Invitational Season 9","nameShortened":"Dota 2 BEAT Invitati","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0BOCwtaCws=","node":{"id":"30879","name":"Betano Masters","nameShortened":"Betano Masters","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09HCwtaCws=","node":{"id":"30880","name":"Hephaestus Cup","nameShortened":"Hephaestus Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09GCwtaCws=","node":{"id":"30881","name":"Isolation Cup","nameShortened":"Isolation Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09FCwtaCws=","node":{"id":"30882","name":"ESEA MDL Season 34 Europe","nameShortened":"ESEA MDL Season 34 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09ECwtaCws=","node":{"id":"30883","name":"ESEA MDL Season 34 North America","nameShortened":"ESEA MDL Season 34 N","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09DCwtaCws=","node":{"id":"30884","name":"Elisa Invitational 2020","nameShortened":"Elisa Invitational 2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09CCwtaCws=","node":{"id":"30885","name":"ESL One: Road to Rio - CIS","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09ACwtaCws=","node":{"id":"30887","name":"ESEA MDL Season 34 Australia","nameShortened":"ESEA MDL Season 34 A","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09PCwtaCws=","node":{"id":"30888","name":"Vulcan Champion League","nameShortened":"Vulcan Champion Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09OCwtaCws=","node":{"id":"30889","name":"Realms Collide","nameShortened":"Realms Collide","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05HCwtaCws=","node":{"id":"30890","name":"RDY Cup","nameShortened":"RDY Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05GCwtaCws=","node":{"id":"30891","name":"Betway CS:GO Asia Masters","nameShortened":"Betway CS:GO Asia Masters","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05FCwtaCws=","node":{"id":"30892","name":"OGA Dota PIT 2020 Online","nameShortened":"OGA Dota PIT 2020 On","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05ECwtaCws=","node":{"id":"30893","name":"SEA Dota Invitational 2020","nameShortened":"SEA Dota Invitationa","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05DCwtaCws=","node":{"id":"30894","name":"Dota2 Secondary Professional League 2020","nameShortened":"Dota2 Secondary Prof","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05CCwtaCws=","node":{"id":"30895","name":"HellCase Cup","nameShortened":"HellCase","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05ACwtaCws=","node":{"id":"30897","name":"FVBet Showmatch","nameShortened":"FVBet Showmatch","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05PCwtaCws=","node":{"id":"30898","name":"ESL One: Road to Rio - Oceania","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","nam ...
# 2024-11-06 14:45:19,834 - INFO - Processed page 9 - Got 50 items
# 2024-11-06 14:45:22,105 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RGRERPCwtaCws="}}
# ...
# 2024-11-06 14:48:50,494 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0BAQ0BCRwsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BBRkNPTgsLWgsL","node":{"id":"761489","name":"ESL Challenger at DreamHack Summer 2024: Asian Closed Qualifier","nameShortened":"ESL Challenger at Dr","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkNOQwsLWgsL","node":{"id":"761494","name":"ESL Challenger at DreamHack Summer 2024: European Closed Qualifier","nameShortened":"ESL Challenger at Dr","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkNOQgsLWgsL","node":{"id":"761495","name":"ESL Challenger at DreamHack Summer 2024: North American Closed Qualifier","nameShortened":"ESL Challenger at Dr","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkNOQQsLWgsL","node":{"id":"761496","name":"Insomnia 72","nameShortened":"Insomnia 72","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJHTwsLWgsL","node":{"id":"761508","name":"BetBoom Dacha Belgrade 2024: European Qualifier","nameShortened":"BetBoom Dacha Belgra","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJHTgsLWgsL","node":{"id":"761509","name":"European Pro League Season 15 - CS2","nameShortened":"European Pro League Season 15","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGRwsLWgsL","node":{"id":"761510","name":"European Pro League Season 17: Division 1 - Dota 2","nameShortened":"European Pro League S17 D1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGRAsLWgsL","node":{"id":"761513","name":"RES Regional Series: SEA #2","nameShortened":"RES Regional Series:","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGQwsLWgsL","node":{"id":"761514","name":"Esportal LuckyCasino Cup 2024","nameShortened":"Esportal LuckyCasino","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGTwsLWgsL","node":{"id":"761518","name":"Minotaur League","nameShortened":"Minotaur League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGTgsLWgsL","node":{"id":"761519","name":"Intel Extreme Masters Chengdu 2024","nameShortened":"Intel Extreme Master","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFRgsLWgsL","node":{"id":"761521","name":"RES Latin American Series #3","nameShortened":"RES Latin American S","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFRQsLWgsL","node":{"id":"761522","name":"Skyesports Masters 2024","nameShortened":"Skyesports Masters 2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQwsLWgsL","node":{"id":"761524","name":"IeSF World Championship 2024 Turkmenistan Qualifier","nameShortened":"IeSF World Champions","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQgsLWgsL","node":{"id":"761525","name":"Tradeit League FE Masters #2","nameShortened":"Tradeit League FE Ma","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQQsLWgsL","node":{"id":"761526","name":"European Pro League Female Season 1","nameShortened":"European Pro League ","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQAsLWgsL","node":{"id":"761527","name":"Impacto Solar 3: Open Qualifier #1","nameShortened":"Impacto Solar 3: Ope","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRk5PQgsLWgsL","node":{"id":"761985","name":"ESL Impact Cash Cup: North America - Spring 2024 #7","nameShortened":"ESL Impact Cash Cup:","private":false,"titles":[{"id":"28" ...
# 2024-11-06 14:48:50,495 - INFO - Processed page 79 - Got 50 items
# 2024-11-06 14:48:52,745 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0BAQ0BCRwsLWgsL"}}
# 2024-11-06 14:48:53,456 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0BAQkdPRQsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BAQ0BCRgsLWgsL","node":{"id":"774751","name":"Elite League Season 2: Southeast Asia Closed Qualifier","nameShortened":"Elite League Season 2: SE Asia","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BAQ0BCRQsLWgsL","node":{"id":"774752","name":"Elite League Season 2: Western Europe Closed Qualifier","nameShortened":"Elite League Season 2: WEU CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BCRAsLWgsL","node":{"id":"774753","name":"Gamers Club Liga Série A: May 2024 (Playoffs only)","nameShortened":"Gamers Club Liga S A: May24 P","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BAQ0BCQwsLWgsL","node":{"id":"774754","name":"Elite League Season 2: China Closed Qualifier","nameShortened":"Elite League Season 2: CN CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BCQgsLWgsL","node":{"id":"774755","name":"Elite League Season 2: Eastern Europe Closed Qualifier","nameShortened":"Elite League Season 2: EEU CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BCQQsLWgsL","node":{"id":"774756","name":"Gamers Club Liga Série A: May 2024 (Playoffs)","nameShortened":"Liga Série A: May 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BBTgsLWgsL","node":{"id":"774769","name":"MESA Nomadic Masters Spring 2024","nameShortened":"MESA Spring 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BPRgsLWgsL","node":{"id":"774781","name":"Thunderpick World Championship 2024 - WILDCARD Qualifier","nameShortened":"Thunderpick WC - WQ","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BPTwsLWgsL","node":{"id":"774788","name":"Champion of Champions Tour Season 2 - Europe Series 6","nameShortened":"CCT S2 - EU Series 6","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09HRQsLWgsL","node":{"id":"774802","name":"Circuito Retake Season 8: Take #3","nameShortened":"Circuito Retake S8: Take #3","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09HRAsLWgsL","node":{"id":"774803","name":"Circuito Retake Season 8: Playoffs","nameShortened":"Circuito Retake S8: Playoffs","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09CRAsLWgsL","node":{"id":"774853","name":"YaLLa Compass 2024","nameShortened":"YaLLa Compass 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09ATgsLWgsL","node":{"id":"774879","name":"Elite League Season 2: Southeast Asia Closed Qualifier","nameShortened":"Elite League S2: SEA CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ09OQQsLWgsL","node":{"id":"774896","name":"Champion of Champions Tour Dota 2 Series 1","nameShortened":"CCT Dota 2 Series 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ09OQAsLWgsL","node":{"id":"774897","name":"FiReLEAGUE Global Finals","nameShortened":"FiReLEAGUE Global Finals","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09OTwsLWgsL","node":{"id":"774898","name":"United21 South America Season 1","nameShortened":"United21 SA S1","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ05HQAsLWgsL","node":{"id":"774907","name":"European Pro League Season 19: Division 2 - Dota 2","nameShortened":"EPL Season 19 D2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ05 ...
# 2024-11-06 14:48:53,457 - INFO - Processed page 80 - Got 50 items
# 2024-11-06 14:48:55,751 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0BAQkdPRQsLWgsL"}}
# 2024-11-06 14:48:56,636 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0BAQkNGQQsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BAQkdPRAsLWgsL","node":{"id":"775083","name":"Thunderpick World Championship 2024 - EU Qualifier #2","nameShortened":"Thunderpick WC 2024 - EU Q2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkdPQwsLWgsL","node":{"id":"775084","name":"Champion of Champions Tour Dota 2 Series 3","nameShortened":"CCT Dota 2 Series 3","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkdOTwsLWgsL","node":{"id":"775098","name":"EPL World Series: America Season 13 - Dota 2","nameShortened":"EPL World Series: America S13","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkZGTwsLWgsL","node":{"id":"775118","name":"Prodigy Series #1","nameShortened":"Prodigy Series #1","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZFRgsLWgsL","node":{"id":"775121","name":"European Pro League Season 18","nameShortened":"EPL Season 18","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZFQQsLWgsL","node":{"id":"775126","name":"Champion of Champions Tour Season 2 - North America Series 3","nameShortened":"CCT S2 - NA Series 3","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZFQAsLWgsL","node":{"id":"775127","name":"Champion of Champions Tour Season 2 - Europe Series 12","nameShortened":"CCT S2 - EU Series 12","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZEQgsLWgsL","node":{"id":"775135","name":"Prodigy Series #2","nameShortened":"Prodigy Series #2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZCRgsLWgsL","node":{"id":"775151","name":"Gamers Club Liga Série A: August 2024","nameShortened":"Gamers Club Liga S-A August 24","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZCQgsLWgsL","node":{"id":"775155","name":"United21 Season 19","nameShortened":"United21 Season 19","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZCTwsLWgsL","node":{"id":"775158","name":"European Pro League Season 20: Division 2 - CS2 (OLD)","nameShortened":"EPL S20: Division 2 CS2 (OLD)","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BAQkZBRwsLWgsL","node":{"id":"775160","name":"European Pro League Season 20: Division 2 - CS2","nameShortened":"EPL S20 Division 2 - CS2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZARwsLWgsL","node":{"id":"775170","name":"Fragicago '24","nameShortened":"Fragicago '24","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZARgsLWgsL","node":{"id":"775171","name":"Champion of Champions Tour Season 2 - Europe Series 13","nameShortened":"CCT Europe S2 Series 13","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZARAsLWgsL","node":{"id":"775173","name":"Champion of Champions Tour Season 2 - Europe Series 14","nameShortened":"CCT Europe S2 Series 14","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZAQgsLWgsL","node":{"id":"775175","name":"Ljósleiðara deildin 2024","nameShortened":"Ljósleiðara deildin 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZORgsLWgsL","node":{"id":"775191","name":"Galaxy Battle #1","nameShortened":"Galaxy Battle #1","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkVHRQsLWgsL","node":{"id":"775202","name":"A1 Gaming League S9","nameShortened":"A1 Gaming League S9","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cur ...
# 2024-11-06 14:48:56,637 - INFO - Processed page 81 - Got 50 items
# 2024-11-06 14:48:58,761 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0BAQkNGQQsLWgsL"}}
# 2024-11-06 14:48:59,440 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":false,"endCursor":"PjMLC1oLC0BAQkNFQwsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BAQkNGQAsLWgsL","node":{"id":"775417","name":"Perfect World Shanghai Major 2024: Asia-Pacific RMR","nameShortened":"Asia-Pacific RMR","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkNFRQsLWgsL","node":{"id":"775422","name":"Summoner's Cup","nameShortened":"Summoner's Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkNFRAsLWgsL","node":{"id":"775423","name":"Champion of Champions Tour Dota 2 Series 5","nameShortened":"CCT Dota 2 Series 5","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkNFQwsLWgsL","node":{"id":"775424","name":"Champion of Champions Tour Season 2 - Europe Series 15","nameShortened":"CCT Europe S2 Series 15","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}}],"totalCount":4054}}}
# 2024-11-06 14:48:59,441 - INFO - Processed page 82 - Got 4 items
# Collected 4054 tournaments
#
# Sample data:
#   id                             name            name_short start_date  \
# 0  1  United Masters League 2018-2019              UML 1819        NaT
# 1  2              Dota PIT 2019 Minor   Dota PIT 2019 Minor        NaT
# 2  3          HotShot Series Season 2     HotShot Series S2        NaT
# 3  4      Blast Pro Series Miami 2019  Blast Pro Miami 2019        NaT
# 4  5     Blast Pro Series Madrid 2019        BP Madrid 2019        NaT
#
#   end_date  private title_ids                         title_names
# 0      NaT    False       [1]  [Counter Strike: Global Offensive]
# 1      NaT    False       [2]         [Defense of the Ancients 2]
# 2      NaT    False       [1]  [Counter Strike: Global Offensive]
# 3      NaT    False       [1]  [Counter Strike: Global Offensive]
# 4      NaT    False       [1]  [Counter Strike: Global Offensive]

# %%
# Collect Match Data
try:
    logging.info("Collecting match data...")
    #ONLY CHANGE THE NUMBER OF DAYS BELOW PLEASE!!!
    matches_df = collector.get_matches(days=7) # Change days to collect more matches
    logging.info(f"Collected {len(matches_df)} matches")
    
    # Basic match analysis
    print("\nMatch Statistics:")
    print(f"Total matches collected: {len(matches_df)}")
    
    print(f"\nMatches by tournament:")
    print(matches_df['tournament_name'].value_counts())
    
    print(f"\nMatches by format:")
    print(matches_df['format_name'].value_counts())
    
    # Display sample of recent matches with key information
    print("\nRecent Matches Sample:")
    display_columns = [
        'id', 'tournament_name', 'team1_name', 'team2_name', 
        'format_short', 'start_time'
    ]
    print(matches_df[display_columns].head())
    
except Exception as e:
    logging.error(f"Error collecting match data: {str(e)}")
    raise
# Out:
# 2024-11-06 14:48:59,482 - INFO - Collecting match data...
# 2024-11-06 14:48:59,482 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\matches.graphql
# 2024-11-06 14:49:01,766 - INFO - >>> {"query": "query GetRecentMatches($first: Int!, $after: Cursor) {\n  allSeries(\n    first: $first\n    after: $after\n    filter: {startTimeScheduled: {gte: \"2024-10-30T14:00:00+00:00\", lte: \"2024-11-06T14:00:00+00:00\"}}\n    orderBy: StartTimeScheduled\n  ) {\n    totalCount\n    edges {\n      cursor\n      node {\n        id\n        title {\n          nameShortened\n        }\n        tournament {\n          nameShortened\n        }\n        startTimeScheduled\n        format {\n          name\n          nameShortened\n        }\n        teams {\n          baseInfo {\n            id\n            name\n          }\n          scoreAdvantage\n        }\n      }\n    }\n    pageInfo {\n      hasPreviousPage\n      hasNextPage\n      startCursor\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": null}}
# 2024-11-06 14:49:02,709 - INFO - <<< {"data":{"allSeries":{"totalCount":111,"edges":[{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ0BCCwtaCwtFR0VDWkZHWkRHI0ZDTURHTUdHLQ==","node":{"id":"2732475","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-10-30T14:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53919","name":"LA CHAMPIONS LIGA"},"scoreAdvantage":0},{"baseInfo":{"id":"51295","name":"Yawara Esports"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkJACwtaCwtFR0VDWkZHWkRHI0ZDTUNHTUdHLQ==","node":{"id":"2738557","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Oct 2024 CS2"},"startTimeScheduled":"2024-10-30T14:40:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0},{"baseInfo":{"id":"51651","name":"Gameinside"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQ0BCCwtaCwtFR0VDWkZHWkRHI0ZCTUdHTUdHLQ==","node":{"id":"2738475","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-10-30T15:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"52068","name":"Aurora YB"},"scoreAdvantage":0},{"baseInfo":{"id":"52233","name":"ECLOT"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ0BBCwtaCwtFR0VDWkZHWkRHI0ZATURCTUdHLQ==","node":{"id":"2732476","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-10-30T17:35:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51146","name":"MIBR Academy"},"scoreAdvantage":0},{"baseInfo":{"id":"54155","name":"Bestia Academy"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ0BACwtaCwtFR0VDWkZHWkRHI0VHTURHTUdHLQ==","node":{"id":"2732477","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-10-30T20:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"50714","name":"Sensei"},"scoreAdvantage":0},{"baseInfo":{"id":"52162","name":"BeBold.gg"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ0BPCwtaCwtFR0VDWkZHWkRHI0VETURHTUdHLQ==","node":{"id":"2732478","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-10-30T23:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53951","name":"Nitro"},"scoreAdvantage":0},{"baseInfo":{"id":"50948","name":"9z Academy"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkJPCwtaCwtFR0VDWkZHWkRGI0dBTUdHTUdHLQ==","node":{"id":"2738558","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Oct 2024 CS2"},"startTimeScheduled":"2024-10-31T06:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0},{"baseInfo":{"id":"51652","name":"Seight"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkJOCwtaCwtFR0VDWkZHWkRGI0dPTURHTUdHLQ==","node":{"id":"2738559","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Oct 2024 CS2"},"startTimeScheduled":"2024-10-31T08:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51652","name":"Seight"},"scoreAdvantage":0},{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQ0BACwtaCwtFR0VDWkZHWkRGI0dOTUdHTUdHLQ==","node":{"id":"2738477","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-10-31T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51542","name":"INSILIO"},"scoreAdvantage":0},{" ...
# 2024-11-06 14:49:02,710 - INFO - Processed page 1 - Got 50 items
# 2024-11-06 14:49:04,774 - INFO - >>> {"query": "query GetRecentMatches($first: Int!, $after: Cursor) {\n  allSeries(\n    first: $first\n    after: $after\n    filter: {startTimeScheduled: {gte: \"2024-10-30T14:00:00+00:00\", lte: \"2024-11-06T14:00:00+00:00\"}}\n    orderBy: StartTimeScheduled\n  ) {\n    totalCount\n    edges {\n      cursor\n      node {\n        id\n        title {\n          nameShortened\n        }\n        tournament {\n          nameShortened\n        }\n        startTimeScheduled\n        format {\n          name\n          nameShortened\n        }\n        teams {\n          baseInfo {\n            id\n            name\n          }\n          scoreAdvantage\n        }\n      }\n    }\n    pageInfo {\n      hasPreviousPage\n      hasNextPage\n      startCursor\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ05HCwtaCwtFR0VDWkZGWkdEI0dHTUZCTUdHLQ=="}}
# 2024-11-06 14:49:05,639 - INFO - <<< {"data":{"allSeries":{"totalCount":111,"edges":[{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHQUFPCwtaCwtFR0VDWkZGWkdEI0dGTUZCTUdHLQ==","node":{"id":"2740668","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"DBE 2024"},"startTimeScheduled":"2024-11-03T01:15:00Z","format":{"name":"best-of-1","nameShortened":"Bo1"},"teams":[{"baseInfo":{"id":"53389","name":"Galorys"},"scoreAdvantage":0},{"baseInfo":{"id":"54156","name":"America Esports"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRUBPCwtaCwtFR0VDWkZGWkdEI0dBTUZCTUdHLQ==","node":{"id":"2740278","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-03T06:15:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0},{"baseInfo":{"id":"51657","name":"REMBAZA"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRUBOCwtaCwtFR0VDWkZGWkdEI0dPTUJHTUdHLQ==","node":{"id":"2740279","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-03T08:50:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51657","name":"REMBAZA"},"scoreAdvantage":0},{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQ09ECwtaCwtFR0VDWkZGWkdEI0dOTUdHTUdHLQ==","node":{"id":"2738483","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-03T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51920","name":"SAMPI"},"scoreAdvantage":0},{"baseInfo":{"id":"51552","name":"Permitta"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERORUdOCwtaCwtFR0VDWkZGWkdEI0dOTUdHTUdHLQ==","node":{"id":"2739209","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"United21 Season 22"},"startTimeScheduled":"2024-11-03T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53692","name":"Copenhagen Wolves"},"scoreAdvantage":0},{"baseInfo":{"id":"51930","name":"Anonymo"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRU9HCwtaCwtFR0VDWkZGWkdEI0ZGTUdHTUdHLQ==","node":{"id":"2740280","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-03T11:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51658","name":"NightRaid"},"scoreAdvantage":0},{"baseInfo":{"id":"51651","name":"Gameinside"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkdPCwtaCwtFR0VDWkZGWkdEI0ZGTURHTUdHLQ==","node":{"id":"2738508","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-03T11:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53125","name":"GUN5"},"scoreAdvantage":0},{"baseInfo":{"id":"52233","name":"ECLOT"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERORUZHCwtaCwtFR0VDWkZGWkdEI0ZGTURHTUdHLQ==","node":{"id":"2739210","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"United21 Season 22"},"startTimeScheduled":"2024-11-03T11:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"49502","name":"ENCE Academy"},"scoreAdvantage":0},{"baseInfo":{"id":"49873","name":"Lilmix"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRkFACwtaCwtFR0VDWkZGWkdEI0ZFTURCTUdHLQ==","node":{"id":"2740167","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-03T12:35:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51651","name":"Gameinside"},"scoreAdvantage":0},{"baseInfo":{"id":"51658","name":"NightRai ...
# 2024-11-06 14:49:05,640 - INFO - Processed page 2 - Got 50 items
# 2024-11-06 14:49:07,785 - INFO - >>> {"query": "query GetRecentMatches($first: Int!, $after: Cursor) {\n  allSeries(\n    first: $first\n    after: $after\n    filter: {startTimeScheduled: {gte: \"2024-10-30T14:00:00+00:00\", lte: \"2024-11-06T14:00:00+00:00\"}}\n    orderBy: StartTimeScheduled\n  ) {\n    totalCount\n    edges {\n      cursor\n      node {\n        id\n        title {\n          nameShortened\n        }\n        tournament {\n          nameShortened\n        }\n        startTimeScheduled\n        format {\n          name\n          nameShortened\n        }\n        teams {\n          baseInfo {\n            id\n            name\n          }\n          scoreAdvantage\n        }\n      }\n    }\n    pageInfo {\n      hasPreviousPage\n      hasNextPage\n      startCursor\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ05OCwtaCwtFR0VDWkZGWkdCI0VFTURHTUdHLQ=="}}
# 2024-11-06 14:49:08,474 - INFO - <<< {"data":{"allSeries":{"totalCount":111,"edges":[{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHQUBBCwtaCwtFR0VDWkZGWkdCI0VETUdHTUdHLQ==","node":{"id":"2740676","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"DBE 2024"},"startTimeScheduled":"2024-11-05T23:00:00Z","format":{"name":"best-of-1","nameShortened":"Bo1"},"teams":[{"baseInfo":{"id":"54156","name":"America Esports"},"scoreAdvantage":0},{"baseInfo":{"id":"51791","name":"Solid"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHQU9FCwtaCwtFR0VDWkZGWkdBI0dHTUZCTUdHLQ==","node":{"id":"2740682","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"DBE 2024"},"startTimeScheduled":"2024-11-06T00:15:00Z","format":{"name":"best-of-1","nameShortened":"Bo1"},"teams":[{"baseInfo":{"id":"52177","name":"INTENSE GAME"},"scoreAdvantage":0},{"baseInfo":{"id":"49558","name":"Sharks"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHQU9ECwtaCwtFR0VDWkZGWkdBI0dGTUNHTUdHLQ==","node":{"id":"2740683","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"DBE 2024"},"startTimeScheduled":"2024-11-06T01:40:00Z","format":{"name":"best-of-1","nameShortened":"Bo1"},"teams":[{"baseInfo":{"id":"54157","name":"Galorys Academy"},"scoreAdvantage":0},{"baseInfo":{"id":"53712","name":"Vikings KR"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENFR0VPCwtaCwtFR0VDWkZGWkdBI0dATUZCTUdHLQ==","node":{"id":"2742028","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-06T07:15:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51652","name":"Seight"},"scoreAdvantage":0},{"baseInfo":{"id":"51651","name":"Gameinside"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENFR0RBCwtaCwtFR0VDWkZGWkdBI0dPTUJCTUdHLQ==","node":{"id":"2742036","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-06T08:55:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51651","name":"Gameinside"},"scoreAdvantage":0},{"baseInfo":{"id":"51652","name":"Seight"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQ09OCwtaCwtFR0VDWkZGWkdBI0dOTUdHTUdHLQ==","node":{"id":"2738489","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-06T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"49787","name":"SINNERS Esports"},"scoreAdvantage":0},{"baseInfo":{"id":"51552","name":"Permitta"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERORUZCCwtaCwtFR0VDWkZGWkdBI0dOTUdHTUdHLQ==","node":{"id":"2739215","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"United21 Season 22"},"startTimeScheduled":"2024-11-06T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"52133","name":"L&G"},"scoreAdvantage":0},{"baseInfo":{"id":"51536","name":"GenOne"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRU5FCwtaCwtFR0VDWkZGWkdBI0ZGTUdHTUdHLQ==","node":{"id":"2740292","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-06T11:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51658","name":"NightRaid"},"scoreAdvantage":0},{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkZDCwtaCwtFR0VDWkZGWkdBI0ZGTURHTUdHLQ==","node":{"id":"2738514","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-06T11:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"49865","name":"9INE"},"scoreAdvantage":0},{"baseInfo":{"id":"50069","name":"Into The Breach"},"scoreAdvantage":0}] ...
# 2024-11-06 14:49:08,475 - INFO - Processed page 3 - Got 11 items
# 2024-11-06 14:49:08,479 - INFO - Collected 111 matches
# Match Statistics:
# Total matches collected: 111
#
# Matches by tournament:
# tournament_name
# CCT S2 - South America S4       25
# Esports Battles Nov 2024 CS2    23
# DBE 2024                        16
# EPL S20 - CS2                   14
# United21 Season 22              14
# Esports Battles Oct 2024 CS2     5
# A1 Gaming League S9              4
# Thunderpick WC 2024 - Finals     4
# Ljósleiðara deildin 2024         2
# GRID-TEST                        2
# T-esports Championship S3        2
# Name: count, dtype: int64
#
# Matches by format:
# format_name
# best-of-3    92
# best-of-1    16
# best-of-5     3
# Name: count, dtype: int64
#
# Recent Matches Sample:
#         id               tournament_name         team1_name      team2_name  \
# 0  2732475     CCT S2 - South America S4  LA CHAMPIONS LIGA  Yawara Esports
# 1  2738557  Esports Battles Oct 2024 CS2        Purple Haze      Gameinside
# 2  2738475                 EPL S20 - CS2          Aurora YB           ECLOT
# 3  2732476     CCT S2 - South America S4       MIBR Academy  Bestia Academy
# 4  2732477     CCT S2 - South America S4             Sensei       BeBold.gg
#
#   format_short                start_time
# 0          Bo3 2024-10-30 14:30:00+00:00
# 1          Bo3 2024-10-30 14:40:00+00:00
# 2          Bo3 2024-10-30 15:00:00+00:00
# 3          Bo3 2024-10-30 17:35:00+00:00
# 4          Bo3 2024-10-30 20:30:00+00:00
