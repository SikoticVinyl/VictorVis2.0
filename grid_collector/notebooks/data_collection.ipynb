# %%
# Imports and Setup
import os
import sys
import logging
from time import sleep

# Add the grid_collector directory to Python path
grid_collector_path = os.path.dirname(os.getcwd())  # Go up one directory to grid_collector
if grid_collector_path not in sys.path:
    sys.path.insert(0, grid_collector_path)  # Insert at beginning of path for priority
    print(f"Added to path: {grid_collector_path}")

from dotenv import load_dotenv
from src.collector.grid_collector import GridCollector
import logging
import pandas as pd
from datetime import datetime, timedelta

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
# Out:
# Added to path: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector

# %%
# Configuration and Initialization
# Load configuration
load_dotenv()
api_key = os.getenv('GRID_API_KEY')
if not api_key:
    raise ValueError("GRID_API_KEY environment variable is not set")

try:
    # Initialize collector
    collector = GridCollector(api_key)
    logging.info("Successfully initialized GridCollector")
except Exception as e:
    logging.error(f"Error initializing collector: {str(e)}")
    raise
# Out:
# 2024-11-13 21:04:06,911 - INFO - Successfully initialized GridCollector

# %%
def verify_queries():
    # Get path to queries directory
    notebook_dir = os.getcwd()
    grid_collector_dir = os.path.dirname(notebook_dir)
    queries_dir = os.path.join(grid_collector_dir, 'queries')
    
    print(f"Checking queries directory: {queries_dir}")
    
    # List of required query files
    required_queries = [
        'match_player_stats.graphql',
        'team_statistics.graphql',
        'tournaments.graphql',
        'matches.graphql',
        'players.graphql',
        'player_statistics.graphql',
        'titles.graphql',
        'comprehensive_player_stats.graphql',
    ]
    
    # Check each file
    print("\nChecking query files:")
    for query in required_queries:
        path = os.path.join(queries_dir, query)
        exists = os.path.exists(path)
        print(f"{'✓' if exists else '✗'} {query}")
        if not exists:
            print(f"  Missing file should be at: {path}")
            
    # If any files are missing, show how to create them
    if any(not os.path.exists(os.path.join(queries_dir, q)) for q in required_queries):
        print("\nMissing query files! Here's how to create them:")
        print(f"1. Create directory: {queries_dir}")
        print("2. Create the following files with their queries:")
        for query in required_queries:
            print(f"   - {query}")

# Run verification
verify_queries()
# Out:
# Checking queries directory: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries
#
# Checking query files:
# ✓ match_player_stats.graphql
# ✓ team_statistics.graphql
# ✓ tournaments.graphql
# ✓ matches.graphql
# ✓ players.graphql
# ✓ player_statistics.graphql
# ✓ titles.graphql
# ✓ comprehensive_player_stats.graphql

# %%
# Fetch all titles
titles_df = collector.get_all_titles()

# Display the titles
print("Available Titles:")
print(titles_df)

# %%
# Save the titles to a CSV file
# Create the path to save the CSV
save_path = os.path.join('..', 'data', 'titles.csv')

# Save the dataframe to CSV
titles_df.to_csv(save_path, index=False)

print(f"Titles saved to: {save_path}")

# %%
# Collect Player Data
try:
    logging.info("Collecting player data...")
    players_df = collector.get_players(limit=5)  # 'title_id' defaults to '28' for CS2, limit to 5 for sample remove for all
    logging.info(f"Collected {len(players_df)} players")
    
    # Display sample of players
    print("\nPlayers Sample:")
    print(players_df.head())
    
except Exception as e:
    logging.error(f"Error collecting player data: {str(e)}")
    raise

# %%
# Save players data to CSV in the data folder
save_path = os.path.join('..', 'data', 'players.csv')

# Save the dataframe to CSV
players_df.to_csv(save_path, index=False)

print(f"Players data saved to: {save_path}")

# %%
# Collect Tournament Data
try:
    tournaments_df = collector.get_tournaments()
    print(f"\nCollected {len(tournaments_df)} tournaments")
    print("\nSample data:")
    print(tournaments_df.head())
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# 2024-11-07 17:34:32,558 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\tournaments.graphql
# 2024-11-07 17:34:32,564 - INFO - >>> {"query": "query IntrospectionQuery {\n  __schema {\n    queryType {\n      name\n    }\n    mutationType {\n      name\n    }\n    subscriptionType {\n      name\n    }\n    types {\n      ...FullType\n    }\n    directives {\n      name\n      description\n      locations\n      args {\n        ...InputValue\n      }\n    }\n  }\n}\n\nfragment FullType on __Type {\n  kind\n  name\n  description\n  fields(includeDeprecated: true) {\n    name\n    description\n    args {\n      ...InputValue\n    }\n    type {\n      ...TypeRef\n    }\n    isDeprecated\n    deprecationReason\n  }\n  inputFields {\n    ...InputValue\n  }\n  interfaces {\n    ...TypeRef\n  }\n  enumValues(includeDeprecated: true) {\n    name\n    description\n    isDeprecated\n    deprecationReason\n  }\n  possibleTypes {\n    ...TypeRef\n  }\n}\n\nfragment InputValue on __InputValue {\n  name\n  description\n  type {\n    ...TypeRef\n  }\n  defaultValue\n}\n\nfragment TypeRef on __Type {\n  kind\n  name\n  ofType {\n    kind\n    name\n    ofType {\n      kind\n      name\n      ofType {\n        kind\n        name\n        ofType {\n          kind\n          name\n          ofType {\n            kind\n            name\n            ofType {\n              kind\n              name\n              ofType {\n                kind\n                name\n                ofType {\n                  kind\n                  name\n                  ofType {\n                    kind\n                    name\n                  }\n                }\n              }\n            }\n          }\n        }\n      }\n    }\n  }\n}"}
# 2024-11-07 17:34:33,525 - INFO - <<< {"data":{"__schema":{"queryType":{"name":"Query"},"types":[{"kind":"SCALAR","name":"Boolean","description":"Built-in Boolean"},{"kind":"INPUT_OBJECT","name":"BooleanFilter","description":"Boolean filter for true/false fields.","inputFields":[{"name":"equals","description":"Value to look for, can be nullable.","type":{"kind":"SCALAR","name":"Boolean"}}]},{"kind":"SCALAR","name":"Cursor","description":"Cursor value for pagination."},{"kind":"OBJECT","name":"DataProvider","fields":[{"name":"name","description":"The name of the external data provider.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"String"}},"isDeprecated":false},{"name":"description","description":"Description of the data provider.","args":[],"type":{"kind":"SCALAR","name":"String"},"isDeprecated":false}],"interfaces":[]},{"kind":"SCALAR","name":"Date","description":"Date formatted as ISO 8601"},{"kind":"SCALAR","name":"DateTime","description":"DateTime formatted as ISO 8601."},{"kind":"INPUT_OBJECT","name":"DateTimeFilter","description":"Filter by a datetime range.","inputFields":[{"name":"gte","description":"DateTime for the beginning of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}},{"name":"lte","description":"DateTime for the end of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}}]},{"kind":"SCALAR","name":"Decimal","description":"Decimal number representation."},{"kind":"ENUM","name":"ErrorDetail","enumValues":[{"name":"UNKNOWN","description":"Unknown error.\n\nThis error should only be returned when no other error detail applies.\nIf a client sees an unknown errorDetail, it will be interpreted as UNKNOWN.\n\nHTTP Mapping: 500 Internal Server Error","isDeprecated":false},{"name":"FIELD_NOT_FOUND","description":"The requested field is not found in the schema.\n\nThis differs from `NOT_FOUND` in that `NOT_FOUND` should be used when a\nquery is valid, but is unable to return a result (if, for example, a\nspecific video id doesn't exist). `FIELD_NOT_FOUND` is intended to be\nreturned by the server to signify that the requested field is not known to exist.\nThis may be returned in lieu of failing the entire query.\nSee also `PERMISSION_DENIED` for cases where the\nrequested field is invalid only for the given user or class of users.\n\nHTTP Mapping: 404 Not Found\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_CURSOR","description":"The provided cursor is not valid.\n\nThe most common usage for this error is when a client is paginating\nthrough a list that uses stateful cursors. In that case, the provided\ncursor may be expired.\n\nHTTP Mapping: 404 Not Found\nError Type: NOT_FOUND","isDeprecated":false},{"name":"UNIMPLEMENTED","description":"The operation is not implemented or is not currently supported/enabled.\n\nHTTP Mapping: 501 Not Implemented\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_ARGUMENT","description":"The client specified an invalid argument.\n\nNote that this differs from `FAILED_PRECONDITION`.\n`INVALID_ARGUMENT` indicates arguments that are problematic\nregardless of the state of the system (e.g., a malformed file name).\n\nHTTP Mapping: 400 Bad Request\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"DEADLINE_EXCEEDED","description":"The deadline expired before the operation could complete.\n\nFor operations that change the state of the system, this error\nmay be returned even if the operation has completed successfully.\nFor example, a successful response from a server could have been\ndelayed long enough for the deadline to expire.\n\nHTTP Mapping: 504 Gateway Timeout\nError Type: UNAVAILABLE","isDeprecated":false},{"name":"SERVICE_ERROR","description":"Service Error.\n\nThere is a problem with an upstream service.\n\nThis may be returned if a gateway re ...
# 2024-11-07 17:34:33,532 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": null}}
# 2024-11-07 17:34:33,903 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0FBCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0YLC1oLCw==","node":{"id":"1","name":"United Masters League 2018-2019","nameShortened":"UML 1819","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ULC1oLCw==","node":{"id":"2","name":"Dota PIT 2019 Minor","nameShortened":"Dota PIT 2019 Minor","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0QLC1oLCw==","node":{"id":"3","name":"HotShot Series Season 2","nameShortened":"HotShot Series S2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0MLC1oLCw==","node":{"id":"4","name":"Blast Pro Series Miami 2019","nameShortened":"Blast Pro Miami 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ILC1oLCw==","node":{"id":"5","name":"Blast Pro Series Madrid 2019","nameShortened":"BP Madrid 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ELC1oLCw==","node":{"id":"6","name":"ECS Season 7","nameShortened":"ECS Season 7","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ALC1oLCw==","node":{"id":"7","name":"HotShot Series Season 3","nameShortened":"HotShot Season 3","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC08LC1oLCw==","node":{"id":"8","name":"StarLadder ImbaTV Dota 2 Minor Season 2","nameShortened":"StarLadder Minor S2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC04LC1oLCw==","node":{"id":"9","name":"StarLadder ImbaTV Dota 2 Minor Season 2 Finals","nameShortened":"StarLadder S2 Finals","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZHCwtaCws=","node":{"id":"10","name":"Blast Pro Series Los Angeles 2019","nameShortened":"BP Los Angeles 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZGCwtaCws=","node":{"id":"11","name":"Good Game League 2019","nameShortened":"GG League 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZFCwtaCws=","node":{"id":"12","name":"StarLadder Minor CS:GO","nameShortened":"SLTV CS:GO","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZECwtaCws=","node":{"id":"13","name":"Unknown","nameShortened":"UNKNOWN","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZDCwtaCws=","node":{"id":"14","name":"Loot.bet/dota Season 1 2019","nameShortened":"Loot.bet/dota","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZCCwtaCws=","node":{"id":"15","name":"CS.MONEY Asian Emperor","nameShortened":"CS.MONEY","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZBCwtaCws=","node":{"id":"16","name":"LOOT.BET/CS SEASON 3","nameShortened":"LOOT.BET/CS S3","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZACwtaCws=","node":{"id":"17","name":"CIS Esports Pro Championship","nameShortened":"CIS Esports Pro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZOCwtaCws=","node":{"id":"19","name":"Blast Pro Moscow Closed Qualifier","nameShortened":"BP Moscow CQ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VFCwtaCws=","node":{"id":"22","name":"ECS Season 8","nameShortened":"ECS S8","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VECwtaCws=","node":{"id":"23","name":"Star Laddar Berlin Major 2019","na ...
# 2024-11-07 17:34:33,904 - INFO - Processed page 1 - Got 50 items
# 2024-11-07 17:34:35,565 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0FBCwtaCws="}}
# 2024-11-07 17:34:36,275 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RFQ04LC1oLCw=="},"edges":[{"cursor":"PjMLC1oLC0FACwtaCws=","node":{"id":"67","name":"LOOT.BET Season 5","nameShortened":"LOOT.BET Season 5","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0FPCwtaCws=","node":{"id":"68","name":"WESG 2019 East Europe Closed Qualifier","nameShortened":"WESG 2019 East Europ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0FOCwtaCws=","node":{"id":"69","name":"ESL Brazil Premier League Season 11","nameShortened":"ESL Brazil Premier L","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BHCwtaCws=","node":{"id":"70","name":"ESEA Advanced Season 32 North America","nameShortened":"ESEA Advanced Season","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BGCwtaCws=","node":{"id":"71","name":"ESL Pro League Season 10 Finals","nameShortened":"ESL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BFCwtaCws=","node":{"id":"72","name":"ESEA MDL Season 32 Europe Climber Cup","nameShortened":"ESEA MDL Season 32 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BECwtaCws=","node":{"id":"73","name":"IEM Katowice 2020 Oceania Open Qualifier #1","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BDCwtaCws=","node":{"id":"74","name":"ESEA Open Season 32 Brazil","nameShortened":"ESEA Open Season 32 ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BCCwtaCws=","node":{"id":"75","name":"ESEA Open Season 32 South Africa","nameShortened":"ESEA Open Season 32 ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BBCwtaCws=","node":{"id":"76","name":"POWER Ligaen Season 12","nameShortened":"POWER Ligaen Season ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BACwtaCws=","node":{"id":"77","name":"SECTOR: MOSTBET","nameShortened":"SECTOR: MOSTBET","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BPCwtaCws=","node":{"id":"78","name":"Hainan Supreme Cup ","nameShortened":"Hainan Supreme Cup ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BOCwtaCws=","node":{"id":"79","name":"WESG 2019 North Europe Closed Qualifier","nameShortened":"WESG 2019 North Euro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09HCwtaCws=","node":{"id":"80","name":"Svenska Elitserien Fall 2019","nameShortened":"Svenska Elitserien F","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09GCwtaCws=","node":{"id":"81","name":"Conquerors Insignia 2019","nameShortened":"Conquerors Insignia ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09FCwtaCws=","node":{"id":"82","name":"IEM Katowice 2020 Oceania Open Qualifier #2","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09ECwtaCws=","node":{"id":"83","name":"WESG 2019 APAC Oceania Qualifier","nameShortened":"WESG 2019 APAC Ocean","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09DCwtaCws=","node":{"id":"84","name":"DreamHack Delhi Invitational 2019","nameShortened":"DreamHack Delhi Invi","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09CCwtaCws=","node":{"id":"8 ...
# 2024-11-07 17:34:36,277 - INFO - Processed page 2 - Got 50 items
# 2024-11-07 17:34:38,578 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RFQ04LC1oLCw=="}}
# 2024-11-07 17:34:39,225 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VAQE5FCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RATkALC1oLCw==","node":{"id":"3797","name":"IEM Katowice 2020 North America Open Qualifier 1","nameShortened":"IEM Katowice 2020 No","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZDRUJGCwtaCws=","node":{"id":"14251","name":"NEST Pro 2019 Female","nameShortened":"NEST Pro 2019 Female","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZOR05BCwtaCws=","node":{"id":"19096","name":"IEM Katowice 2020 North America Open Qualifier 2","nameShortened":"IEM Katowice 2020 No","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VERUVCCwtaCws=","node":{"id":"23225","name":"ESL Meisterschaft Winter 2019 Finals","nameShortened":"ESL Meisterschaft Wi","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VEQU9CCwtaCws=","node":{"id":"23685","name":"ESEA MDL Season 32 Global Challenge","nameShortened":"ESEA MDL Season 32 G","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCRUBGCwtaCws=","node":{"id":"25271","name":"NCS Grand Finals 2019 @ Fragadelphia 14","nameShortened":"NCS Grand Finals 201","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCQ0ZFCwtaCws=","node":{"id":"25412","name":"EPICENTER 2019","nameShortened":"EPICENTER 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCQUZECwtaCws=","node":{"id":"25613","name":"ESL Nationals CZSK Season 2 Finals","nameShortened":"ESL Nationals CZSK S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBR0BDCwtaCws=","node":{"id":"26074","name":"Dragon Spirit Cup 2019","nameShortened":"Dragon Spirit Cup 20","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBT0dDCwtaCws=","node":{"id":"26804","name":"Grosvenor CS:GO Championship Season 3","nameShortened":"Grosvenor CS:GO Cham","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBTkNDCwtaCws=","node":{"id":"26944","name":"Swiss Esports League Fall Season 2019 Finals","nameShortened":"Swiss Esports League","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJDCwtaCws=","node":{"id":"27754","name":"Champions Cup Finals","nameShortened":"Champions Cup Finals","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJCCwtaCws=","node":{"id":"27755","name":"Brasileirão Season 1","nameShortened":"Brasileirão Season ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJBCwtaCws=","node":{"id":"27756","name":"RES Season 1","nameShortened":"RES Season 1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJACwtaCws=","node":{"id":"27757","name":"99Damage League Season 13","nameShortened":"99Damage League Seas","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"},{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAQEJPCwtaCws=","node":{"id":"27758","name":"Aorus League 2019 #4 Finals","nameShortened":"Aorus League 2019 #4","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJOCwtaCws=","node":{"id":"27759","name":"RES Season 1 Finals","nameShortened":"RES Season 1 Finals","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEFHCwtaCws=","node":{"id":"27760","name":"Asian DOTA2 Gold Occupation Competition S9","nameSh ...
# 2024-11-07 17:34:39,227 - INFO - Processed page 3 - Got 50 items
# 2024-11-07 17:34:41,588 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VAQE5FCwtaCws="}}
# 2024-11-07 17:34:42,301 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VAT0NPCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VAQE5ECwtaCws=","node":{"id":"27793","name":"Aorus League 2019 #4 Northern Cone","nameShortened":"Aorus League 2019 #4","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5DCwtaCws=","node":{"id":"27794","name":"IEM Katowice 2020 Europe Closed Qualifier","nameShortened":"IEM Katowice 2020 Eu","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5CCwtaCws=","node":{"id":"27795","name":"WINNERS League Season 3 Europe","nameShortened":"WINNERS League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5BCwtaCws=","node":{"id":"27796","name":"Hot Price League","nameShortened":"Hot Price League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAQE5PCwtaCws=","node":{"id":"27798","name":"DreamHack Open Leipzig 2020 Europe Open Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5OCwtaCws=","node":{"id":"27799","name":"OMG BET Cup 2","nameShortened":"OMG BET Cup 2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0dHCwtaCws=","node":{"id":"27800","name":"WINNERS League Season 3 North America","nameShortened":"WINNERS League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dGCwtaCws=","node":{"id":"27801","name":"DreamHack Open Leipzig 2020 North America Open Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dFCwtaCws=","node":{"id":"27802","name":"WESG 2019 Brazil Open Qualifier","nameShortened":"WESG 2019 Brazil Ope","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dECwtaCws=","node":{"id":"27803","name":"DreamHack Open Leipzig 2020 Europe Closed Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dDCwtaCws=","node":{"id":"27804","name":"WESG 2019 Brazil","nameShortened":"WESG 2019 Brazil","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dCCwtaCws=","node":{"id":"27805","name":"DreamHack Open Leipzig 2020 North America Closed Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dBCwtaCws=","node":{"id":"27806","name":"ESEA MDL Season 33 Australia","nameShortened":"ESEA MDL Season 33 A","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dACwtaCws=","node":{"id":"27807","name":"FACEIT Pro League","nameShortened":"FPL","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dPCwtaCws=","node":{"id":"27808","name":"Great Universe Cup","nameShortened":"Great Universe Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dOCwtaCws=","node":{"id":"27809","name":"LEGENDS.bet L33T Cup","nameShortened":"LEGENDS.bet L33T Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0ZHCwtaCws=","node":{"id":"27810","name":"IEM Katowice 2020 Oceania Closed Qualifier","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0ZGCwtaCws=","node":{"id":"27811","name":"Masters Tournament Season 4","nameShortened":"Masters Tournament S","pr ...
# 2024-11-07 17:34:42,302 - INFO - Processed page 4 - Got 50 items
# 2024-11-07 17:34:44,604 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VAT0NPCwtaCws="}}
# 2024-11-07 17:34:45,292 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VPR0NGCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VAT0NOCwtaCws=","node":{"id":"27849","name":"Americas Minor North America Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Americas Minor North","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JHCwtaCws=","node":{"id":"27850","name":"Asia Minor Greater China Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Asia Minor Greater C","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JGCwtaCws=","node":{"id":"27851","name":"Asia Minor SEA Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Asia Minor SEA Open ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JFCwtaCws=","node":{"id":"27852","name":"Supreme Masters European Invitational 2020","nameShortened":"Supreme Masters Euro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JDCwtaCws=","node":{"id":"27854","name":"ESEA MDL Season 33 North America","nameShortened":"ESEA MDL Season 33 N","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JCCwtaCws=","node":{"id":"27855","name":"Asia Challenger League Season 6","nameShortened":"Asia Challenger Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0JBCwtaCws=","node":{"id":"27856","name":"Asia Minor SEA Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Asia Minor SEA Open ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JACwtaCws=","node":{"id":"27857","name":"ESEA MDL Season 33 Europe","nameShortened":"ESEA MDL Season 33 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JPCwtaCws=","node":{"id":"27858","name":"CIS Minor Open Qualifier 1 - ESL One Rio 2020","nameShortened":"CIS Minor Open Quali","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JOCwtaCws=","node":{"id":"27859","name":"Americas Minor South America Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Americas Minor South","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0FHCwtaCws=","node":{"id":"27860","name":"Brazilian Dota 2 Championships Season 2","nameShortened":"Brazilian Dota 2 Cha","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0FGCwtaCws=","node":{"id":"27861","name":"Red Star Cup Season 3","nameShortened":"Red Star Cup Season ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VATk5PCwtaCws=","node":{"id":"27998","name":"Europe Minor Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Europe Minor Open Qu","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VATk5OCwtaCws=","node":{"id":"27999","name":"Americas Minor North America Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Americas Minor North","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dHCwtaCws=","node":{"id":"28000","name":"Vietnam Pro League Season 3","nameShortened":"Vietnam Pro League S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dFCwtaCws=","node":{"id":"28002","name":"WESG 2019 Russia Closed Qualifier","nameShortened":"WESG 2019 Russia Clo","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dECwtaCws=","node":{"id":"28003","name":"CIS Minor Open Qualifier 2 - ESL One Rio 2020","nameShortened":"CIS Minor Open Quali","private" ...
# 2024-11-07 17:34:45,293 - INFO - Processed page 5 - Got 50 items
# 2024-11-07 17:34:47,616 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VPR0NGCwtaCws="}}
# 2024-11-07 17:34:48,305 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VPRkdECwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VPR0NFCwtaCws=","node":{"id":"28042","name":"WePlay! Dota2 Tug of War: Mad Moon","nameShortened":"WePlay! Dota2 Tug of","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NECwtaCws=","node":{"id":"28043","name":"CBDota - Brazilian Dota 2 Championships 2020","nameShortened":"CBDota - Brazilian D","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NDCwtaCws=","node":{"id":"28044","name":"Epic League Season 1","nameShortened":"Epic League Season 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NCCwtaCws=","node":{"id":"28045","name":"Hainan Master Spring Invitational","nameShortened":"Hainan Master Spring","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NBCwtaCws=","node":{"id":"28046","name":"GIRLGAMER World Finals 2020","nameShortened":"GIRLGAMER World Fina","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NACwtaCws=","node":{"id":"28047","name":"IEM Katowice 2020","nameShortened":"IEM Katowice 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NPCwtaCws=","node":{"id":"28048","name":"epic29","nameShortened":"epic29","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NOCwtaCws=","node":{"id":"28049","name":"Samsung GOEXANIMO CS:GO 5X5 #20","nameShortened":"Samsung GOEXANIMO CS","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JHCwtaCws=","node":{"id":"28050","name":"SIGUL Pro League","nameShortened":"SIGUL Pro League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JGCwtaCws=","node":{"id":"28051","name":"Elite Challenge Season 3","nameShortened":"Elite Challenge Seas","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JFCwtaCws=","node":{"id":"28052","name":"BashFest 2020","nameShortened":"BashFest 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JECwtaCws=","node":{"id":"28053","name":"Maxline Winter Madness","nameShortened":"Maxline Winter Madne","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JDCwtaCws=","node":{"id":"28054","name":"EGB Arena of Blood: Closed Qualifier","nameShortened":"EGB Arena of Blood: ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JCCwtaCws=","node":{"id":"28055","name":"LPL Pro Season 1","nameShortened":"LPL Pro Season 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JBCwtaCws=","node":{"id":"28056","name":"LanTrek 2020","nameShortened":"LanTrek 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JACwtaCws=","node":{"id":"28057","name":"Aorus League 2020 #1 Southern Cone","nameShortened":"Aorus League 2020 #1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JPCwtaCws=","node":{"id":"28058","name":"WESG 2019 Russia Finals","nameShortened":"WESG 2019 Russia Fin","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JOCwtaCws=","node":{"id":"28059","name":"LPL Pro League Season 4","nameShortened":"LPL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0FHCwtaCws=","node":{"id":"28060","name":"Masters Tournament Season 5 Group Stage","nameShortened":"Maste ...
# 2024-11-07 17:34:48,306 - INFO - Processed page 6 - Got 50 items
# 2024-11-07 17:34:50,622 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0VPRkdECwtaCws="}}
# 2024-11-07 17:34:51,324 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RHT0VECwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VPRkdDCwtaCws=","node":{"id":"28104","name":"Asian Hero League Season 2","nameShortened":"Asian Hero League Se","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdCCwtaCws=","node":{"id":"28105","name":"Red Star Cup Season 4","nameShortened":"Red Star Cup Season ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdBCwtaCws=","node":{"id":"28106","name":"SECTOR: MOSTBET 2","nameShortened":"SECTOR: MOSTBET 2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkdACwtaCws=","node":{"id":"28107","name":"Flashpoint 1","nameShortened":"Flashpoint 1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkdPCwtaCws=","node":{"id":"28108","name":"Arena of Blood","nameShortened":"Arena of Blood","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdOCwtaCws=","node":{"id":"28109","name":"ESL Pro League Season 11","nameShortened":"ESL Pro League S11","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZHCwtaCws=","node":{"id":"28110","name":"ESL Pro League Season 11 Europe","nameShortened":"ESL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZGCwtaCws=","node":{"id":"28111","name":"eFire Master League Season 1 North America","nameShortened":"eFire Master League ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZFCwtaCws=","node":{"id":"28112","name":"ESL Australia & NZ Championship Season 10 Qualifier 3","nameShortened":"ESL Australia & NZ C","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZECwtaCws=","node":{"id":"28113","name":"GGBET Championship 2","nameShortened":"GGBET Championship 2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkZDCwtaCws=","node":{"id":"28114","name":"HardCup 6","nameShortened":"HardCup 6","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZCCwtaCws=","node":{"id":"28115","name":"SECTOR: MOSTBET Season 2","nameShortened":"SECTOR: MOSTBET Seas","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZBCwtaCws=","node":{"id":"28116","name":"META '20 Open","nameShortened":"META '20 Open","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZACwtaCws=","node":{"id":"28117","name":"eFire Master League North America","nameShortened":"eFire Master League ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZPCwtaCws=","node":{"id":"28118","name":"No Major No Problem","nameShortened":"No Major No Problem","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkZOCwtaCws=","node":{"id":"28119","name":"ESEA Advanced Season 33 Europe","nameShortened":"ESEA Advanced Season","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkVGCwtaCws=","node":{"id":"28121","name":"China Development League Season 2: Promotion","nameShortened":"China Dev League 2 Promotion","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkVFCwtaCws=","node":{"id":"28122","name":"WeSave! Charity Play","nameShortened":"WeSave! Charity Play","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPQEZGCwtaCws=","node":{"id":"28711","name":"Maxline League Sea ...
# 2024-11-07 17:34:51,325 - INFO - Processed page 7 - Got 50 items
# 2024-11-07 17:34:53,627 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RHT0VECwtaCws="}}
# 2024-11-07 17:34:54,317 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RHT0BBCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RHT0VDCwtaCws=","node":{"id":"30824","name":"Spring Championship","nameShortened":"Spring Championship","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VCCwtaCws=","node":{"id":"30825","name":"SECTOR DOTA 2 Season 2","nameShortened":"SECTOR DOTA 2 Season","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VACwtaCws=","node":{"id":"30827","name":"ESL One: Road To Rio - Europe","nameShortened":"ESL One: Road to Rio 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0VPCwtaCws=","node":{"id":"30828","name":"Saturnbet Spring Championship","nameShortened":"Saturnbet Spring Cha","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VOCwtaCws=","node":{"id":"30829","name":"Hot Price League Season 3","nameShortened":"Hot Price League Sea","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RHCwtaCws=","node":{"id":"30830","name":"BTS Pro Series","nameShortened":"BTS Pro Series","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RGCwtaCws=","node":{"id":"30831","name":"ESEA MDL Season 33 Europe Relegation","nameShortened":"ESEA MDL Season 33 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RFCwtaCws=","node":{"id":"30832","name":"Oceanic Esports League","nameShortened":"Oceanic Esports Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RECwtaCws=","node":{"id":"30833","name":"Play From Home","nameShortened":"Play From Home","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RDCwtaCws=","node":{"id":"30834","name":"Home Sweet Home Cup 2","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RCCwtaCws=","node":{"id":"30835","name":"Asian Hero League Season 3","nameShortened":"Asian Hero League Se","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RACwtaCws=","node":{"id":"30837","name":"Home Sweet Home Cup 3","nameShortened":"Home Sweet Home Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RPCwtaCws=","node":{"id":"30838","name":"Home Sweet Home Cup 4","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0ROCwtaCws=","node":{"id":"30839","name":"Home Sweet Home Cup 5","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NHCwtaCws=","node":{"id":"30840","name":"Home Sweet Home Cup 6","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NGCwtaCws=","node":{"id":"30841","name":"Home Sweet Home Cup 7","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NFCwtaCws=","node":{"id":"30842","name":"Home Sweet Home Cup 8","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NECwtaCws=","node":{"id":"30843","name":"ESL One: Road to Rio - CIS Play-in","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NDCwtaCws=","node":{"id":"30844","name":"ESL One: Road to Rio - South Ame ...
# 2024-11-07 17:34:54,318 - INFO - Processed page 8 - Got 50 items
# 2024-11-07 17:34:56,642 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RHT0BBCwtaCws="}}
# 2024-11-07 17:34:57,360 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RGRERPCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RHT0BPCwtaCws=","node":{"id":"30878","name":"Dota 2 BEAT Invitational Season 9","nameShortened":"Dota 2 BEAT Invitati","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0BOCwtaCws=","node":{"id":"30879","name":"Betano Masters","nameShortened":"Betano Masters","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09HCwtaCws=","node":{"id":"30880","name":"Hephaestus Cup","nameShortened":"Hephaestus Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09GCwtaCws=","node":{"id":"30881","name":"Isolation Cup","nameShortened":"Isolation Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09FCwtaCws=","node":{"id":"30882","name":"ESEA MDL Season 34 Europe","nameShortened":"ESEA MDL Season 34 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09ECwtaCws=","node":{"id":"30883","name":"ESEA MDL Season 34 North America","nameShortened":"ESEA MDL Season 34 N","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09DCwtaCws=","node":{"id":"30884","name":"Elisa Invitational 2020","nameShortened":"Elisa Invitational 2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09CCwtaCws=","node":{"id":"30885","name":"ESL One: Road to Rio - CIS","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09ACwtaCws=","node":{"id":"30887","name":"ESEA MDL Season 34 Australia","nameShortened":"ESEA MDL Season 34 A","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09PCwtaCws=","node":{"id":"30888","name":"Vulcan Champion League","nameShortened":"Vulcan Champion Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09OCwtaCws=","node":{"id":"30889","name":"Realms Collide","nameShortened":"Realms Collide","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05HCwtaCws=","node":{"id":"30890","name":"RDY Cup","nameShortened":"RDY Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05GCwtaCws=","node":{"id":"30891","name":"Betway CS:GO Asia Masters","nameShortened":"Betway CS:GO Asia Masters","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05FCwtaCws=","node":{"id":"30892","name":"OGA Dota PIT 2020 Online","nameShortened":"OGA Dota PIT 2020 On","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05ECwtaCws=","node":{"id":"30893","name":"SEA Dota Invitational 2020","nameShortened":"SEA Dota Invitationa","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05DCwtaCws=","node":{"id":"30894","name":"Dota2 Secondary Professional League 2020","nameShortened":"Dota2 Secondary Prof","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05CCwtaCws=","node":{"id":"30895","name":"HellCase Cup","nameShortened":"HellCase","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05ACwtaCws=","node":{"id":"30897","name":"FVBet Showmatch","nameShortened":"FVBet Showmatch","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05PCwtaCws=","node":{"id":"30898","name":"ESL One: Road to Rio - Oceania","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","nam ...
# 2024-11-07 17:34:57,361 - INFO - Processed page 9 - Got 50 items
# 2024-11-07 17:34:59,649 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0RGRERPCwtaCws="}}
# ...
# 2024-11-07 17:36:57,648 - INFO - Processed page 49 - Got 50 items
# 2024-11-07 17:37:00,000 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0ZHQUFCTgsLWgsL"}}
# 2024-11-07 17:37:00,686 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0ZHQUBEQwsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0ZHQUFBRgsLWgsL","node":{"id":"106661","name":"CCT South America Series #2","nameShortened":"CCT South America Se","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFBRQsLWgsL","node":{"id":"106662","name":"Fragadelphia 17","nameShortened":"Fragadelphia 17","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFBRAsLWgsL","node":{"id":"106663","name":"The International 2022: Southeast Asia Qualifier","nameShortened":"The International 20","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZHQUFBQgsLWgsL","node":{"id":"106665","name":"The International 2022: Western Europe Qualifier","nameShortened":"The International 20","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZHQUFBTwsLWgsL","node":{"id":"106668","name":"CCT Central Europe Series #2: Closed Qualifier","nameShortened":"CCT Central Europe S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFBTgsLWgsL","node":{"id":"106669","name":"ESL Challenger Rotterdam 2022: European Open Qualifier #2","nameShortened":"ESL Challenger Rotte","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFARgsLWgsL","node":{"id":"106671","name":"PARI PATRIKI VIBE LAN","nameShortened":"PARI PATRIKI VIBE LA","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFAQwsLWgsL","node":{"id":"106674","name":"Polska Liga Esportowa Autumn 2022: Pretendentów","nameShortened":"PLE Autumn 2022: Pretendentów","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFATgsLWgsL","node":{"id":"106679","name":"Kinguin Legends #1","nameShortened":"Kinguin Legends #1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFPRwsLWgsL","node":{"id":"106680","name":"FiReLEAGUE Latin Power Fall 2022","nameShortened":"FiReLEAGUE Latin Pow","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFPRQsLWgsL","node":{"id":"106682","name":"Icelandic Esports League Season 7","nameShortened":"Icelandic Season7","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFPQwsLWgsL","node":{"id":"106684","name":"Elite Series 2022: Summer Split","nameShortened":"Elite Series 2022: S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFPQgsLWgsL","node":{"id":"106685","name":"GAM3RS_X EU Champions: Fall 2022","nameShortened":"GAM3RS_X EU Champion","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFPQAsLWgsL","node":{"id":"106687","name":"ESL Challenger Rotterdam 2022: South American Qualifier","nameShortened":"ESL Challenger Rotte","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFPTwsLWgsL","node":{"id":"106688","name":"ESL Challenger Rotterdam 2022: European Qualifier","nameShortened":"ESL Challenger Rotte","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFPTgsLWgsL","node":{"id":"106689","name":"ESL Challenger Rotterdam 2022: North American Open Qualifier #2","nameShortened":"ESL Challenger Rotte","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZHQUFORwsLWgsL","node":{"id":"106690","name":"CCT Central Europe Series #2","nameShortened":"CCT Central Europe S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive ...
# 2024-11-07 17:37:00,687 - INFO - Processed page 50 - Got 50 items
# 2024-11-07 17:37:03,005 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"first": 50, "after": "PjMLC1oLC0ZHQUBEQwsLWgsL"}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Collect Tournament Data
#       2 try:
# ----> 3     tournaments_df = collector.get_tournaments()
#       4     print(f"\nCollected {len(tournaments_df)} tournaments")
#       5     print("\nSample data:")
#
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:131, in GridCollector.get_tournaments(self)
#     127 query = self._load_query('tournaments')
#     129 try:
#     130     # Get all tournament nodes
# --> 131     tournaments = self._execute_paginated_query(query, self.central_client)
#     133     # Process tournaments into a list of dictionaries
#     134     processed_tournaments = []
#
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:88, in GridCollector._execute_paginated_query(self, query, client, variables, limit)
#      85 current_vars = {**variables, 'first': 50, 'after': after}
#      87 # Execute query with rate limiting
# ---> 88 result = self._execute_query(query, current_vars, client)
#      90 # Get the correct data key (first key in result)
#      91 data_key = next(key for key in result.keys() if key != '__typename')
#
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:59, in GridCollector._execute_query(self, query, variables, client)
#      57     # Execute query
#      58     self.logger.debug(f"Executing query (attempt {attempt + 1})")
# ---> 59     result = client.execute(gql(query), variable_values=variables)
#      61     return result
#      63 except Exception as e:
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:484, in Client.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     481     return data
#     483 else:  # Sync transports
# --> 484     return self.execute_sync(
#     485         document,
#     486         variable_values=variable_values,
#     487         operation_name=operation_name,
#     488         serialize_variables=serialize_variables,
#     489         parse_result=parse_result,
#     490         get_execution_result=get_execution_result,
#     491         **kwargs,
#     492     )
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:248, in Client.execute_sync(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     246 """:meta private:"""
#     247 with self as session:
# --> 248     return session.execute(
#     249         document,
#     250         variable_values=variable_values,
#     251         operation_name=operation_name,
#     252         serialize_variables=serialize_variables,
#     253         parse_result=parse_result,
#     254         get_execution_result=get_execution_result,
#     255         **kwargs,
#     256     )
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:1017, in SyncClientSession.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     997 """Execute the provided document AST synchronously using
#     998 the sync transport.
#     999
#    (...)
#    1013
#    1014 The extra arguments are passed to the transport execute method."""
#    1016 # Validate and execute on the transport
# -> 1017 result = self._execute(
#    1018     document,
#    1019     variable_values=variable_values,
#    1020     operation_name=operation_name,
#    1021     serialize_variables=serialize_variables,
#    1022     parse_result=parse_result,
#    1023     **kwargs,
#    1024 )
#    1026 # Raise an error if an error is returned in the ExecutionResult object
#    1027 if result.errors:
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:926, in SyncClientSession._execute(self, document, variable_values, operation_name, serialize_variables, parse_result, **kwargs)
#     923     result = future_result.result()
#     925 else:
# --> 926     result = self.transport.execute(
#     927         document,
#     928         variable_values=variable_values,
#     929         operation_name=operation_name,
#     930         **kwargs,
#     931     )
#     933 # Unserialize the result if requested
#     934 if self.client.schema:
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\transport\requests.py:237, in RequestsHTTPTransport.execute(self, document, variable_values, operation_name, timeout, extra_args, upload_files)
#     234     post_args.update(extra_args)
#     236 # Using the created session to perform requests
# --> 237 response = self.session.request(
#     238     self.method, self.url, **post_args  # type: ignore
#     239 )
#     240 self.response_headers = response.headers
#     242 def raise_response_error(resp: requests.Response, reason: str):
#     243     # We raise a TransportServerError if the status code is 400 or higher
#     244     # We raise a TransportProtocolError in the other cases
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Save tournaments data to CSV in the data folder
save_path = os.path.join('..', 'data', 'tournaments.csv')

# Save the dataframe to CSV
tournaments_df.to_csv(save_path, index=False)

print(f"Tournaments data saved to: {save_path}")
# Out:
# Tournaments data saved to: ..\data\tournaments.csv

# %%
# Collect Match Data
try:
    logging.info("Collecting match data...")
    #ONLY CHANGE THE NUMBER OF DAYS BELOW PLEASE!!!
    matches_df = collector.get_matches(days=7) # Change days to collect more matches
    logging.info(f"Collected {len(matches_df)} matches")
    
    # Basic match analysis
    print("\nMatch Statistics:")
    print(f"Total matches collected: {len(matches_df)}")
    
    print(f"\nMatches by tournament:")
    print(matches_df['tournament_name'].value_counts())
    
    print(f"\nMatches by format:")
    print(matches_df['format_name'].value_counts())
    
    # Display sample of recent matches with key information
    print("\nRecent Matches Sample:")
    display_columns = [
        'id', 'tournament_name', 'team1_name', 'team2_name', 
        'format_short', 'start_time'
    ]
    print(matches_df[display_columns].head())
    
except Exception as e:
    logging.error(f"Error collecting match data: {str(e)}")
    raise
# Out:
# 2024-11-07 17:15:48,297 - INFO - Collecting match data...
# 2024-11-07 17:15:48,298 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\matches.graphql
# 2024-11-07 17:15:50,525 - INFO - >>> {"query": "query GetRecentMatches($first: Int!, $after: Cursor) {\n  allSeries(\n    first: $first\n    after: $after\n    filter: {startTimeScheduled: {gte: \"2024-10-31T17:00:00+00:00\", lte: \"2024-11-07T17:00:00+00:00\"}}\n    orderBy: StartTimeScheduled\n  ) {\n    totalCount\n    edges {\n      cursor\n      node {\n        id\n        title {\n          nameShortened\n        }\n        tournament {\n          nameShortened\n        }\n        startTimeScheduled\n        format {\n          name\n          nameShortened\n        }\n        teams {\n          baseInfo {\n            id\n            name\n          }\n          scoreAdvantage\n        }\n      }\n    }\n    pageInfo {\n      hasPreviousPage\n      hasNextPage\n      startCursor\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": null}}
# 2024-11-07 17:15:51,343 - INFO - <<< {"data":{"allSeries":{"totalCount":109,"edges":[{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ09HCwtaCwtFR0VDWkZHWkRGI0ZATURHTUdHLQ==","node":{"id":"2732480","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-10-31T17:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53712","name":"Vikings KR"},"scoreAdvantage":0},{"baseInfo":{"id":"49973","name":"VeloX"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERCREVHCwtaCwtFR0VDWkZHWkRGI0ZOTURHTUdHLQ==","node":{"id":"2735320","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Ljósleiðara deildin 2024"},"startTimeScheduled":"2024-10-31T19:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"50072","name":"Þór"},"scoreAdvantage":0},{"baseInfo":{"id":"49944","name":"DUSTY"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ09GCwtaCwtFR0VDWkZHWkRGI0VHTURHTUdHLQ==","node":{"id":"2732481","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-10-31T20:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"54147","name":"ShindeN"},"scoreAdvantage":0},{"baseInfo":{"id":"54149","name":"Tropa do Taco"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ09FCwtaCwtFR0VDWkZHWkRGI0VETUNHTUdHLQ==","node":{"id":"2732482","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-10-31T23:40:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53830","name":"JOGA DE TERNO"},"scoreAdvantage":0},{"baseInfo":{"id":"51588","name":"paiN Academy"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkFFCwtaCwtFR0VDWkZGWkdGI0dBTUdHTUdHLQ==","node":{"id":"2738562","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-01T06:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51658","name":"NightRaid"},"scoreAdvantage":0},{"baseInfo":{"id":"51651","name":"Gameinside"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQ0BOCwtaCwtFR0VDWkZGWkdGI0dOTUdHTUdHLQ==","node":{"id":"2738479","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-01T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51108","name":"ECSTATIC"},"scoreAdvantage":0},{"baseInfo":{"id":"49506","name":"Verdant"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkFECwtaCwtFR0VDWkZGWkdGI0dOTUdHTUdHLQ==","node":{"id":"2738563","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-01T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51657","name":"REMBAZA"},"scoreAdvantage":0},{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERORUdCCwtaCwtFR0VDWkZGWkdGI0dOTUdHTUdHLQ==","node":{"id":"2739205","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"United21 Season 22"},"startTimeScheduled":"2024-11-01T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53826","name":"ADEPTS"},"scoreAdvantage":0},{"baseInfo":{"id":"53713","name":"HEIMO"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkdDCwtaCwtFR0VDWkZGWkdGI0ZGTURHTUdHLQ==","node":{"id":"2738504","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-01T11:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53084","name":"Navi Junior"},"scoreAdvantage":0},{"baseInfo":{"id":"51337","name":" ...
# 2024-11-07 17:15:51,346 - INFO - Processed page 1 - Got 50 items
# 2024-11-07 17:15:53,532 - INFO - >>> {"query": "query GetRecentMatches($first: Int!, $after: Cursor) {\n  allSeries(\n    first: $first\n    after: $after\n    filter: {startTimeScheduled: {gte: \"2024-10-31T17:00:00+00:00\", lte: \"2024-11-07T17:00:00+00:00\"}}\n    orderBy: StartTimeScheduled\n  ) {\n    totalCount\n    edges {\n      cursor\n      node {\n        id\n        title {\n          nameShortened\n        }\n        tournament {\n          nameShortened\n        }\n        startTimeScheduled\n        format {\n          name\n          nameShortened\n        }\n        teams {\n          baseInfo {\n            id\n            name\n          }\n          scoreAdvantage\n        }\n      }\n    }\n    pageInfo {\n      hasPreviousPage\n      hasNextPage\n      startCursor\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERCQUZFCwtaCwtFR0VDWkZGWkdEI0ZATUZHTUdHLQ=="}}
# 2024-11-07 17:15:54,283 - INFO - <<< {"data":{"allSeries":{"totalCount":109,"edges":[{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ05FCwtaCwtFR0VDWkZGWkdEI0ZOTURHTUdHLQ==","node":{"id":"2732492","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-11-03T19:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53919","name":"LA CHAMPIONS LIGA"},"scoreAdvantage":0},{"baseInfo":{"id":"50948","name":"9z Academy"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHQUBHCwtaCwtFR0VDWkZGWkdEI0VFTUdHTUdHLQ==","node":{"id":"2740670","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"DBE 2024"},"startTimeScheduled":"2024-11-03T22:00:00Z","format":{"name":"best-of-1","nameShortened":"Bo1"},"teams":[{"baseInfo":{"id":"52023","name":"ODDIK"},"scoreAdvantage":0},{"baseInfo":{"id":"53712","name":"Vikings KR"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQ05ECwtaCwtFR0VDWkZGWkdEI0VFTURHTUdHLQ==","node":{"id":"2732493","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-11-03T22:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"54147","name":"ShindeN"},"scoreAdvantage":0},{"baseInfo":{"id":"51146","name":"MIBR Academy"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHQUBGCwtaCwtFR0VDWkZGWkdEI0VETUZCTUdHLQ==","node":{"id":"2740671","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"DBE 2024"},"startTimeScheduled":"2024-11-03T23:15:00Z","format":{"name":"best-of-1","nameShortened":"Bo1"},"teams":[{"baseInfo":{"id":"53389","name":"Galorys"},"scoreAdvantage":0},{"baseInfo":{"id":"52177","name":"INTENSE GAME"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHQUBFCwtaCwtFR0VDWkZGWkdDI0dHTUdHTUdHLQ==","node":{"id":"2740672","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"DBE 2024"},"startTimeScheduled":"2024-11-04T00:00:00Z","format":{"name":"best-of-1","nameShortened":"Bo1"},"teams":[{"baseInfo":{"id":"51791","name":"Solid"},"scoreAdvantage":0},{"baseInfo":{"id":"49558","name":"Sharks"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRU9FCwtaCwtFR0VDWkZGWkdDI0dBTUNCTUdHLQ==","node":{"id":"2740282","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-04T06:45:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51657","name":"REMBAZA"},"scoreAdvantage":0},{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERORUZGCwtaCwtFR0VDWkZGWkdDI0dOTUdHTUdHLQ==","node":{"id":"2739211","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"United21 Season 22"},"startTimeScheduled":"2024-11-04T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51986","name":"Illuminar gaming"},"scoreAdvantage":0},{"baseInfo":{"id":"53069","name":"Case"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRU9ECwtaCwtFR0VDWkZGWkdDI0dOTUdHTUdHLQ==","node":{"id":"2740283","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-04T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0},{"baseInfo":{"id":"51657","name":"REMBAZA"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQ09CCwtaCwtFR0VDWkZGWkdDI0dOTUdCTUdHLQ==","node":{"id":"2738485","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-04T09:05:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"49865","name":"9INE"},"scoreAdvantage":0},{"baseInfo":{"id":"53084","name":"Navi Junior"},"scoreAdvantage ...
# 2024-11-07 17:15:54,284 - INFO - Processed page 2 - Got 50 items
# 2024-11-07 17:15:56,546 - INFO - >>> {"query": "query GetRecentMatches($first: Int!, $after: Cursor) {\n  allSeries(\n    first: $first\n    after: $after\n    filter: {startTimeScheduled: {gte: \"2024-10-31T17:00:00+00:00\", lte: \"2024-11-07T17:00:00+00:00\"}}\n    orderBy: StartTimeScheduled\n  ) {\n    totalCount\n    edges {\n      cursor\n      node {\n        id\n        title {\n          nameShortened\n        }\n        tournament {\n          nameShortened\n        }\n        startTimeScheduled\n        format {\n          name\n          nameShortened\n        }\n        teams {\n          baseInfo {\n            id\n            name\n          }\n          scoreAdvantage\n        }\n      }\n    }\n    pageInfo {\n      hasPreviousPage\n      hasNextPage\n      startCursor\n      endCursor\n    }\n  }\n}", "variables": {"first": 50, "after": "JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQkdFCwtaCwtFR0VDWkZGWkdBI0VGTUVHTUdHLQ=="}}
# 2024-11-07 17:15:57,152 - INFO - <<< {"data":{"allSeries":{"totalCount":109,"edges":[{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERFQkdECwtaCwtFR0VDWkZGWkdBI0VETURHTUdHLQ==","node":{"id":"2732503","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"CCT S2 - South America S4"},"startTimeScheduled":"2024-11-06T23:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"54147","name":"ShindeN"},"scoreAdvantage":0},{"baseInfo":{"id":"51499","name":"Hype E-sports"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRk9HCwtaCwtFR0VDWkZGWkdAI0dBTURCTUdHLQ==","node":{"id":"2740180","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-07T06:35:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0},{"baseInfo":{"id":"51658","name":"NightRaid"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRU5CCwtaCwtFR0VDWkZGWkdAI0dPTUNHTUdHLQ==","node":{"id":"2740295","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-07T08:40:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51658","name":"NightRaid"},"scoreAdvantage":0},{"baseInfo":{"id":"51659","name":"Purple Haze"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQkZCCwtaCwtFR0VDWkZGWkdAI0dOTUdHTUdHLQ==","node":{"id":"2738515","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-07T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53084","name":"Navi Junior"},"scoreAdvantage":0},{"baseInfo":{"id":"53754","name":"Rebels Gaming"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERORUZACwtaCwtFR0VDWkZGWkdAI0dOTUdHTUdHLQ==","node":{"id":"2739217","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"United21 Season 22"},"startTimeScheduled":"2024-11-07T09:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53692","name":"Copenhagen Wolves"},"scoreAdvantage":0},{"baseInfo":{"id":"49502","name":"ENCE Academy"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRU5BCwtaCwtFR0VDWkZGWkdAI0ZGTUdHTUdHLQ==","node":{"id":"2740296","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-07T11:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51657","name":"REMBAZA"},"scoreAdvantage":0},{"baseInfo":{"id":"51652","name":"Seight"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERORUZPCwtaCwtFR0VDWkZGWkdAI0ZGTURHTUdHLQ==","node":{"id":"2739218","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"United21 Season 22"},"startTimeScheduled":"2024-11-07T11:30:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"53069","name":"Case"},"scoreAdvantage":0},{"baseInfo":{"id":"49506","name":"Verdant"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQERPQ05GCwtaCwtFR0VDWkZGWkdAI0ZGTUJHTUdHLQ==","node":{"id":"2738491","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"EPL S20 - CS2"},"startTimeScheduled":"2024-11-07T11:50:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"52233","name":"ECLOT"},"scoreAdvantage":0},{"baseInfo":{"id":"51337","name":"9 Pandas"},"scoreAdvantage":0}]}},{"cursor":"JAMWBQMjHhoSJBQfEhMCGxITCwtaCwtFQENHRU5ACwtaCwtFR0VDWkZGWkdAI0ZDTUdHTUdHLQ==","node":{"id":"2740297","title":{"nameShortened":"cs2"},"tournament":{"nameShortened":"Esports Battles Nov 2024 CS2"},"startTimeScheduled":"2024-11-07T14:00:00Z","format":{"name":"best-of-3","nameShortened":"Bo3"},"teams":[{"baseInfo":{"id":"51652","name":"Seight"},"scoreAdvantage":0},{"baseInfo":{"id":"5 ...
# 2024-11-07 17:15:57,153 - INFO - Processed page 3 - Got 9 items
# 2024-11-07 17:15:57,156 - INFO - Collected 109 matches
# Match Statistics:
# Total matches collected: 109
#
# Matches by tournament:
# tournament_name
# Esports Battles Nov 2024 CS2    27
# CCT S2 - South America S4       24
# DBE 2024                        16
# EPL S20 - CS2                   14
# United21 Season 22              14
# A1 Gaming League S9              4
# Thunderpick WC 2024 - Finals     4
# Ljósleiðara deildin 2024         2
# GRID-TEST                        2
# T-esports Championship S3        2
# Name: count, dtype: int64
#
# Matches by format:
# format_name
# best-of-3    90
# best-of-1    16
# best-of-5     3
# Name: count, dtype: int64
#
# Recent Matches Sample:
#         id               tournament_name     team1_name     team2_name  \
# 0  2732480     CCT S2 - South America S4     Vikings KR          VeloX
# 1  2735320      Ljósleiðara deildin 2024            Þór          DUSTY
# 2  2732481     CCT S2 - South America S4        ShindeN  Tropa do Taco
# 3  2732482     CCT S2 - South America S4  JOGA DE TERNO   paiN Academy
# 4  2738562  Esports Battles Nov 2024 CS2      NightRaid     Gameinside
#
#   format_short                start_time
# 0          Bo3 2024-10-31 17:30:00+00:00
# 1          Bo3 2024-10-31 19:30:00+00:00
# 2          Bo3 2024-10-31 20:30:00+00:00
# 3          Bo3 2024-10-31 23:40:00+00:00
# 4          Bo3 2024-11-01 06:00:00+00:00

# %%
# Save matches data to CSV in the data folder
save_path = os.path.join('..', 'data', 'matches.csv')

# Save the dataframe to CSV
matches_df.to_csv(save_path, index=False)

print(f"Matches data saved to: {save_path}")
# Out:
# Matches data saved to: ..\data\matches.csv

# %%
# Collect Player Statistics
try:
    logging.info("Collecting player statistics...")
    
    # Get all players from recent matches
    all_team_ids = pd.concat([
        matches_df['team1_id'],
        matches_df['team2_id']
    ]).unique()
    
    # Get players from these teams
    players_df = collector.get_players()
    active_players = players_df[players_df['team_id'].isin(all_team_ids)]
    print(f"\nFound {len(active_players)} active players")
    
    # Collect statistics for active players one by one
    print("\nCollecting player statistics...")
    all_player_stats = []
    
    # Use tqdm for progress bar
    from tqdm.notebook import tqdm
    
    # Add retry mechanism
    max_retries = 3
    base_retry_delay = 5
    
    for player_id in tqdm(active_players['id'].tolist()):
        retry_count = 0
        while retry_count < max_retries:
            try:
                # Make sure to respect rate limits
                collector.rate_limiter.wait()
                
                # Properly structure the filter object
                variables = {
                    'playerId': player_id,
                    'filter': {
                        'timeWindow': 'LAST_3_MONTHS'
                    }
                }
                
                result = collector._execute_query(
                    collector._load_query('player_statistics'),
                    variables,
                    collector.stats_client
                )
                
                if result and 'playerStatistics' in result:
                    stats = result['playerStatistics']
                    if stats:
                        # Handle series data
                        series_stats = stats.get('series', {})
                        game_stats = stats.get('game', {})
                        
                        # Safely extract nested values
                        kills = series_stats.get('kills', {}) if isinstance(series_stats, dict) else {}
                        deaths = series_stats.get('deaths', {}) if isinstance(series_stats, dict) else {}
                        wins = game_stats.get('wins', {}) if isinstance(game_stats, dict) else {}
                        
                        flat_stats = {
                            'player_id': player_id,
                            'series_count': series_stats.get('count', 0) if isinstance(series_stats, dict) else 0,
                            'game_count': game_stats.get('count', 0) if isinstance(game_stats, dict) else 0
                        }
                        
                        # Safely add kill statistics
                        if isinstance(kills, dict):
                            flat_stats.update({
                                'total_kills': kills.get('sum', 0),
                                'avg_kills': kills.get('avg', 0),
                                'max_kills': kills.get('max', 0),
                                'min_kills': kills.get('min', 0)
                            })
                        
                        # Safely add death statistics
                        if isinstance(deaths, dict):
                            flat_stats.update({
                                'total_deaths': deaths.get('sum', 0),
                                'avg_deaths': deaths.get('avg', 0),
                                'max_deaths': deaths.get('max', 0),
                                'min_deaths': deaths.get('min', 0)
                            })
                        
                        # Safely add win statistics
                        if isinstance(wins, dict):
                            flat_stats.update({
                                'win_count': wins.get('count', 0),
                                'win_percentage': wins.get('percentage', 0)
                            })
                            
                            # Safely handle streak data
                            streak = wins.get('streak', {})
                            if isinstance(streak, dict):
                                flat_stats.update({
                                    'current_streak': streak.get('current', 0),
                                    'max_streak': streak.get('max', 0)
                                })
                        
                        # Calculate derived statistics only if we have valid data
                        try:
                            if flat_stats.get('total_deaths', 0) > 0:
                                flat_stats['kd_ratio'] = flat_stats.get('total_kills', 0) / flat_stats['total_deaths']
                            else:
                                flat_stats['kd_ratio'] = flat_stats.get('total_kills', 0)
                            
                            if flat_stats.get('game_count', 0) > 0:
                                flat_stats['kills_per_game'] = flat_stats.get('total_kills', 0) / flat_stats['game_count']
                                flat_stats['deaths_per_game'] = flat_stats.get('total_deaths', 0) / flat_stats['game_count']
                            else:
                                flat_stats['kills_per_game'] = 0
                                flat_stats['deaths_per_game'] = 0
                        except Exception as calc_error:
                            logging.warning(f"Error calculating derived stats for player {player_id}: {str(calc_error)}")
                            flat_stats.update({
                                'kd_ratio': 0,
                                'kills_per_game': 0,
                                'deaths_per_game': 0
                            })
                        
                        all_player_stats.append(flat_stats)
                        break  # Success, exit retry loop
                    
            except Exception as e:
                retry_count += 1
                logging.warning(f"Error processing player {player_id} (attempt {retry_count}): {str(e)}")
                if retry_count < max_retries:
                    wait_time = base_retry_delay * retry_count
                    logging.info(f"Waiting {wait_time} seconds before retry...")
                    sleep(wait_time)
                else:
                    logging.error(f"Failed to process player {player_id} after {max_retries} attempts")
            
        # Save progress every 50 players
        if len(all_player_stats) > 0 and len(all_player_stats) % 50 == 0:
            temp_df = pd.DataFrame(all_player_stats)
            temp_df.to_csv(f'player_stats_temp_{datetime.now().strftime("%Y%m%d_%H%M")}.csv', index=False)
            logging.info(f"Saved temporary progress - {len(all_player_stats)} players processed")
    
    # Final processing
    if len(all_player_stats) > 0:
        player_stats_df = pd.DataFrame(all_player_stats)
        
        # Merge with player info
        player_analysis = pd.merge(
            player_stats_df,
            active_players[['id', 'nickname', 'team_name']],
            left_on='player_id',
            right_on='id',
            how='left'
        )
        
        # Save final results
        timestamp = datetime.now().strftime('%Y%m%d_%H%M')
        player_analysis.to_csv(f'player_stats_{timestamp}.csv', index=False)
        print(f"\nStatistics saved to player_stats_{timestamp}.csv")
    else:
        print("No valid player statistics were collected.")
    
except Exception as e:
    logging.error(f"Error in player statistics collection: {str(e)}")
    raise
# Out:
# 2024-11-07 17:42:12,367 - INFO - Collecting player statistics...
# 2024-11-07 17:42:12,368 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\players.graphql
# 2024-11-07 17:42:12,372 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": null}}
# 2024-11-07 17:42:13,032 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"18932","nickname":"AG Nuke","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52314","name":"CS2-1"},"private":false}},{"node":{"id":"18933","nickname":"BadjoSP","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52314","name":"CS2-1"},"private":false}},{"node":{"id":"18934","nickname":"wunder","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52314","name":"CS2-1"},"private":false}},{"node":{"id":"18935","nickname":"Bulletito","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52315","name":"CS2-2"},"private":false}},{"node":{"id":"18936","nickname":"AGmurdercore","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52315","name":"CS2-2"},"private":false}},{"node":{"id":"18937","nickname":"Hello 21","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52314","name":"CS2-1"},"private":false}},{"node":{"id":"18938","nickname":"perrch","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52315","name":"CS2-2"},"private":false}},{"node":{"id":"19268","nickname":"Hoggi`","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19270","nickname":"Dktruman - Twitch","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19272","nickname":"I miss her...","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19274","nickname":"Furpants","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19276","nickname":"xV1nc3e","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19339","nickname":"Penguino","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19340","nickname":"Bobis ♥V","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19341","nickname":"daejv ツ","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19342","nickname":"milo155","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19343","nickname":"veriol","title":{"id":"28","name":"Counter Strike 2"},"private":false}},{"node":{"id":"19355","nickname":"f0","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52355","name":"Grid test 2"},"private":false}},{"node":{"id":"19356","nickname":"BulStreamObserver2","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50070","name":"Grid test 1"},"private":false}},{"node":{"id":"19537","nickname":"jambo.","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52356","name":"Passion UA"},"private":false}},{"node":{"id":"19538","nickname":"marat2k 風速","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52133","name":"L&G"},"private":false}},{"node":{"id":"19539","nickname":"s-chilla","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52356","name":"Passion UA"},"private":false}},{"node":{"id":"19540","nickname":"jackasmo","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52356","name":"Passion UA"},"private":false}},{"node":{"id":"19541","nickname":"zeRRoFIX","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52356","name":"Passion UA"},"private":false}},{"node":{"id":"19549","nickname":"2high","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49502","name":"ENCE Academy"},"private":false}},{"node":{"id":"43856","nickname":"chawzyyy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53618","name":"Johnny Speeds"},"private":false}},{"node":{"id":"43890","nickname":"arvid","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53713","name":"HEIMO"},"private":false}},{"node":{"id":"43891","nickname":"ykis","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53713","name":"HEIMO"},"private":false}},{"node":{"id":"43892","nickname":"japE","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53713","name":"HEIMO"},"private":false}},{"node":{"id":"43893","nickname":"welho","title":{"id":"28 ...
# 2024-11-07 17:42:13,032 - INFO - Processed page 1 - Got 50 items
# 2024-11-07 17:42:15,378 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0NBQkVDCwtaCws="}}
# 2024-11-07 17:42:16,070 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"46834","nickname":"hagmeister","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50020","name":"777"},"private":false}},{"node":{"id":"46836","nickname":"Affava","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50020","name":"777"},"private":false}},{"node":{"id":"46838","nickname":"MadeInRed","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50020","name":"777"},"private":false}},{"node":{"id":"46840","nickname":"Viktha","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50020","name":"777"},"private":false}},{"node":{"id":"46842","nickname":"wenba","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50020","name":"777"},"private":false}},{"node":{"id":"48296","nickname":"prisma21","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54157","name":"Galorys Academy"},"private":false}},{"node":{"id":"49997","nickname":"T3mpty","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51657","name":"REMBAZA"},"private":false}},{"node":{"id":"50406","nickname":"ms","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53706","name":"NeverPlay"},"private":false}},{"node":{"id":"50410","nickname":"arki","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54010","name":"Turritos"},"private":false}},{"node":{"id":"50412","nickname":"NaOw","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54127","name":"CarritoSpain"},"private":false}},{"node":{"id":"50414","nickname":"ZaCkETiZOR","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53756","name":"TGD Pro"},"private":false}},{"node":{"id":"50416","nickname":"ar4gN","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54127","name":"CarritoSpain"},"private":false}},{"node":{"id":"50417","nickname":"Joey","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53756","name":"TGD Pro"},"private":false}},{"node":{"id":"50697","nickname":"FTKFenix","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53757","name":"Mixzada"},"private":false}},{"node":{"id":"50699","nickname":"Ftu","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53757","name":"Mixzada"},"private":false}},{"node":{"id":"50700","nickname":"goncoff","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53757","name":"Mixzada"},"private":false}},{"node":{"id":"50702","nickname":"denkje","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53757","name":"Mixzada"},"private":false}},{"node":{"id":"50704","nickname":"Virgolino","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53757","name":"Mixzada"},"private":false}},{"node":{"id":"50708","nickname":"trips","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51015","name":"SAW Youngsters"},"private":false}},{"node":{"id":"51611","nickname":"brA+","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51504","name":"GTZ.ESPORTS"},"private":false}},{"node":{"id":"51613","nickname":"M1KA","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54067","name":"Impulse GW"},"private":false}},{"node":{"id":"51615","nickname":"c0mplex","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51771","name":"Agency Clan"},"private":false}},{"node":{"id":"51617","nickname":"MattyMyimb","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51541","name":"EXSAD Gaming"},"private":false}},{"node":{"id":"51619","nickname":"Jayy2s","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51541","name":"EXSAD Gaming"},"private":false}},{"node":{"id":"53694","nickname":"stavn","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49528","name":"Astralis"},"private":false}},{"node":{"id":"54044","nickname":"RUSH","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51290","name":"Nouns"},"private":false}},{"node":{"id":"55313","nickname":"dziugss","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53084","name":"Navi Junior"},"pr ...
# 2024-11-07 17:42:16,071 - INFO - Processed page 2 - Got 50 items
# 2024-11-07 17:42:18,385 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0FFRUZOCwtaCws="}}
# 2024-11-07 17:42:19,060 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"62221","nickname":"FincHY","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51895","name":"Reason"},"private":false}},{"node":{"id":"62223","nickname":"cJe","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51895","name":"Reason"},"private":false}},{"node":{"id":"62225","nickname":"Cha0s","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51895","name":"Reason"},"private":false}},{"node":{"id":"63719","nickname":"Fawx","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53789","name":"Limitless Angels"},"private":false}},{"node":{"id":"63721","nickname":"erin","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53789","name":"Limitless Angels"},"private":false}},{"node":{"id":"63723","nickname":"Celia","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53789","name":"Limitless Angels"},"private":false}},{"node":{"id":"63725","nickname":"mira","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53789","name":"Limitless Angels"},"private":false}},{"node":{"id":"63726","nickname":"bungee","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53789","name":"Limitless Angels"},"private":false}},{"node":{"id":"63732","nickname":"Emy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53538","name":"Revel"},"private":false}},{"node":{"id":"63772","nickname":"phoebe","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51765","name":"shimmer"},"private":false}},{"node":{"id":"63776","nickname":"EMUHLEET","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52285","name":"Karma"},"private":false}},{"node":{"id":"63778","nickname":"artStar","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52285","name":"Karma"},"private":false}},{"node":{"id":"63779","nickname":"rain","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52285","name":"Karma"},"private":false}},{"node":{"id":"63781","nickname":"Ellie","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52285","name":"Karma"},"private":false}},{"node":{"id":"63783","nickname":"olya","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52285","name":"Karma"},"private":false}},{"node":{"id":"64397","nickname":"suma","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49975","name":"Astralis Talent"},"private":false}},{"node":{"id":"64403","nickname":"sSen","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49975","name":"Astralis Talent"},"private":false}},{"node":{"id":"64746","nickname":"VILBy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52068","name":"Aurora YB"},"private":false}},{"node":{"id":"64748","nickname":"gr1ks","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52068","name":"Aurora YB"},"private":false}},{"node":{"id":"64760","nickname":"forkyz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53677","name":"RUBY"},"private":false}},{"node":{"id":"64764","nickname":"tasman","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53677","name":"RUBY"},"private":false}},{"node":{"id":"65064","nickname":"m1QUSE","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52068","name":"Aurora YB"},"private":false}},{"node":{"id":"65199","nickname":"⑳ lcs","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53446","name":"Últimos Romanticos"},"private":false}},{"node":{"id":"65207","nickname":"㉑ JNC","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53830","name":"JOGA DE TERNO"},"private":false}},{"node":{"id":"65215","nickname":"lezy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50948","name":"9z Academy"},"private":false}},{"node":{"id":"65555","nickname":"RoDfps_","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53794","name":"Full House Gaming"},"private":false}},{"node":{"id":"65556","nickname":"shun7","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53794","name ...
# 2024-11-07 17:42:19,062 - INFO - Processed page 3 - Got 50 items
# 2024-11-07 17:42:21,388 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0BFRUNBCwtaCws="}}
# 2024-11-07 17:42:21,998 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"72248","nickname":"AntGuerra","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53811","name":"Kings da Pegada"},"private":false}},{"node":{"id":"72250","nickname":"hK","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50933","name":"Rhyno Esports"},"private":false}},{"node":{"id":"72252","nickname":"FR9","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53811","name":"Kings da Pegada"},"private":false}},{"node":{"id":"72254","nickname":"DpZz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53811","name":"Kings da Pegada"},"private":false}},{"node":{"id":"72596","nickname":"1203456789abcd","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49575","name":"Lynn Vision"},"private":false}},{"node":{"id":"72598","nickname":"MESA","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49575","name":"Lynn Vision"},"private":false}},{"node":{"id":"72600","nickname":"SH!ro.","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49575","name":"Lynn Vision"},"private":false}},{"node":{"id":"72602","nickname":"CDR","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49575","name":"Lynn Vision"},"private":false}},{"node":{"id":"72608","nickname":"Enel","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52149","name":"ATOX"},"private":false}},{"node":{"id":"72610","nickname":"zakder","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52149","name":"ATOX"},"private":false}},{"node":{"id":"72738","nickname":"brain","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50074","name":"AURORA"},"private":false}},{"node":{"id":"72956","nickname":"SpavaQu","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51986","name":"Illuminar gaming"},"private":false}},{"node":{"id":"72999","nickname":"dex","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51318","name":"Eyeballers"},"private":false}},{"node":{"id":"74811","nickname":"-_Chudy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51930","name":"Anonymo"},"private":false}},{"node":{"id":"75216","nickname":"Strope","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50020","name":"777"},"private":false}},{"node":{"id":"75881","nickname":"EspiranTo","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54119","name":"Ex-9INE Academy"},"private":false}},{"node":{"id":"76724","nickname":"Mer","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53813","name":"Asian Kings"},"private":false}},{"node":{"id":"76725","nickname":"Edbooo","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53813","name":"Asian Kings"},"private":false}},{"node":{"id":"76727","nickname":"Akbeast","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53813","name":"Asian Kings"},"private":false}},{"node":{"id":"76729","nickname":"Tar1us","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53813","name":"Asian Kings"},"private":false}},{"node":{"id":"76967","nickname":"Halen","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50835","name":"Detonate"},"private":false}},{"node":{"id":"76968","nickname":"rayxts","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51484","name":"LAG"},"private":false}},{"node":{"id":"76970","nickname":"abp","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53106","name":"Akimbo"},"private":false}},{"node":{"id":"76972","nickname":"weeza","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51484","name":"LAG"},"private":false}},{"node":{"id":"76974","nickname":"alula","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53106","name":"Akimbo"},"private":false}},{"node":{"id":"77194","nickname":"betinho","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53069","name":"Case"},"private":false}},{"node":{"id":"77291","nickname":"hyza","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53998","name":"L ...
# 2024-11-07 17:42:21,999 - INFO - Processed page 4 - Got 50 items
# 2024-11-07 17:42:24,397 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC09HQU9ACwtaCws="}}
# 2024-11-07 17:42:25,025 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"82553","nickname":"Mellow","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51434","name":"Limitless"},"private":false}},{"node":{"id":"85319","nickname":"H4SAN4TOR","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52222","name":"Team Space"},"private":false}},{"node":{"id":"85768","nickname":"tmk","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52192","name":"OMiT"},"private":false}},{"node":{"id":"86827","nickname":"stanf1x","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53999","name":"Dangerous"},"private":false}},{"node":{"id":"86828","nickname":"TERMINA","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53815","name":"Lost Recognition"},"private":false}},{"node":{"id":"87888","nickname":"waterfaLLZ","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52222","name":"Team Space"},"private":false}},{"node":{"id":"88945","nickname":"Nivera","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52244","name":"Revenant"},"private":false}},{"node":{"id":"88982","nickname":"krAGHHHH","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53693","name":"WOPA Esport"},"private":false}},{"node":{"id":"89549","nickname":"prn","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53826","name":"ADEPTS"},"private":false}},{"node":{"id":"89551","nickname":"cHeuuuuk'","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53826","name":"ADEPTS"},"private":false}},{"node":{"id":"89553","nickname":"Oxbrandd","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53826","name":"ADEPTS"},"private":false}},{"node":{"id":"89555","nickname":"Chucky","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53826","name":"ADEPTS"},"private":false}},{"node":{"id":"89557","nickname":"Tarkky","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53826","name":"ADEPTS"},"private":false}},{"node":{"id":"90041","nickname":"LethJ","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49997","name":"MASONIC"},"private":false}},{"node":{"id":"91262","nickname":"h1ghnesS","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53827","name":"Fluffy Gangsters"},"private":false}},{"node":{"id":"91264","nickname":"Djon8","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53827","name":"Fluffy Gangsters"},"private":false}},{"node":{"id":"91268","nickname":"takanashi","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53827","name":"Fluffy Gangsters"},"private":false}},{"node":{"id":"92600","nickname":"skcH","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53501","name":"ROSOMAHA Team"},"private":false}},{"node":{"id":"92602","nickname":"3ippoch","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53501","name":"ROSOMAHA Team"},"private":false}},{"node":{"id":"92603","nickname":"maggent","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53501","name":"ROSOMAHA Team"},"private":false}},{"node":{"id":"92607","nickname":"Dengzoe","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53825","name":"XI"},"private":false}},{"node":{"id":"92609","nickname":"Scr0b","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53825","name":"XI"},"private":false}},{"node":{"id":"92612","nickname":"foam","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53825","name":"XI"},"private":false}},{"node":{"id":"93359","nickname":"Bambosh","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53668","name":"9INE Academy"},"private":false}},{"node":{"id":"97284","nickname":"kln","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54160","name":"2070"},"private":false}},{"node":{"id":"97735","nickname":"baccseven","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54157","name":"Galorys Academy"},"private":false}},{"node":{"id":"97739","nickname":"✓ ★ ㉑ Tineu","title":{"id":"28","name":"Counter Strike 2"},"te ...
# 2024-11-07 17:42:25,026 - INFO - Processed page 5 - Got 50 items
# 2024-11-07 17:42:27,410 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0ZHRk5ETwsLWgsL"}}
# 2024-11-07 17:42:28,092 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"101940","nickname":"Zhenn","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54121","name":"Planet Express"},"private":false}},{"node":{"id":"101975","nickname":"FRIZZY","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53848","name":"After Hours"},"private":false}},{"node":{"id":"101977","nickname":"Redman","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53848","name":"After Hours"},"private":false}},{"node":{"id":"101979","nickname":"Roar","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53848","name":"After Hours"},"private":false}},{"node":{"id":"101981","nickname":"Icarus","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52101","name":"GTZ Esports"},"private":false}},{"node":{"id":"101982","nickname":"Freaky","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53848","name":"After Hours"},"private":false}},{"node":{"id":"101983","nickname":"BurneyProMod","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53847","name":"Evil Space Wizards"},"private":false}},{"node":{"id":"101985","nickname":"Vitalz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53847","name":"Evil Space Wizards"},"private":false}},{"node":{"id":"101987","nickname":"mythii","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53847","name":"Evil Space Wizards"},"private":false}},{"node":{"id":"101989","nickname":"glxy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"101991","nickname":"Tiski","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53412","name":"ENIGMA"},"private":false}},{"node":{"id":"102016","nickname":"lambchoppington 3","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54107","name":"Alter Iron Club"},"private":false}},{"node":{"id":"102024","nickname":"misha","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54107","name":"Alter Iron Club"},"private":false}},{"node":{"id":"102026","nickname":"yoda","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53851","name":"Parkers Money Crew"},"private":false}},{"node":{"id":"102030","nickname":"praze","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53851","name":"Parkers Money Crew"},"private":false}},{"node":{"id":"102032","nickname":"Laxufy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53851","name":"Parkers Money Crew"},"private":false}},{"node":{"id":"102034","nickname":"pianoman","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53851","name":"Parkers Money Crew"},"private":false}},{"node":{"id":"102450","nickname":"GHOST","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53845","name":"Wave Esports"},"private":false}},{"node":{"id":"102452","nickname":"XCR_","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53845","name":"Wave Esports"},"private":false}},{"node":{"id":"102454","nickname":"sjN","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53845","name":"Wave Esports"},"private":false}},{"node":{"id":"102456","nickname":"Spexy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53845","name":"Wave Esports"},"private":false}},{"node":{"id":"102458","nickname":"syncD","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53845","name":"Wave Esports"},"private":false}},{"node":{"id":"102564","nickname":"KennyTexas","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53844","name":"atomic"},"private":false}},{"node":{"id":"102565","nickname":"DanielSw0w","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53844","name":"atomic"},"private":false}},{"node":{"id":"102566","nickname":"Kranoli","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53844","name":"atomic"},"private":false}},{"node":{"id":"102567","nickname":"Reverbzzz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53844","name":"atomic"},"pri ...
# 2024-11-07 17:42:28,093 - INFO - Processed page 6 - Got 50 items
# 2024-11-07 17:42:30,515 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0ZGR09ATwsLWgsL"}}
# 2024-11-07 17:42:31,281 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"110880","nickname":"Kleepok","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51651","name":"Gameinside"},"private":false}},{"node":{"id":"110882","nickname":"Shleper","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51651","name":"Gameinside"},"private":false}},{"node":{"id":"110884","nickname":"noeN","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51652","name":"Seight"},"private":false}},{"node":{"id":"110885","nickname":"myata","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51658","name":"NightRaid"},"private":false}},{"node":{"id":"110887","nickname":"yakut","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51659","name":"Purple Haze"},"private":false}},{"node":{"id":"110889","nickname":"ZLOBAAAAAAAA","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51652","name":"Seight"},"private":false}},{"node":{"id":"110891","nickname":"sashqua","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51652","name":"Seight"},"private":false}},{"node":{"id":"110893","nickname":"Rhys","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53846","name":"The Last Resort"},"private":false}},{"node":{"id":"110895","nickname":"MMS","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51403","name":"K10"},"private":false}},{"node":{"id":"110897","nickname":"Frontsiderr","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54068","name":"DevilsOne"},"private":false}},{"node":{"id":"110899","nickname":"-ZEMO","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54068","name":"DevilsOne"},"private":false}},{"node":{"id":"110901","nickname":"PeTeRoOo","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54068","name":"DevilsOne"},"private":false}},{"node":{"id":"110903","nickname":"suonko","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54068","name":"DevilsOne"},"private":false}},{"node":{"id":"110905","nickname":"Pelle","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52201","name":"lajtbitexe"},"private":false}},{"node":{"id":"110926","nickname":"rem1x","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53712","name":"Vikings KR"},"private":false}},{"node":{"id":"110928","nickname":"realz1n","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53712","name":"Vikings KR"},"private":false}},{"node":{"id":"110930","nickname":"zmb","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53712","name":"Vikings KR"},"private":false}},{"node":{"id":"110932","nickname":"ksloks","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52023","name":"ODDIK"},"private":false}},{"node":{"id":"110934","nickname":"honda","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53712","name":"Vikings KR"},"private":false}},{"node":{"id":"110936","nickname":"shoowtime","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52238","name":"Bounty Hunters"},"private":false}},{"node":{"id":"110938","nickname":"Reix","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52238","name":"Bounty Hunters"},"private":false}},{"node":{"id":"110940","nickname":"KAISERzy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52238","name":"Bounty Hunters"},"private":false}},{"node":{"id":"110942","nickname":"bnc77","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52238","name":"Bounty Hunters"},"private":false}},{"node":{"id":"110944","nickname":"piriajr","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51311","name":"Fluxo"},"private":false}},{"node":{"id":"110954","nickname":"yaph","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51657","name":"REMBAZA"},"private":false}},{"node":{"id":"110956","nickname":"dera","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51652","name":"Seight"},"private":false}},{"node":{"id":"110958","nickname":"PARKER","title":{"id":"28","name":"Counter S ...
# 2024-11-07 17:42:31,282 - INFO - Processed page 7 - Got 50 items
# 2024-11-07 17:42:33,428 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0ZGRkdGQgsLWgsL"}}
# 2024-11-07 17:42:34,091 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"111023","nickname":"iDk","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53710","name":"inSanitY Sports"},"private":false}},{"node":{"id":"111025","nickname":"⑳ shz-_-","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53710","name":"inSanitY Sports"},"private":false}},{"node":{"id":"111027","nickname":"cass1n","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53710","name":"inSanitY Sports"},"private":false}},{"node":{"id":"111029","nickname":"pesadelo ;)","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53710","name":"inSanitY Sports"},"private":false}},{"node":{"id":"111030","nickname":"f4stzin","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53710","name":"inSanitY Sports"},"private":false}},{"node":{"id":"111077","nickname":"Flicky","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53846","name":"The Last Resort"},"private":false}},{"node":{"id":"111107","nickname":"SiKO","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49731","name":"Team Brute"},"private":false}},{"node":{"id":"111146","nickname":"lauNX","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52244","name":"Revenant"},"private":false}},{"node":{"id":"111170","nickname":"lenci","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53919","name":"LA CHAMPIONS LIGA"},"private":false}},{"node":{"id":"111172","nickname":"reversive","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53711","name":"KRU Esports"},"private":false}},{"node":{"id":"111174","nickname":"atarax1a","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53711","name":"KRU Esports"},"private":false}},{"node":{"id":"111176","nickname":"laser","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53711","name":"KRU Esports"},"private":false}},{"node":{"id":"111178","nickname":"righi","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53711","name":"KRU Esports"},"private":false}},{"node":{"id":"111180","nickname":"GYZER","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50113","name":"FURIA Academy"},"private":false}},{"node":{"id":"111182","nickname":"mello","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54148","name":"Game Hunters"},"private":false}},{"node":{"id":"111184","nickname":"souz4h","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50113","name":"FURIA Academy"},"private":false}},{"node":{"id":"111186","nickname":"Jotag3","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"50113","name":"FURIA Academy"},"private":false}},{"node":{"id":"111188","nickname":"max","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51864","name":"9z Team"},"private":false}},{"node":{"id":"111193","nickname":"⑳ JLK","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51146","name":"MIBR Academy"},"private":false}},{"node":{"id":"111195","nickname":"★ ⑳ bobz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51146","name":"MIBR Academy"},"private":false}},{"node":{"id":"111197","nickname":"Markz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51588","name":"paiN Academy"},"private":false}},{"node":{"id":"111199","nickname":"mlhzin","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51146","name":"MIBR Academy"},"private":false}},{"node":{"id":"111201","nickname":"brn$","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51146","name":"MIBR Academy"},"private":false}},{"node":{"id":"111203","nickname":"lukiz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53712","name":"Vikings KR"},"private":false}},{"node":{"id":"111238","nickname":"matios","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52023","name":"ODDIK"},"private":false}},{"node":{"id":"111240","nickname":"WOOD7","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52023","name":"ODDIK"},"private":false}},{"node":{"id":"111 ...
# 2024-11-07 17:42:34,093 - INFO - Processed page 8 - Got 50 items
# 2024-11-07 17:42:36,432 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0ZGRkVORwsLWgsL"}}
# 2024-11-07 17:42:37,073 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"111292","nickname":"Astra","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53869","name":"Team France"},"private":false}},{"node":{"id":"111294","nickname":"Rachel","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53869","name":"Team France"},"private":false}},{"node":{"id":"111296","nickname":"Chanti","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53870","name":"AaB Female"},"private":false}},{"node":{"id":"111298","nickname":"Hanz1","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53870","name":"AaB Female"},"private":false}},{"node":{"id":"111299","nickname":"Zygimage","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53870","name":"AaB Female"},"private":false}},{"node":{"id":"111301","nickname":"Tipsie","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53870","name":"AaB Female"},"private":false}},{"node":{"id":"111302","nickname":"Dewi","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53870","name":"AaB Female"},"private":false}},{"node":{"id":"111304","nickname":"Anotka","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53871","name":"CENSORED"},"private":false}},{"node":{"id":"111306","nickname":"icytears","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53871","name":"CENSORED"},"private":false}},{"node":{"id":"111308","nickname":"metori","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53871","name":"CENSORED"},"private":false}},{"node":{"id":"111310","nickname":"c0ldhurt","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53871","name":"CENSORED"},"private":false}},{"node":{"id":"111312","nickname":"g1tsune","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53871","name":"CENSORED"},"private":false}},{"node":{"id":"111317","nickname":"t4tty","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53872","name":"Dreamcatchers"},"private":false}},{"node":{"id":"111319","nickname":"f6tal","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53872","name":"Dreamcatchers"},"private":false}},{"node":{"id":"111321","nickname":"Elizabeth-","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53872","name":"Dreamcatchers"},"private":false}},{"node":{"id":"111323","nickname":"wieenN-","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53872","name":"Dreamcatchers"},"private":false}},{"node":{"id":"111324","nickname":"k175un4","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53872","name":"Dreamcatchers"},"private":false}},{"node":{"id":"111326","nickname":"st8cy","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53873","name":"OneDay"},"private":false}},{"node":{"id":"111327","nickname":"aiveri","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53873","name":"OneDay"},"private":false}},{"node":{"id":"111329","nickname":"v1spel","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53873","name":"OneDay"},"private":false}},{"node":{"id":"111331","nickname":"takioka","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53873","name":"OneDay"},"private":false}},{"node":{"id":"111333","nickname":"irbitka","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53873","name":"OneDay"},"private":false}},{"node":{"id":"111337","nickname":"Madam","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53875","name":"K10 Ashes"},"private":false}},{"node":{"id":"111339","nickname":"Natrise","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53875","name":"K10 Ashes"},"private":false}},{"node":{"id":"111341","nickname":"tess","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53875","name":"K10 Ashes"},"private":false}},{"node":{"id":"111342","nickname":"Moraltis","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53875","name":"K10 Ashes"},"private":false}},{"node":{"id":"111343","nickname":"oona1","title":{"id":"28","name":" ...
# 2024-11-07 17:42:37,074 - INFO - Processed page 9 - Got 50 items
# 2024-11-07 17:42:39,444 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0ZGRkROTwsLWgsL"}}
# 2024-11-07 17:42:40,138 - INFO - <<< {"data":{"players":{"edges":[{"node":{"id":"111400","nickname":"olimp","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53754","name":"Rebels Gaming"},"private":false}},{"node":{"id":"111404","nickname":"ex1st","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51930","name":"Anonymo"},"private":false}},{"node":{"id":"111406","nickname":"U10m3k","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54079","name":"Haspers Team"},"private":false}},{"node":{"id":"111408","nickname":"fr3nd","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51552","name":"Permitta"},"private":false}},{"node":{"id":"111410","nickname":"Sobol","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53960","name":"ex-Enterprise Esports"},"private":false}},{"node":{"id":"111411","nickname":"l3abaYaga","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"54079","name":"Haspers Team"},"private":false}},{"node":{"id":"111413","nickname":"bcwila","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53874","name":"BlueJays FE"},"private":false}},{"node":{"id":"111419","nickname":"Noktse","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52060","name":"Bestia"},"private":false}},{"node":{"id":"111421","nickname":"luchov","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52060","name":"Bestia"},"private":false}},{"node":{"id":"111423","nickname":"naz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52060","name":"Bestia"},"private":false}},{"node":{"id":"111425","nickname":"tomaszin","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52060","name":"Bestia"},"private":false}},{"node":{"id":"111427","nickname":"zock","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52060","name":"Bestia"},"private":false}},{"node":{"id":"111428","nickname":"✓   ⑳ levi","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51734","name":"Sharks Youngsters"},"private":false}},{"node":{"id":"111430","nickname":"xinesJesus","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51734","name":"Sharks Youngsters"},"private":false}},{"node":{"id":"111432","nickname":"Longo","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51734","name":"Sharks Youngsters"},"private":false}},{"node":{"id":"111434","nickname":"RenanZin","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"51146","name":"MIBR Academy"},"private":false}},{"node":{"id":"111438","nickname":"⑳ nsherzs","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52060","name":"Bestia"},"private":false}},{"node":{"id":"111440","nickname":"hoax","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"49558","name":"Sharks"},"private":false}},{"node":{"id":"111442","nickname":"ninjaZ","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53389","name":"Galorys"},"private":false}},{"node":{"id":"111444","nickname":"tomate","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53389","name":"Galorys"},"private":false}},{"node":{"id":"111446","nickname":"detr0ittj","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53389","name":"Galorys"},"private":false}},{"node":{"id":"111448","nickname":"happ","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"53951","name":"Nitro"},"private":false}},{"node":{"id":"111450","nickname":"ckzao","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52153","name":"Intense"},"private":false}},{"node":{"id":"111452","nickname":"fREQ","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52153","name":"Intense"},"private":false}},{"node":{"id":"111454","nickname":"keiz","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52153","name":"Intense"},"private":false}},{"node":{"id":"111456","nickname":"mxa","title":{"id":"28","name":"Counter Strike 2"},"team":{"id":"52153","name":"Intense"},"private":false}},{"node":{"id":"111458","nickname":"diozera","title":{"id":"28","name":"Counter ...
# 2024-11-07 17:42:40,139 - INFO - Processed page 10 - Got 50 items
# 2024-11-07 17:42:42,455 - INFO - >>> {"query": "query GetAllPlayers($first: Int!, $after: Cursor, $filter: PlayerFilter) {\n  players(first: $first, after: $after, filter: $filter) {\n    edges {\n      node {\n        id\n        nickname\n        title {\n          id\n          name\n        }\n        team {\n          id\n          name\n        }\n        private\n      }\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"filter": {"titleId": "28"}, "first": 50, "after": "PjMLC1oLC0ZGRkJHQgsLWgsL"}}
# ...
# 2024-11-07 18:31:18,721 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119135", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:31:19,569 - INFO - <<< {"data":{"playerStatistics":{"id":"119135","series":{"count":2,"kills":{"sum":86,"min":34,"max":52,"avg":43.0},"deaths":{"sum":85,"min":39,"max":46,"avg":42.5}},"game":{"count":6,"wins":[{"count":4,"percentage":66.66666666666666,"streak":{"current":1,"max":3}},{"count":2,"percentage":33.33333333333333,"streak":{"current":0,"max":1}}]}}}}
# 2024-11-07 18:31:21,718 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:31:24,726 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119137", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:31:25,556 - INFO - <<< {"data":{"playerStatistics":{"id":"119137","series":{"count":2,"kills":{"sum":68,"min":34,"max":34,"avg":34.0},"deaths":{"sum":94,"min":41,"max":53,"avg":47.0}},"game":{"count":6,"wins":[{"count":4,"percentage":66.66666666666666,"streak":{"current":1,"max":3}},{"count":2,"percentage":33.33333333333333,"streak":{"current":0,"max":1}}]}}}}
# 2024-11-07 18:31:27,725 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:31:30,736 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119138", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:31:31,630 - INFO - <<< {"data":{"playerStatistics":{"id":"119138","series":{"count":2,"kills":{"sum":68,"min":27,"max":41,"avg":34.0},"deaths":{"sum":88,"min":38,"max":50,"avg":44.0}},"game":{"count":6,"wins":[{"count":4,"percentage":66.66666666666666,"streak":{"current":1,"max":3}},{"count":2,"percentage":33.33333333333333,"streak":{"current":0,"max":1}}]}}}}
# 2024-11-07 18:31:33,734 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:31:36,751 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119309", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:31:37,535 - INFO - <<< {"data":{"playerStatistics":{"id":"119309","series":{"count":1,"kills":{"sum":38,"min":38,"max":38,"avg":38.0},"deaths":{"sum":44,"min":44,"max":44,"avg":44.0}},"game":{"count":2,"wins":[{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}},{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}}]}}}}
# 2024-11-07 18:31:39,760 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:31:42,777 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119311", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:31:43,607 - INFO - <<< {"data":{"playerStatistics":{"id":"119311","series":{"count":1,"kills":{"sum":44,"min":44,"max":44,"avg":44.0},"deaths":{"sum":42,"min":42,"max":42,"avg":42.0}},"game":{"count":2,"wins":[{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}},{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}}]}}}}
# 2024-11-07 18:31:45,780 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:31:48,786 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119346", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:31:49,575 - INFO - <<< {"data":{"playerStatistics":{"id":"119346","series":{"count":2,"kills":{"sum":76,"min":37,"max":39,"avg":38.0},"deaths":{"sum":99,"min":45,"max":54,"avg":49.5}},"game":{"count":6,"wins":[{"count":4,"percentage":66.66666666666666,"streak":{"current":1,"max":2}},{"count":2,"percentage":33.33333333333333,"streak":{"current":0,"max":1}}]}}}}
# 2024-11-07 18:31:51,785 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:31:54,800 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119403", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:31:55,580 - INFO - <<< {"data":{"playerStatistics":{"id":"119403","series":{"count":2,"kills":{"sum":62,"min":24,"max":38,"avg":31.0},"deaths":{"sum":69,"min":33,"max":36,"avg":34.5}},"game":{"count":4,"wins":[{"count":4,"percentage":100.0,"streak":{"current":4,"max":4}},{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}}]}}}}
# 2024-11-07 18:31:57,798 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:32:00,817 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119405", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:32:01,815 - INFO - <<< {"data":{"playerStatistics":{"id":"119405","series":{"count":2,"kills":{"sum":71,"min":35,"max":36,"avg":35.5},"deaths":{"sum":74,"min":32,"max":42,"avg":37.0}},"game":{"count":5,"wins":[{"count":2,"percentage":40.0,"streak":{"current":0,"max":1}},{"count":3,"percentage":60.0,"streak":{"current":2,"max":2}}]}}}}
# 2024-11-07 18:32:03,821 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:32:06,831 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119454", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:32:07,664 - INFO - <<< {"data":{"playerStatistics":{"id":"119454","series":{"count":1,"kills":{"sum":24,"min":24,"max":24,"avg":24.0},"deaths":{"sum":33,"min":33,"max":33,"avg":33.0}},"game":{"count":2,"wins":[{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}},{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}}]}}}}
# 2024-11-07 18:32:09,832 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:32:12,851 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119496", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:32:13,635 - INFO - <<< {"data":{"playerStatistics":{"id":"119496","series":{"count":1,"kills":{"sum":20,"min":20,"max":20,"avg":20.0},"deaths":{"sum":21,"min":21,"max":21,"avg":21.0}},"game":{"count":2,"wins":[{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}},{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}}]}}}}
# 2024-11-07 18:32:15,860 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:32:18,877 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "119696", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:32:19,718 - INFO - <<< {"data":{"playerStatistics":{"id":"119696","series":{"count":1,"kills":{"sum":31,"min":31,"max":31,"avg":31.0},"deaths":{"sum":33,"min":33,"max":33,"avg":33.0}},"game":{"count":2,"wins":[{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}},{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}}]}}}}
# 2024-11-07 18:32:21,879 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:32:24,891 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "120255", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:32:25,648 - INFO - <<< {"data":{"playerStatistics":{"id":"120255","series":{"count":1,"kills":{"sum":23,"min":23,"max":23,"avg":23.0},"deaths":{"sum":19,"min":19,"max":19,"avg":19.0}},"game":{"count":2,"wins":[{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}},{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}}]}}}}
# 2024-11-07 18:32:27,898 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:32:30,911 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "120298", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:32:31,788 - INFO - <<< {"data":{"playerStatistics":{"id":"120298","series":{"count":1,"kills":{"sum":14,"min":14,"max":14,"avg":14.0},"deaths":{"sum":30,"min":30,"max":30,"avg":30.0}},"game":{"count":2,"wins":[{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}},{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}}]}}}}
# 2024-11-07 18:32:33,910 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\player_statistics.graphql
# 2024-11-07 18:32:36,921 - INFO - >>> {"query": "query PlayerStatistics($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    series {\n      count\n      kills {\n        sum\n        min\n        max\n        avg\n      }\n      deaths {\n        sum\n        min\n        max\n        avg\n      }\n    }\n    game {\n      count\n      wins {\n        count\n        percentage\n        streak {\n          current\n          max\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "120300", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-07 18:32:37,750 - INFO - <<< {"data":{"playerStatistics":{"id":"120300","series":{"count":1,"kills":{"sum":13,"min":13,"max":13,"avg":13.0},"deaths":{"sum":28,"min":28,"max":28,"avg":28.0}},"game":{"count":2,"wins":[{"count":2,"percentage":100.0,"streak":{"current":2,"max":2}},{"count":0,"percentage":0.0,"streak":{"current":0,"max":0}}]}}}}
# Statistics saved to player_stats_20241107_1832.csv

# %%
#Comprehenisve Player Stats
# Test player stats collection
test_player_id = "19549"  # 2high from ENCE Academy

# Get the player stats
player_stats = collector.get_comprehensive_player_stats(test_player_id)

# Print basic overview
print(f"\nKey Statistics:")
print(f"Games Played: {player_stats['general']['games_played']}")
print(f"Kills: {player_stats['combat']['kills']['total']}")
print(f"Win Rate: {player_stats['performance']['wins']['percentage']}%")

# Print full stats if you want to inspect
from pprint import pprint
print("\nFull Statistics:")
pprint(player_stats)
# Out:
# 2024-11-13 21:05:51,857 - INFO - Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\comprehensive_player_stats.graphql
# 2024-11-13 21:05:51,870 - INFO - >>> {"query": "query IntrospectionQuery {\n  __schema {\n    queryType {\n      name\n    }\n    mutationType {\n      name\n    }\n    subscriptionType {\n      name\n    }\n    types {\n      ...FullType\n    }\n    directives {\n      name\n      description\n      locations\n      args {\n        ...InputValue\n      }\n    }\n  }\n}\n\nfragment FullType on __Type {\n  kind\n  name\n  description\n  fields(includeDeprecated: true) {\n    name\n    description\n    args {\n      ...InputValue\n    }\n    type {\n      ...TypeRef\n    }\n    isDeprecated\n    deprecationReason\n  }\n  inputFields {\n    ...InputValue\n  }\n  interfaces {\n    ...TypeRef\n  }\n  enumValues(includeDeprecated: true) {\n    name\n    description\n    isDeprecated\n    deprecationReason\n  }\n  possibleTypes {\n    ...TypeRef\n  }\n}\n\nfragment InputValue on __InputValue {\n  name\n  description\n  type {\n    ...TypeRef\n  }\n  defaultValue\n}\n\nfragment TypeRef on __Type {\n  kind\n  name\n  ofType {\n    kind\n    name\n    ofType {\n      kind\n      name\n      ofType {\n        kind\n        name\n        ofType {\n          kind\n          name\n          ofType {\n            kind\n            name\n            ofType {\n              kind\n              name\n              ofType {\n                kind\n                name\n                ofType {\n                  kind\n                  name\n                  ofType {\n                    kind\n                    name\n                  }\n                }\n              }\n            }\n          }\n        }\n      }\n    }\n  }\n}"}
# 2024-11-13 21:05:53,090 - INFO - <<< {"data":{"__schema":{"queryType":{"name":"Query"},"types":[{"kind":"OBJECT","name":"AggregateIntStatistic","description":"The aggregated numerical statistics.","fields":[{"name":"sum","description":"The sum of the statistics' all numerical values.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Int"}},"isDeprecated":false},{"name":"min","description":"The minimum statistics numerical value.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Int"}},"isDeprecated":false},{"name":"max","description":"The maximum statistics numerical value.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Int"}},"isDeprecated":false},{"name":"avg","description":"The average statistics numerical value.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Float"}},"isDeprecated":false},{"name":"ratePerMinute","description":"The rate of the statistics' numerical value per minute.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"OBJECT","name":"RateStatistic"}},"isDeprecated":false}],"interfaces":[]},{"kind":"SCALAR","name":"Boolean","description":"Built-in Boolean"},{"kind":"INPUT_OBJECT","name":"BooleanFilter","description":"Boolean filter for true/false fields.","inputFields":[{"name":"equals","description":"Value to look for, can be nullable.","type":{"kind":"SCALAR","name":"Boolean"}}]},{"kind":"OBJECT","name":"BooleanOccurrenceStatistic","description":"The boolean occurrence statistics.","fields":[{"name":"value","description":"The boolean value to make the calculations for.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Boolean"}},"isDeprecated":false},{"name":"count","description":"The number of occurrences of the value.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Int"}},"isDeprecated":false},{"name":"percentage","description":"The percentage of statistics occurrences.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Float"}},"isDeprecated":false},{"name":"streak","description":"The streak of statistics occurrences.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"OBJECT","name":"OccurrenceStreakStatistic"}},"isDeprecated":false}],"interfaces":[]},{"kind":"INPUT_OBJECT","name":"CharacterFilter","description":"Filter by character.","inputFields":[{"name":"id","description":"Filter by character ID.","type":{"kind":"INPUT_OBJECT","name":"IdFilter"}},{"name":"name","description":"Filter by character name.","type":{"kind":"INPUT_OBJECT","name":"StringFilter"}}]},{"kind":"OBJECT","name":"CsgoPlayerSeriesStatistics","description":"The CSGO player statistics for aggregated series.","fields":[{"name":"count","description":"The number of aggregated series.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"Int"}},"isDeprecated":false},{"name":"kills","description":"The aggregations of kills acquired by the player.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"OBJECT","name":"AggregateIntStatistic"}},"isDeprecated":false},{"name":"killAssistsGiven","description":"The aggregations of enemy kills given by the player.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"OBJECT","name":"AggregateIntStatistic"}},"isDeprecated":false},{"name":"killAssistsReceived","description":"The aggregations of enemy kills received by the player.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"OBJECT","name":"AggregateIntStatistic"}},"isDeprecated":false},{"name":"teamkills","description":"The aggregations of player kills acquired by the player.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"OBJECT","name":"AggregateIntStatistic"}},"isDeprecated":false},{"name":"teamkillAssistsGiven","description":"The aggregations of allied kills given by the player.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"OBJECT","name":"AggregateIntStatistic"}},"isDeprecated":false},{"name":"teamkillAssistsReceived","description":"The aggrega ...
# 2024-11-13 21:05:53,111 - INFO - >>> {"query": "query GetComprehensivePlayerStats($playerId: ID!, $filter: PlayerStatisticsFilter!) {\n  playerStatistics(playerId: $playerId, filter: $filter) {\n    id\n    aggregationSeriesIds\n    series {\n      count\n      kills {\n        sum\n        avg\n        max\n        min\n      }\n      deaths {\n        sum\n        avg\n        max\n        min\n      }\n      firstKill {\n        count\n        percentage\n      }\n    }\n    game {\n      count\n      ... on DefaultPlayerGameStatistics {\n        won {\n          count\n          percentage\n          streak {\n            current\n            max\n          }\n        }\n        money {\n          sum\n          avg\n          max\n        }\n        inventoryValue {\n          avg\n          max\n        }\n        netWorth {\n          avg\n          max\n        }\n        kills {\n          sum\n          avg\n        }\n        deaths {\n          sum\n          avg\n        }\n        unitKills {\n          unitName\n          count {\n            sum\n            avg\n          }\n        }\n      }\n      ... on PlayerGameStatisticsCs2 {\n        damageDealt {\n          sum\n          avg\n          max\n        }\n      }\n      ... on PlayerGameStatisticsCsgo {\n        damageDealt {\n          sum\n          avg\n          max\n        }\n      }\n      ... on PlayerGameStatisticsDota {\n        experiencePoints {\n          sum\n          avg\n          max\n        }\n      }\n      ... on PlayerGameStatisticsLol {\n        experiencePoints {\n          sum\n          avg\n          max\n        }\n        totalMoneyEarned {\n          sum\n          avg\n          max\n        }\n      }\n      ... on PlayerGameStatisticsR6 {\n        damageDealt {\n          sum\n          avg\n          max\n        }\n        healingDealt {\n          sum\n          avg\n        }\n        healingReceived {\n          sum\n          avg\n        }\n      }\n    }\n    segment {\n      type\n      count\n      kills {\n        sum\n        avg\n      }\n      deaths {\n        sum\n        avg\n      }\n      won {\n        count\n        percentage\n      }\n      objectives {\n        type\n        completionCount {\n          sum\n          avg\n        }\n        completedFirst {\n          count\n          percentage\n        }\n      }\n    }\n  }\n}", "variables": {"playerId": "19549", "filter": {"timeWindow": "LAST_3_MONTHS"}}}
# 2024-11-13 21:05:54,439 - INFO - <<< {"data":{"playerStatistics":{"id":"19549","aggregationSeriesIds":["2719960","2719964","2719880","2719883","2726690","2726698","2723217","2723221","2726718","2727413","2727417","2729740","2727343","2727348","2729749","2727358","2729755","2734897","2734905","2739201","2739210","2739217"],"series":{"count":22,"kills":{"sum":750,"avg":34.09090909090909,"max":53,"min":18},"deaths":{"sum":784,"avg":35.63636363636363,"max":47,"min":18},"firstKill":[{"count":21,"percentage":95.45454545454545},{"count":1,"percentage":4.545454545454546}]},"game":{"count":53,"damageDealt":{"sum":86077,"avg":1624.0943396226414,"max":2951}},"segment":[{"type":"round","count":1140,"kills":{"sum":750,"avg":0.6578947368421053},"deaths":{"sum":784,"avg":0.6877192982456141},"won":[{"count":625,"percentage":54.824561403508774},{"count":515,"percentage":45.17543859649123}],"objectives":[{"type":"beginDefuseWithKit","completionCount":{"sum":6,"avg":0.005263157894736842},"completedFirst":[{"count":1134,"percentage":99.47368421052632},{"count":6,"percentage":0.5263157894736842}]},{"type":"beginDefuseWithoutKit","completionCount":{"sum":18,"avg":0.015789473684210527},"completedFirst":[{"count":1128,"percentage":98.94736842105263},{"count":12,"percentage":1.0526315789473684}]},{"type":"explodeBomb","completionCount":{"sum":13,"avg":0.011403508771929825},"completedFirst":[{"count":1127,"percentage":98.85964912280701},{"count":13,"percentage":1.1403508771929824}]},{"type":"plantBomb","completionCount":{"sum":58,"avg":0.05087719298245614},"completedFirst":[{"count":1082,"percentage":94.91228070175438},{"count":58,"percentage":5.087719298245614}]}]}]}}}
# Key Statistics:
# Games Played: 53
# Kills: 750
# Win Rate: 0%
#
# Full Statistics:
# {'combat': {'damage': {'average': 1624.0943396226414,
#                        'max': 2951,
#                        'total': 86077},
#             'deaths': {'average': 35.63636363636363,
#                        'best': 18,
#                        'total': 784,
#                        'worst': 47},
#             'first_kills': {'percentage': 95.45454545454545, 'total': 21},
#             'kills': {'average': 34.09090909090909,
#                       'best': 53,
#                       'total': 750,
#                       'worst': 18}},
#  'economy': {'inventory_value': {'average': 0, 'max': 0},
#              'net_worth': {'average': 0, 'max': 0}},
#  'general': {'games_played': 53, 'series_played': 22},
#  'performance': {'wins': {'count': 0,
#                           'current_streak': 0,
#                           'max_streak': 0,
#                           'percentage': 0}},
#  'player_id': '19549',
#  'segments': [{'combat': {'deaths': {'average': 0.6877192982456141,
#                                      'total': 784},
#                           'kills': {'average': 0.6578947368421053,
#                                     'total': 750}},
#                'count': 1140,
#                'objectives': [{'avg_completions': 0.005263157894736842,
#                                'completions': 6,
#                                'first_completions': {'count': 1134,
#                                                      'percentage': 99.47368421052632},
#                                'type': 'beginDefuseWithKit'},
#                               {'avg_completions': 0.015789473684210527,
#                                'completions': 18,
#                                'first_completions': {'count': 1128,
#                                                      'percentage': 98.94736842105263},
#                                'type': 'beginDefuseWithoutKit'},
#                               {'avg_completions': 0.011403508771929825,
#                                'completions': 13,
#                                'first_completions': {'count': 1127,
#                                                      'percentage': 98.85964912280701},
#                                'type': 'explodeBomb'},
#                               {'avg_completions': 0.05087719298245614,
#                                'completions': 58,
#                                'first_completions': {'count': 1082,
#                                                      'percentage': 94.91228070175438},
#                                'type': 'plantBomb'}],
#                'type': 'round',
#                'win_rate': 54.824561403508774}]}
