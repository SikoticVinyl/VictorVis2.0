# %%
# Imports and Setup
import os
import sys

# Add the grid_collector directory to Python path
grid_collector_path = os.path.dirname(os.getcwd())  # Go up one directory to grid_collector
if grid_collector_path not in sys.path:
    sys.path.insert(0, grid_collector_path)  # Insert at beginning of path for priority
    print(f"Added to path: {grid_collector_path}")

from dotenv import load_dotenv
from src.collector.grid_collector import GridCollector
import logging
import pandas as pd
from datetime import datetime, timedelta

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('grid_collection.log'),
        logging.StreamHandler()
    ]
)
# Out:
# Added to path: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector

# %%
# Configuration and Initialization
# Load configuration
load_dotenv()
api_key = os.getenv('GRID_API_KEY')
if not api_key:
    raise ValueError("GRID_API_KEY environment variable is not set")

try:
    # Initialize collector
    collector = GridCollector(api_key)
    logging.info("Successfully initialized GridCollector")
except Exception as e:
    logging.error(f"Error initializing collector: {str(e)}")
    raise
# Out:
# 2024-11-06 12:55:12,987 - INFO - Successfully initialized GridCollector

# %%
def verify_queries():
    # Get path to queries directory
    notebook_dir = os.getcwd()
    grid_collector_dir = os.path.dirname(notebook_dir)
    queries_dir = os.path.join(grid_collector_dir, 'queries')
    
    print(f"Checking queries directory: {queries_dir}")
    
    # List of required query files
    required_queries = [
        'tournaments.graphql',
        'matches.graphql',
        'players.graphql',
        'statistics.graphql',
        'teams.graphql'
    ]
    
    # Check each file
    print("\nChecking query files:")
    for query in required_queries:
        path = os.path.join(queries_dir, query)
        exists = os.path.exists(path)
        print(f"{'✓' if exists else '✗'} {query}")
        if not exists:
            print(f"  Missing file should be at: {path}")
            
    # If any files are missing, show how to create them
    if any(not os.path.exists(os.path.join(queries_dir, q)) for q in required_queries):
        print("\nMissing query files! Here's how to create them:")
        print(f"1. Create directory: {queries_dir}")
        print("2. Create the following files with their queries:")
        for query in required_queries:
            print(f"   - {query}")

# Run verification
verify_queries()
# Out:
# Checking queries directory: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries
#
# Checking query files:
# ✓ tournaments.graphql
# ✓ matches.graphql
# ✓ players.graphql
# ✓ statistics.graphql
# ✓ teams.graphql

# %%
# Collect Tournament Data
try:
    logging.info("Collecting tournament data...")
    tournaments_df = collector.get_tournaments()
    logging.info(f"Collected {len(tournaments_df)} tournaments")
    
    # Display sample of tournaments
    print("\nSample of tournaments:")
    print(tournaments_df.head())
except Exception as e:
    logging.error(f"Error collecting tournament data: {str(e)}")
    raise
# Out:
# 2024-11-06 12:55:22,276 - INFO - Collecting tournament data...
# 2024-11-06 12:55:22,283 - INFO - >>> {"query": "query IntrospectionQuery {\n  __schema {\n    queryType {\n      name\n    }\n    mutationType {\n      name\n    }\n    subscriptionType {\n      name\n    }\n    types {\n      ...FullType\n    }\n    directives {\n      name\n      description\n      locations\n      args {\n        ...InputValue\n      }\n    }\n  }\n}\n\nfragment FullType on __Type {\n  kind\n  name\n  description\n  fields(includeDeprecated: true) {\n    name\n    description\n    args {\n      ...InputValue\n    }\n    type {\n      ...TypeRef\n    }\n    isDeprecated\n    deprecationReason\n  }\n  inputFields {\n    ...InputValue\n  }\n  interfaces {\n    ...TypeRef\n  }\n  enumValues(includeDeprecated: true) {\n    name\n    description\n    isDeprecated\n    deprecationReason\n  }\n  possibleTypes {\n    ...TypeRef\n  }\n}\n\nfragment InputValue on __InputValue {\n  name\n  description\n  type {\n    ...TypeRef\n  }\n  defaultValue\n}\n\nfragment TypeRef on __Type {\n  kind\n  name\n  ofType {\n    kind\n    name\n    ofType {\n      kind\n      name\n      ofType {\n        kind\n        name\n        ofType {\n          kind\n          name\n          ofType {\n            kind\n            name\n            ofType {\n              kind\n              name\n              ofType {\n                kind\n                name\n                ofType {\n                  kind\n                  name\n                  ofType {\n                    kind\n                    name\n                  }\n                }\n              }\n            }\n          }\n        }\n      }\n    }\n  }\n}"}
# Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\tournaments.graphql
# File exists: True
# 2024-11-06 12:55:23,343 - INFO - <<< {"data":{"__schema":{"queryType":{"name":"Query"},"types":[{"kind":"SCALAR","name":"Boolean","description":"Built-in Boolean"},{"kind":"INPUT_OBJECT","name":"BooleanFilter","description":"Boolean filter for true/false fields.","inputFields":[{"name":"equals","description":"Value to look for, can be nullable.","type":{"kind":"SCALAR","name":"Boolean"}}]},{"kind":"SCALAR","name":"Cursor","description":"Cursor value for pagination."},{"kind":"OBJECT","name":"DataProvider","fields":[{"name":"name","description":"The name of the external data provider.","args":[],"type":{"kind":"NON_NULL","ofType":{"kind":"SCALAR","name":"String"}},"isDeprecated":false},{"name":"description","description":"Description of the data provider.","args":[],"type":{"kind":"SCALAR","name":"String"},"isDeprecated":false}],"interfaces":[]},{"kind":"SCALAR","name":"Date","description":"Date formatted as ISO 8601"},{"kind":"SCALAR","name":"DateTime","description":"DateTime formatted as ISO 8601."},{"kind":"INPUT_OBJECT","name":"DateTimeFilter","description":"Filter by a datetime range.","inputFields":[{"name":"gte","description":"DateTime for the beginning of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}},{"name":"lte","description":"DateTime for the end of the time range (optional), formatted as an ISO date string. Time window includes the given value.","type":{"kind":"SCALAR","name":"String"}}]},{"kind":"SCALAR","name":"Decimal","description":"Decimal number representation."},{"kind":"ENUM","name":"ErrorDetail","enumValues":[{"name":"UNKNOWN","description":"Unknown error.\n\nThis error should only be returned when no other error detail applies.\nIf a client sees an unknown errorDetail, it will be interpreted as UNKNOWN.\n\nHTTP Mapping: 500 Internal Server Error","isDeprecated":false},{"name":"FIELD_NOT_FOUND","description":"The requested field is not found in the schema.\n\nThis differs from `NOT_FOUND` in that `NOT_FOUND` should be used when a\nquery is valid, but is unable to return a result (if, for example, a\nspecific video id doesn't exist). `FIELD_NOT_FOUND` is intended to be\nreturned by the server to signify that the requested field is not known to exist.\nThis may be returned in lieu of failing the entire query.\nSee also `PERMISSION_DENIED` for cases where the\nrequested field is invalid only for the given user or class of users.\n\nHTTP Mapping: 404 Not Found\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_CURSOR","description":"The provided cursor is not valid.\n\nThe most common usage for this error is when a client is paginating\nthrough a list that uses stateful cursors. In that case, the provided\ncursor may be expired.\n\nHTTP Mapping: 404 Not Found\nError Type: NOT_FOUND","isDeprecated":false},{"name":"UNIMPLEMENTED","description":"The operation is not implemented or is not currently supported/enabled.\n\nHTTP Mapping: 501 Not Implemented\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"INVALID_ARGUMENT","description":"The client specified an invalid argument.\n\nNote that this differs from `FAILED_PRECONDITION`.\n`INVALID_ARGUMENT` indicates arguments that are problematic\nregardless of the state of the system (e.g., a malformed file name).\n\nHTTP Mapping: 400 Bad Request\nError Type: BAD_REQUEST","isDeprecated":false},{"name":"DEADLINE_EXCEEDED","description":"The deadline expired before the operation could complete.\n\nFor operations that change the state of the system, this error\nmay be returned even if the operation has completed successfully.\nFor example, a successful response from a server could have been\ndelayed long enough for the deadline to expire.\n\nHTTP Mapping: 504 Gateway Timeout\nError Type: UNAVAILABLE","isDeprecated":false},{"name":"SERVICE_ERROR","description":"Service Error.\n\nThere is a problem with an upstream service.\n\nThis may be returned if a gateway re ...
# 2024-11-06 12:55:23,352 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": null, "first": 50}}
# 2024-11-06 12:55:23,689 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0FBCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0YLC1oLCw==","node":{"id":"1","name":"United Masters League 2018-2019","nameShortened":"UML 1819","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ULC1oLCw==","node":{"id":"2","name":"Dota PIT 2019 Minor","nameShortened":"Dota PIT 2019 Minor","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0QLC1oLCw==","node":{"id":"3","name":"HotShot Series Season 2","nameShortened":"HotShot Series S2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0MLC1oLCw==","node":{"id":"4","name":"Blast Pro Series Miami 2019","nameShortened":"Blast Pro Miami 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ILC1oLCw==","node":{"id":"5","name":"Blast Pro Series Madrid 2019","nameShortened":"BP Madrid 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ELC1oLCw==","node":{"id":"6","name":"ECS Season 7","nameShortened":"ECS Season 7","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ALC1oLCw==","node":{"id":"7","name":"HotShot Series Season 3","nameShortened":"HotShot Season 3","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC08LC1oLCw==","node":{"id":"8","name":"StarLadder ImbaTV Dota 2 Minor Season 2","nameShortened":"StarLadder Minor S2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC04LC1oLCw==","node":{"id":"9","name":"StarLadder ImbaTV Dota 2 Minor Season 2 Finals","nameShortened":"StarLadder S2 Finals","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZHCwtaCws=","node":{"id":"10","name":"Blast Pro Series Los Angeles 2019","nameShortened":"BP Los Angeles 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZGCwtaCws=","node":{"id":"11","name":"Good Game League 2019","nameShortened":"GG League 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZFCwtaCws=","node":{"id":"12","name":"StarLadder Minor CS:GO","nameShortened":"SLTV CS:GO","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZECwtaCws=","node":{"id":"13","name":"Unknown","nameShortened":"UNKNOWN","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZDCwtaCws=","node":{"id":"14","name":"Loot.bet/dota Season 1 2019","nameShortened":"Loot.bet/dota","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0ZCCwtaCws=","node":{"id":"15","name":"CS.MONEY Asian Emperor","nameShortened":"CS.MONEY","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZBCwtaCws=","node":{"id":"16","name":"LOOT.BET/CS SEASON 3","nameShortened":"LOOT.BET/CS S3","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZACwtaCws=","node":{"id":"17","name":"CIS Esports Pro Championship","nameShortened":"CIS Esports Pro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZOCwtaCws=","node":{"id":"19","name":"Blast Pro Moscow Closed Qualifier","nameShortened":"BP Moscow CQ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VFCwtaCws=","node":{"id":"22","name":"ECS Season 8","nameShortened":"ECS S8","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VECwtaCws=","node":{"id":"23","name":"Star Laddar Berlin Major 2019","na ...
# 2024-11-06 12:55:25,286 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0FBCwtaCws=", "first": 50}}
# 2024-11-06 12:55:26,052 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RFQ04LC1oLCw=="},"edges":[{"cursor":"PjMLC1oLC0FACwtaCws=","node":{"id":"67","name":"LOOT.BET Season 5","nameShortened":"LOOT.BET Season 5","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0FPCwtaCws=","node":{"id":"68","name":"WESG 2019 East Europe Closed Qualifier","nameShortened":"WESG 2019 East Europ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0FOCwtaCws=","node":{"id":"69","name":"ESL Brazil Premier League Season 11","nameShortened":"ESL Brazil Premier L","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BHCwtaCws=","node":{"id":"70","name":"ESEA Advanced Season 32 North America","nameShortened":"ESEA Advanced Season","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BGCwtaCws=","node":{"id":"71","name":"ESL Pro League Season 10 Finals","nameShortened":"ESL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BFCwtaCws=","node":{"id":"72","name":"ESEA MDL Season 32 Europe Climber Cup","nameShortened":"ESEA MDL Season 32 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BECwtaCws=","node":{"id":"73","name":"IEM Katowice 2020 Oceania Open Qualifier #1","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BDCwtaCws=","node":{"id":"74","name":"ESEA Open Season 32 Brazil","nameShortened":"ESEA Open Season 32 ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BCCwtaCws=","node":{"id":"75","name":"ESEA Open Season 32 South Africa","nameShortened":"ESEA Open Season 32 ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BBCwtaCws=","node":{"id":"76","name":"POWER Ligaen Season 12","nameShortened":"POWER Ligaen Season ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BACwtaCws=","node":{"id":"77","name":"SECTOR: MOSTBET","nameShortened":"SECTOR: MOSTBET","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BPCwtaCws=","node":{"id":"78","name":"Hainan Supreme Cup ","nameShortened":"Hainan Supreme Cup ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BOCwtaCws=","node":{"id":"79","name":"WESG 2019 North Europe Closed Qualifier","nameShortened":"WESG 2019 North Euro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09HCwtaCws=","node":{"id":"80","name":"Svenska Elitserien Fall 2019","nameShortened":"Svenska Elitserien F","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09GCwtaCws=","node":{"id":"81","name":"Conquerors Insignia 2019","nameShortened":"Conquerors Insignia ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09FCwtaCws=","node":{"id":"82","name":"IEM Katowice 2020 Oceania Open Qualifier #2","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09ECwtaCws=","node":{"id":"83","name":"WESG 2019 APAC Oceania Qualifier","nameShortened":"WESG 2019 APAC Ocean","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09DCwtaCws=","node":{"id":"84","name":"DreamHack Delhi Invitational 2019","nameShortened":"DreamHack Delhi Invi","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC09CCwtaCws=","node":{"id":"8 ...
# 2024-11-06 12:55:28,297 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0RFQ04LC1oLCw==", "first": 50}}
# 2024-11-06 12:55:29,031 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VAQE5FCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RATkALC1oLCw==","node":{"id":"3797","name":"IEM Katowice 2020 North America Open Qualifier 1","nameShortened":"IEM Katowice 2020 No","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZDRUJGCwtaCws=","node":{"id":"14251","name":"NEST Pro 2019 Female","nameShortened":"NEST Pro 2019 Female","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0ZOR05BCwtaCws=","node":{"id":"19096","name":"IEM Katowice 2020 North America Open Qualifier 2","nameShortened":"IEM Katowice 2020 No","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VERUVCCwtaCws=","node":{"id":"23225","name":"ESL Meisterschaft Winter 2019 Finals","nameShortened":"ESL Meisterschaft Wi","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VEQU9CCwtaCws=","node":{"id":"23685","name":"ESEA MDL Season 32 Global Challenge","nameShortened":"ESEA MDL Season 32 G","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCRUBGCwtaCws=","node":{"id":"25271","name":"NCS Grand Finals 2019 @ Fragadelphia 14","nameShortened":"NCS Grand Finals 201","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCQ0ZFCwtaCws=","node":{"id":"25412","name":"EPICENTER 2019","nameShortened":"EPICENTER 2019","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VCQUZECwtaCws=","node":{"id":"25613","name":"ESL Nationals CZSK Season 2 Finals","nameShortened":"ESL Nationals CZSK S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBR0BDCwtaCws=","node":{"id":"26074","name":"Dragon Spirit Cup 2019","nameShortened":"Dragon Spirit Cup 20","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBT0dDCwtaCws=","node":{"id":"26804","name":"Grosvenor CS:GO Championship Season 3","nameShortened":"Grosvenor CS:GO Cham","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VBTkNDCwtaCws=","node":{"id":"26944","name":"Swiss Esports League Fall Season 2019 Finals","nameShortened":"Swiss Esports League","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJDCwtaCws=","node":{"id":"27754","name":"Champions Cup Finals","nameShortened":"Champions Cup Finals","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJCCwtaCws=","node":{"id":"27755","name":"Brasileirão Season 1","nameShortened":"Brasileirão Season ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJBCwtaCws=","node":{"id":"27756","name":"RES Season 1","nameShortened":"RES Season 1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJACwtaCws=","node":{"id":"27757","name":"99Damage League Season 13","nameShortened":"99Damage League Seas","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"},{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAQEJPCwtaCws=","node":{"id":"27758","name":"Aorus League 2019 #4 Finals","nameShortened":"Aorus League 2019 #4","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEJOCwtaCws=","node":{"id":"27759","name":"RES Season 1 Finals","nameShortened":"RES Season 1 Finals","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQEFHCwtaCws=","node":{"id":"27760","name":"Asian DOTA2 Gold Occupation Competition S9","nameSh ...
# 2024-11-06 12:55:31,304 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0VAQE5FCwtaCws=", "first": 50}}
# 2024-11-06 12:55:32,018 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VAT0NPCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VAQE5ECwtaCws=","node":{"id":"27793","name":"Aorus League 2019 #4 Northern Cone","nameShortened":"Aorus League 2019 #4","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5DCwtaCws=","node":{"id":"27794","name":"IEM Katowice 2020 Europe Closed Qualifier","nameShortened":"IEM Katowice 2020 Eu","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5CCwtaCws=","node":{"id":"27795","name":"WINNERS League Season 3 Europe","nameShortened":"WINNERS League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5BCwtaCws=","node":{"id":"27796","name":"Hot Price League","nameShortened":"Hot Price League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAQE5PCwtaCws=","node":{"id":"27798","name":"DreamHack Open Leipzig 2020 Europe Open Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAQE5OCwtaCws=","node":{"id":"27799","name":"OMG BET Cup 2","nameShortened":"OMG BET Cup 2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0dHCwtaCws=","node":{"id":"27800","name":"WINNERS League Season 3 North America","nameShortened":"WINNERS League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dGCwtaCws=","node":{"id":"27801","name":"DreamHack Open Leipzig 2020 North America Open Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dFCwtaCws=","node":{"id":"27802","name":"WESG 2019 Brazil Open Qualifier","nameShortened":"WESG 2019 Brazil Ope","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dECwtaCws=","node":{"id":"27803","name":"DreamHack Open Leipzig 2020 Europe Closed Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dDCwtaCws=","node":{"id":"27804","name":"WESG 2019 Brazil","nameShortened":"WESG 2019 Brazil","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dCCwtaCws=","node":{"id":"27805","name":"DreamHack Open Leipzig 2020 North America Closed Qualifier","nameShortened":"DreamHack Open Leipz","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dBCwtaCws=","node":{"id":"27806","name":"ESEA MDL Season 33 Australia","nameShortened":"ESEA MDL Season 33 A","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dACwtaCws=","node":{"id":"27807","name":"FACEIT Pro League","nameShortened":"FPL","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dPCwtaCws=","node":{"id":"27808","name":"Great Universe Cup","nameShortened":"Great Universe Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0dOCwtaCws=","node":{"id":"27809","name":"LEGENDS.bet L33T Cup","nameShortened":"LEGENDS.bet L33T Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0ZHCwtaCws=","node":{"id":"27810","name":"IEM Katowice 2020 Oceania Closed Qualifier","nameShortened":"IEM Katowice 2020 Oc","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0ZGCwtaCws=","node":{"id":"27811","name":"Masters Tournament Season 4","nameShortened":"Masters Tournament S","pr ...
# 2024-11-06 12:55:34,311 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0VAT0NPCwtaCws=", "first": 50}}
# 2024-11-06 12:55:35,034 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VPR0NGCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VAT0NOCwtaCws=","node":{"id":"27849","name":"Americas Minor North America Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Americas Minor North","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JHCwtaCws=","node":{"id":"27850","name":"Asia Minor Greater China Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Asia Minor Greater C","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JGCwtaCws=","node":{"id":"27851","name":"Asia Minor SEA Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Asia Minor SEA Open ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JFCwtaCws=","node":{"id":"27852","name":"Supreme Masters European Invitational 2020","nameShortened":"Supreme Masters Euro","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JDCwtaCws=","node":{"id":"27854","name":"ESEA MDL Season 33 North America","nameShortened":"ESEA MDL Season 33 N","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JCCwtaCws=","node":{"id":"27855","name":"Asia Challenger League Season 6","nameShortened":"Asia Challenger Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0JBCwtaCws=","node":{"id":"27856","name":"Asia Minor SEA Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Asia Minor SEA Open ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JACwtaCws=","node":{"id":"27857","name":"ESEA MDL Season 33 Europe","nameShortened":"ESEA MDL Season 33 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JPCwtaCws=","node":{"id":"27858","name":"CIS Minor Open Qualifier 1 - ESL One Rio 2020","nameShortened":"CIS Minor Open Quali","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0JOCwtaCws=","node":{"id":"27859","name":"Americas Minor South America Open Qualifier 1 - ESL One Rio 2020","nameShortened":"Americas Minor South","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VAT0FHCwtaCws=","node":{"id":"27860","name":"Brazilian Dota 2 Championships Season 2","nameShortened":"Brazilian Dota 2 Cha","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VAT0FGCwtaCws=","node":{"id":"27861","name":"Red Star Cup Season 3","nameShortened":"Red Star Cup Season ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VATk5PCwtaCws=","node":{"id":"27998","name":"Europe Minor Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Europe Minor Open Qu","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VATk5OCwtaCws=","node":{"id":"27999","name":"Americas Minor North America Open Qualifier 2 - ESL One Rio 2020","nameShortened":"Americas Minor North","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dHCwtaCws=","node":{"id":"28000","name":"Vietnam Pro League Season 3","nameShortened":"Vietnam Pro League S","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dFCwtaCws=","node":{"id":"28002","name":"WESG 2019 Russia Closed Qualifier","nameShortened":"WESG 2019 Russia Clo","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0dECwtaCws=","node":{"id":"28003","name":"CIS Minor Open Qualifier 2 - ESL One Rio 2020","nameShortened":"CIS Minor Open Quali","private" ...
# 2024-11-06 12:55:37,318 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0VPR0NGCwtaCws=", "first": 50}}
# 2024-11-06 12:55:38,067 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0VPRkdECwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VPR0NFCwtaCws=","node":{"id":"28042","name":"WePlay! Dota2 Tug of War: Mad Moon","nameShortened":"WePlay! Dota2 Tug of","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NECwtaCws=","node":{"id":"28043","name":"CBDota - Brazilian Dota 2 Championships 2020","nameShortened":"CBDota - Brazilian D","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NDCwtaCws=","node":{"id":"28044","name":"Epic League Season 1","nameShortened":"Epic League Season 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NCCwtaCws=","node":{"id":"28045","name":"Hainan Master Spring Invitational","nameShortened":"Hainan Master Spring","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0NBCwtaCws=","node":{"id":"28046","name":"GIRLGAMER World Finals 2020","nameShortened":"GIRLGAMER World Fina","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NACwtaCws=","node":{"id":"28047","name":"IEM Katowice 2020","nameShortened":"IEM Katowice 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NPCwtaCws=","node":{"id":"28048","name":"epic29","nameShortened":"epic29","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0NOCwtaCws=","node":{"id":"28049","name":"Samsung GOEXANIMO CS:GO 5X5 #20","nameShortened":"Samsung GOEXANIMO CS","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JHCwtaCws=","node":{"id":"28050","name":"SIGUL Pro League","nameShortened":"SIGUL Pro League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JGCwtaCws=","node":{"id":"28051","name":"Elite Challenge Season 3","nameShortened":"Elite Challenge Seas","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JFCwtaCws=","node":{"id":"28052","name":"BashFest 2020","nameShortened":"BashFest 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JECwtaCws=","node":{"id":"28053","name":"Maxline Winter Madness","nameShortened":"Maxline Winter Madne","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JDCwtaCws=","node":{"id":"28054","name":"EGB Arena of Blood: Closed Qualifier","nameShortened":"EGB Arena of Blood: ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JCCwtaCws=","node":{"id":"28055","name":"LPL Pro Season 1","nameShortened":"LPL Pro Season 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPR0JBCwtaCws=","node":{"id":"28056","name":"LanTrek 2020","nameShortened":"LanTrek 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JACwtaCws=","node":{"id":"28057","name":"Aorus League 2020 #1 Southern Cone","nameShortened":"Aorus League 2020 #1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JPCwtaCws=","node":{"id":"28058","name":"WESG 2019 Russia Finals","nameShortened":"WESG 2019 Russia Fin","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0JOCwtaCws=","node":{"id":"28059","name":"LPL Pro League Season 4","nameShortened":"LPL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPR0FHCwtaCws=","node":{"id":"28060","name":"Masters Tournament Season 5 Group Stage","nameShortened":"Maste ...
# 2024-11-06 12:55:40,330 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0VPRkdECwtaCws=", "first": 50}}
# 2024-11-06 12:55:41,006 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RHT0VECwtaCws="},"edges":[{"cursor":"PjMLC1oLC0VPRkdDCwtaCws=","node":{"id":"28104","name":"Asian Hero League Season 2","nameShortened":"Asian Hero League Se","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdCCwtaCws=","node":{"id":"28105","name":"Red Star Cup Season 4","nameShortened":"Red Star Cup Season ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdBCwtaCws=","node":{"id":"28106","name":"SECTOR: MOSTBET 2","nameShortened":"SECTOR: MOSTBET 2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkdACwtaCws=","node":{"id":"28107","name":"Flashpoint 1","nameShortened":"Flashpoint 1","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkdPCwtaCws=","node":{"id":"28108","name":"Arena of Blood","nameShortened":"Arena of Blood","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkdOCwtaCws=","node":{"id":"28109","name":"ESL Pro League Season 11","nameShortened":"ESL Pro League S11","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZHCwtaCws=","node":{"id":"28110","name":"ESL Pro League Season 11 Europe","nameShortened":"ESL Pro League Seaso","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZGCwtaCws=","node":{"id":"28111","name":"eFire Master League Season 1 North America","nameShortened":"eFire Master League ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZFCwtaCws=","node":{"id":"28112","name":"ESL Australia & NZ Championship Season 10 Qualifier 3","nameShortened":"ESL Australia & NZ C","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZECwtaCws=","node":{"id":"28113","name":"GGBET Championship 2","nameShortened":"GGBET Championship 2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkZDCwtaCws=","node":{"id":"28114","name":"HardCup 6","nameShortened":"HardCup 6","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZCCwtaCws=","node":{"id":"28115","name":"SECTOR: MOSTBET Season 2","nameShortened":"SECTOR: MOSTBET Seas","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZBCwtaCws=","node":{"id":"28116","name":"META '20 Open","nameShortened":"META '20 Open","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZACwtaCws=","node":{"id":"28117","name":"eFire Master League North America","nameShortened":"eFire Master League ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkZPCwtaCws=","node":{"id":"28118","name":"No Major No Problem","nameShortened":"No Major No Problem","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkZOCwtaCws=","node":{"id":"28119","name":"ESEA Advanced Season 33 Europe","nameShortened":"ESEA Advanced Season","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0VPRkVGCwtaCws=","node":{"id":"28121","name":"China Development League Season 2: Promotion","nameShortened":"China Dev League 2 Promotion","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPRkVFCwtaCws=","node":{"id":"28122","name":"WeSave! Charity Play","nameShortened":"WeSave! Charity Play","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0VPQEZGCwtaCws=","node":{"id":"28711","name":"Maxline League Sea ...
# 2024-11-06 12:55:43,338 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0RHT0VECwtaCws=", "first": 50}}
# 2024-11-06 12:55:44,051 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RHT0BBCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RHT0VDCwtaCws=","node":{"id":"30824","name":"Spring Championship","nameShortened":"Spring Championship","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VCCwtaCws=","node":{"id":"30825","name":"SECTOR DOTA 2 Season 2","nameShortened":"SECTOR DOTA 2 Season","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VACwtaCws=","node":{"id":"30827","name":"ESL One: Road To Rio - Europe","nameShortened":"ESL One: Road to Rio 2020","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0VPCwtaCws=","node":{"id":"30828","name":"Saturnbet Spring Championship","nameShortened":"Saturnbet Spring Cha","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0VOCwtaCws=","node":{"id":"30829","name":"Hot Price League Season 3","nameShortened":"Hot Price League Sea","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RHCwtaCws=","node":{"id":"30830","name":"BTS Pro Series","nameShortened":"BTS Pro Series","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RGCwtaCws=","node":{"id":"30831","name":"ESEA MDL Season 33 Europe Relegation","nameShortened":"ESEA MDL Season 33 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RFCwtaCws=","node":{"id":"30832","name":"Oceanic Esports League","nameShortened":"Oceanic Esports Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RECwtaCws=","node":{"id":"30833","name":"Play From Home","nameShortened":"Play From Home","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RDCwtaCws=","node":{"id":"30834","name":"Home Sweet Home Cup 2","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RCCwtaCws=","node":{"id":"30835","name":"Asian Hero League Season 3","nameShortened":"Asian Hero League Se","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0RACwtaCws=","node":{"id":"30837","name":"Home Sweet Home Cup 3","nameShortened":"Home Sweet Home Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0RPCwtaCws=","node":{"id":"30838","name":"Home Sweet Home Cup 4","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0ROCwtaCws=","node":{"id":"30839","name":"Home Sweet Home Cup 5","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NHCwtaCws=","node":{"id":"30840","name":"Home Sweet Home Cup 6","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NGCwtaCws=","node":{"id":"30841","name":"Home Sweet Home Cup 7","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NFCwtaCws=","node":{"id":"30842","name":"Home Sweet Home Cup 8","nameShortened":"Home Sweet Home Cup ","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NECwtaCws=","node":{"id":"30843","name":"ESL One: Road to Rio - CIS Play-in","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT0NDCwtaCws=","node":{"id":"30844","name":"ESL One: Road to Rio - South Ame ...
# 2024-11-06 12:55:46,389 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0RHT0BBCwtaCws=", "first": 50}}
# 2024-11-06 12:55:47,259 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0RGRERPCwtaCws="},"edges":[{"cursor":"PjMLC1oLC0RHT0BPCwtaCws=","node":{"id":"30878","name":"Dota 2 BEAT Invitational Season 9","nameShortened":"Dota 2 BEAT Invitati","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT0BOCwtaCws=","node":{"id":"30879","name":"Betano Masters","nameShortened":"Betano Masters","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09HCwtaCws=","node":{"id":"30880","name":"Hephaestus Cup","nameShortened":"Hephaestus Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09GCwtaCws=","node":{"id":"30881","name":"Isolation Cup","nameShortened":"Isolation Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09FCwtaCws=","node":{"id":"30882","name":"ESEA MDL Season 34 Europe","nameShortened":"ESEA MDL Season 34 E","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09ECwtaCws=","node":{"id":"30883","name":"ESEA MDL Season 34 North America","nameShortened":"ESEA MDL Season 34 N","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09DCwtaCws=","node":{"id":"30884","name":"Elisa Invitational 2020","nameShortened":"Elisa Invitational 2","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09CCwtaCws=","node":{"id":"30885","name":"ESL One: Road to Rio - CIS","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09ACwtaCws=","node":{"id":"30887","name":"ESEA MDL Season 34 Australia","nameShortened":"ESEA MDL Season 34 A","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT09PCwtaCws=","node":{"id":"30888","name":"Vulcan Champion League","nameShortened":"Vulcan Champion Leag","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT09OCwtaCws=","node":{"id":"30889","name":"Realms Collide","nameShortened":"Realms Collide","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05HCwtaCws=","node":{"id":"30890","name":"RDY Cup","nameShortened":"RDY Cup","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05GCwtaCws=","node":{"id":"30891","name":"Betway CS:GO Asia Masters","nameShortened":"Betway CS:GO Asia Masters","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05FCwtaCws=","node":{"id":"30892","name":"OGA Dota PIT 2020 Online","nameShortened":"OGA Dota PIT 2020 On","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05ECwtaCws=","node":{"id":"30893","name":"SEA Dota Invitational 2020","nameShortened":"SEA Dota Invitationa","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05DCwtaCws=","node":{"id":"30894","name":"Dota2 Secondary Professional League 2020","nameShortened":"Dota2 Secondary Prof","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05CCwtaCws=","node":{"id":"30895","name":"HellCase Cup","nameShortened":"HellCase","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0RHT05ACwtaCws=","node":{"id":"30897","name":"FVBet Showmatch","nameShortened":"FVBet Showmatch","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0RHT05PCwtaCws=","node":{"id":"30898","name":"ESL One: Road to Rio - Oceania","nameShortened":"ESL One: Road to Rio","private":false,"titles":[{"id":"1","nam ...
# 2024-11-06 12:55:49,359 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0RGRERPCwtaCws=", "first": 50}}
# ...
# 2024-11-06 12:59:17,669 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0BAQ0BCRwsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BBRkNPTgsLWgsL","node":{"id":"761489","name":"ESL Challenger at DreamHack Summer 2024: Asian Closed Qualifier","nameShortened":"ESL Challenger at Dr","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkNOQwsLWgsL","node":{"id":"761494","name":"ESL Challenger at DreamHack Summer 2024: European Closed Qualifier","nameShortened":"ESL Challenger at Dr","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkNOQgsLWgsL","node":{"id":"761495","name":"ESL Challenger at DreamHack Summer 2024: North American Closed Qualifier","nameShortened":"ESL Challenger at Dr","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkNOQQsLWgsL","node":{"id":"761496","name":"Insomnia 72","nameShortened":"Insomnia 72","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJHTwsLWgsL","node":{"id":"761508","name":"BetBoom Dacha Belgrade 2024: European Qualifier","nameShortened":"BetBoom Dacha Belgra","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJHTgsLWgsL","node":{"id":"761509","name":"European Pro League Season 15 - CS2","nameShortened":"European Pro League Season 15","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGRwsLWgsL","node":{"id":"761510","name":"European Pro League Season 17: Division 1 - Dota 2","nameShortened":"European Pro League S17 D1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGRAsLWgsL","node":{"id":"761513","name":"RES Regional Series: SEA #2","nameShortened":"RES Regional Series:","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGQwsLWgsL","node":{"id":"761514","name":"Esportal LuckyCasino Cup 2024","nameShortened":"Esportal LuckyCasino","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGTwsLWgsL","node":{"id":"761518","name":"Minotaur League","nameShortened":"Minotaur League","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJGTgsLWgsL","node":{"id":"761519","name":"Intel Extreme Masters Chengdu 2024","nameShortened":"Intel Extreme Master","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFRgsLWgsL","node":{"id":"761521","name":"RES Latin American Series #3","nameShortened":"RES Latin American S","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFRQsLWgsL","node":{"id":"761522","name":"Skyesports Masters 2024","nameShortened":"Skyesports Masters 2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQwsLWgsL","node":{"id":"761524","name":"IeSF World Championship 2024 Turkmenistan Qualifier","nameShortened":"IeSF World Champions","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQgsLWgsL","node":{"id":"761525","name":"Tradeit League FE Masters #2","nameShortened":"Tradeit League FE Ma","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQQsLWgsL","node":{"id":"761526","name":"European Pro League Female Season 1","nameShortened":"European Pro League ","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BBRkJFQAsLWgsL","node":{"id":"761527","name":"Impacto Solar 3: Open Qualifier #1","nameShortened":"Impacto Solar 3: Ope","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BBRk5PQgsLWgsL","node":{"id":"761985","name":"ESL Impact Cash Cup: North America - Spring 2024 #7","nameShortened":"ESL Impact Cash Cup:","private":false,"titles":[{"id":"28" ...
# 2024-11-06 12:59:19,849 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0BAQ0BCRwsLWgsL", "first": 50}}
# 2024-11-06 12:59:20,697 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0BAQkdPRQsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BAQ0BCRgsLWgsL","node":{"id":"774751","name":"Elite League Season 2: Southeast Asia Closed Qualifier","nameShortened":"Elite League Season 2: SE Asia","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BAQ0BCRQsLWgsL","node":{"id":"774752","name":"Elite League Season 2: Western Europe Closed Qualifier","nameShortened":"Elite League Season 2: WEU CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BCRAsLWgsL","node":{"id":"774753","name":"Gamers Club Liga Série A: May 2024 (Playoffs only)","nameShortened":"Gamers Club Liga S A: May24 P","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BAQ0BCQwsLWgsL","node":{"id":"774754","name":"Elite League Season 2: China Closed Qualifier","nameShortened":"Elite League Season 2: CN CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BCQgsLWgsL","node":{"id":"774755","name":"Elite League Season 2: Eastern Europe Closed Qualifier","nameShortened":"Elite League Season 2: EEU CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BCQQsLWgsL","node":{"id":"774756","name":"Gamers Club Liga Série A: May 2024 (Playoffs)","nameShortened":"Liga Série A: May 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BBTgsLWgsL","node":{"id":"774769","name":"MESA Nomadic Masters Spring 2024","nameShortened":"MESA Spring 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BPRgsLWgsL","node":{"id":"774781","name":"Thunderpick World Championship 2024 - WILDCARD Qualifier","nameShortened":"Thunderpick WC - WQ","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ0BPTwsLWgsL","node":{"id":"774788","name":"Champion of Champions Tour Season 2 - Europe Series 6","nameShortened":"CCT S2 - EU Series 6","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09HRQsLWgsL","node":{"id":"774802","name":"Circuito Retake Season 8: Take #3","nameShortened":"Circuito Retake S8: Take #3","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09HRAsLWgsL","node":{"id":"774803","name":"Circuito Retake Season 8: Playoffs","nameShortened":"Circuito Retake S8: Playoffs","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09CRAsLWgsL","node":{"id":"774853","name":"YaLLa Compass 2024","nameShortened":"YaLLa Compass 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09ATgsLWgsL","node":{"id":"774879","name":"Elite League Season 2: Southeast Asia Closed Qualifier","nameShortened":"Elite League S2: SEA CQ","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ09OQQsLWgsL","node":{"id":"774896","name":"Champion of Champions Tour Dota 2 Series 1","nameShortened":"CCT Dota 2 Series 1","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ09OQAsLWgsL","node":{"id":"774897","name":"FiReLEAGUE Global Finals","nameShortened":"FiReLEAGUE Global Finals","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ09OTwsLWgsL","node":{"id":"774898","name":"United21 South America Season 1","nameShortened":"United21 SA S1","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQ05HQAsLWgsL","node":{"id":"774907","name":"European Pro League Season 19: Division 2 - Dota 2","nameShortened":"EPL Season 19 D2","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQ05 ...
# 2024-11-06 12:59:22,854 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0BAQkdPRQsLWgsL", "first": 50}}
# 2024-11-06 12:59:23,593 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":true,"endCursor":"PjMLC1oLC0BAQkNGQQsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BAQkdPRAsLWgsL","node":{"id":"775083","name":"Thunderpick World Championship 2024 - EU Qualifier #2","nameShortened":"Thunderpick WC 2024 - EU Q2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkdPQwsLWgsL","node":{"id":"775084","name":"Champion of Champions Tour Dota 2 Series 3","nameShortened":"CCT Dota 2 Series 3","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkdOTwsLWgsL","node":{"id":"775098","name":"EPL World Series: America Season 13 - Dota 2","nameShortened":"EPL World Series: America S13","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkZGTwsLWgsL","node":{"id":"775118","name":"Prodigy Series #1","nameShortened":"Prodigy Series #1","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZFRgsLWgsL","node":{"id":"775121","name":"European Pro League Season 18","nameShortened":"EPL Season 18","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZFQQsLWgsL","node":{"id":"775126","name":"Champion of Champions Tour Season 2 - North America Series 3","nameShortened":"CCT S2 - NA Series 3","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZFQAsLWgsL","node":{"id":"775127","name":"Champion of Champions Tour Season 2 - Europe Series 12","nameShortened":"CCT S2 - EU Series 12","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZEQgsLWgsL","node":{"id":"775135","name":"Prodigy Series #2","nameShortened":"Prodigy Series #2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZCRgsLWgsL","node":{"id":"775151","name":"Gamers Club Liga Série A: August 2024","nameShortened":"Gamers Club Liga S-A August 24","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZCQgsLWgsL","node":{"id":"775155","name":"United21 Season 19","nameShortened":"United21 Season 19","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZCTwsLWgsL","node":{"id":"775158","name":"European Pro League Season 20: Division 2 - CS2 (OLD)","nameShortened":"EPL S20: Division 2 CS2 (OLD)","private":false,"titles":[{"id":"1","name":"Counter Strike: Global Offensive"}]}},{"cursor":"PjMLC1oLC0BAQkZBRwsLWgsL","node":{"id":"775160","name":"European Pro League Season 20: Division 2 - CS2","nameShortened":"EPL S20 Division 2 - CS2","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZARwsLWgsL","node":{"id":"775170","name":"Fragicago '24","nameShortened":"Fragicago '24","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZARgsLWgsL","node":{"id":"775171","name":"Champion of Champions Tour Season 2 - Europe Series 13","nameShortened":"CCT Europe S2 Series 13","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZARAsLWgsL","node":{"id":"775173","name":"Champion of Champions Tour Season 2 - Europe Series 14","nameShortened":"CCT Europe S2 Series 14","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZAQgsLWgsL","node":{"id":"775175","name":"Ljósleiðara deildin 2024","nameShortened":"Ljósleiðara deildin 2024","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkZORgsLWgsL","node":{"id":"775191","name":"Galaxy Battle #1","nameShortened":"Galaxy Battle #1","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkVHRQsLWgsL","node":{"id":"775202","name":"A1 Gaming League S9","nameShortened":"A1 Gaming League S9","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cur ...
# 2024-11-06 12:59:25,869 - INFO - >>> {"query": "query GetTournaments($first: Int!, $after: Cursor) {\n  tournaments(first: $first, after: $after) {\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n    edges {\n      cursor\n      node {\n        id\n        name\n        nameShortened\n        startDate\n        endDate\n        private\n        titles {\n          id\n          name\n        }\n      }\n    }\n    totalCount\n  }\n}", "variables": {"after": "PjMLC1oLC0BAQkNGQQsLWgsL", "first": 50}}
# 2024-11-06 12:59:26,543 - INFO - <<< {"data":{"tournaments":{"pageInfo":{"hasNextPage":false,"endCursor":"PjMLC1oLC0BAQkNFQwsLWgsL"},"edges":[{"cursor":"PjMLC1oLC0BAQkNGQAsLWgsL","node":{"id":"775417","name":"Perfect World Shanghai Major 2024: Asia-Pacific RMR","nameShortened":"Asia-Pacific RMR","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}},{"cursor":"PjMLC1oLC0BAQkNFRQsLWgsL","node":{"id":"775422","name":"Summoner's Cup","nameShortened":"Summoner's Cup","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkNFRAsLWgsL","node":{"id":"775423","name":"Champion of Champions Tour Dota 2 Series 5","nameShortened":"CCT Dota 2 Series 5","private":false,"titles":[{"id":"2","name":"Defense of the Ancients 2"}]}},{"cursor":"PjMLC1oLC0BAQkNFQwsLWgsL","node":{"id":"775424","name":"Champion of Champions Tour Season 2 - Europe Series 15","nameShortened":"CCT Europe S2 Series 15","private":false,"titles":[{"id":"28","name":"Counter Strike 2"}]}}],"totalCount":4054}}}
# 2024-11-06 12:59:26,546 - ERROR - Error collecting tournament data: 'node'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:133, in GridCollector.get_tournaments(self)
#     132 for edge in self._paginated_query(query, {}, self.central_client):
# --> 133     tournament = edge['node']
#     134     results.append({
#     135         'id': tournament['id'],
#     136         'name': tournament['name'],
#     137         'name_short': tournament['nameShortened']
#     138     })
#
# KeyError: 'node'
#
# During handling of the above exception, another exception occurred:
#
# GridAPIError                              Traceback (most recent call last)
# Cell In[4], line 4
#       2 try:
#       3     logging.info("Collecting tournament data...")
# ----> 4     tournaments_df = collector.get_tournaments()
#       5     logging.info(f"Collected {len(tournaments_df)} tournaments")
#       7     # Display sample of tournaments
#
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:142, in GridCollector.get_tournaments(self)
#     140     return pd.DataFrame(results)
#     141 except Exception as e:
# --> 142     raise handle_api_error(e)
#
# GridAPIError: 'node'

# %%
# Collect Match Data
try:
    logging.info("Collecting match data...")
    matches_df = collector.get_matches(days=7)
    logging.info(f"Collected {len(matches_df)} matches")
    
    # Basic match analysis
    print("\nMatches per tournament:")
    print(matches_df['tournament_name'].value_counts())
    
    print("\nSample of matches:")
    print(matches_df.head())
except Exception as e:
    logging.error(f"Error collecting match data: {str(e)}")
    raise
# Out:
# 2024-11-05 22:09:44,866 - INFO - Collecting match data...
# 2024-11-05 22:09:44,876 - ERROR - Error collecting match data: Variable '$startDate' of type 'DateTime!' used in position expecting type 'String'.
#
# GraphQL request:1:54
# 1 | query GetRecentMatches($first: Int!, $after: Cursor, $startDate: DateTime!, $endDate: DateTime!) {
#   |                                                      ^
# 2 |     allSeries(
#
# GraphQL request:7:22
# 6 |             startTimeScheduled: {
# 7 |                 gte: $startDate
#   |                      ^
# 8 |                 lte: $endDate
# Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\matches.graphql
# File exists: True
# ---------------------------------------------------------------------------
# GraphQLError                              Traceback (most recent call last)
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:79, in GridCollector.get_matches(self, days)
#      78 self.rate_limiter.wait()
# ---> 79 result = self.central_client.execute(
#      80     gql(query),
#      81     variable_values={
#      82         'startDate': start_date,
#      83         'endDate': end_date,
#      84         'first': 50
#      85     }
#      86 )
#      88 matches = []
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:484, in Client.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     483 else:  # Sync transports
# --> 484     return self.execute_sync(
#     485         document,
#     486         variable_values=variable_values,
#     487         operation_name=operation_name,
#     488         serialize_variables=serialize_variables,
#     489         parse_result=parse_result,
#     490         get_execution_result=get_execution_result,
#     491         **kwargs,
#     492     )
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:248, in Client.execute_sync(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     247 with self as session:
# --> 248     return session.execute(
#     249         document,
#     250         variable_values=variable_values,
#     251         operation_name=operation_name,
#     252         serialize_variables=serialize_variables,
#     253         parse_result=parse_result,
#     254         get_execution_result=get_execution_result,
#     255         **kwargs,
#     256     )
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:1017, in SyncClientSession.execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#    1016 # Validate and execute on the transport
# -> 1017 result = self._execute(
#    1018     document,
#    1019     variable_values=variable_values,
#    1020     operation_name=operation_name,
#    1021     serialize_variables=serialize_variables,
#    1022     parse_result=parse_result,
#    1023     **kwargs,
#    1024 )
#    1026 # Raise an error if an error is returned in the ExecutionResult object
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:902, in SyncClientSession._execute(self, document, variable_values, operation_name, serialize_variables, parse_result, **kwargs)
#     901 if self.client.schema:
# --> 902     self.client.validate(document)
#     904     # Parse variable values for custom scalars if requested
#
# File c:\Users\Chaos\anaconda3\envs\dev\lib\site-packages\gql\client.py:175, in Client.validate(self, document)
#     174 if validation_errors:
# --> 175     raise validation_errors[0]
#
# GraphQLError: Variable '$startDate' of type 'DateTime!' used in position expecting type 'String'.
#
# GraphQL request:1:54
# 1 | query GetRecentMatches($first: Int!, $after: Cursor, $startDate: DateTime!, $endDate: DateTime!) {
#   |                                                      ^
# 2 |     allSeries(
#
# GraphQL request:7:22
# 6 |             startTimeScheduled: {
# 7 |                 gte: $startDate
#   |                      ^
# 8 |                 lte: $endDate
#
# During handling of the above exception, another exception occurred:
#
# GridAPIError                              Traceback (most recent call last)
# Cell In[5], line 4
#       2 try:
#       3     logging.info("Collecting match data...")
# ----> 4     matches_df = collector.get_matches(days=7)
#       5     logging.info(f"Collected {len(matches_df)} matches")
#       7     # Basic match analysis
#
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:107, in GridCollector.get_matches(self, days)
#     104     return pd.DataFrame([vars(m) for m in matches])
#     106 except Exception as e:
# --> 107     raise handle_api_error(e)
#
# GridAPIError: Variable '$startDate' of type 'DateTime!' used in position expecting type 'String'.
#
# GraphQL request:1:54
# 1 | query GetRecentMatches($first: Int!, $after: Cursor, $startDate: DateTime!, $endDate: DateTime!) {
#   |                                                      ^
# 2 |     allSeries(
#
# GraphQL request:7:22
# 6 |             startTimeScheduled: {
# 7 |                 gte: $startDate
#   |                      ^
# 8 |                 lte: $endDate

# %%
# Collect Team Data
try:
    logging.info("Collecting team data...")
    teams_df = collector.get_teams()
    logging.info(f"Collected {len(teams_df)} teams")
    
    # Get unique teams from matches
    match_team_ids = pd.concat([
        matches_df['team1_id'],
        matches_df['team2_id']
    ]).unique()
    
    print(f"\nTotal teams: {len(teams_df)}")
    print(f"Teams in recent matches: {len(match_team_ids)}")
except Exception as e:
    logging.error(f"Error collecting team data: {str(e)}")
    raise
# Out:
# 2024-11-05 22:09:49,571 - INFO - Collecting team data...
# 2024-11-05 22:09:49,577 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": null, "first": 50}}
# Looking for query file at: c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\queries\teams.graphql
# File exists: True
# 2024-11-05 22:09:50,330 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"1","name":"Sprout","nameShortened":"","colorPrimary":"#34bc6e","colorSecondary":"#726180","logoUrl":"https://cdn.grid.gg/assets/team-logos/4a99a16c029eba9db3169ec2b83e284e","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0YLC1oLCw=="},{"node":{"id":"2","name":"Red Reserve","colorPrimary":"#da1e28","colorSecondary":"#cc666b","logoUrl":"https://cdn.grid.gg/assets/team-logos/0304b33ec0316ea7b0fd50feff7bd7cb","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ULC1oLCw=="},{"node":{"id":"4","name":"Windigo","colorPrimary":"#7732bb","colorSecondary":"#5e6868","logoUrl":"https://cdn.grid.gg/assets/team-logos/f07247147aeced1c8148fd2066e8280d","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0MLC1oLCw=="},{"node":{"id":"6","name":"x6tence","colorPrimary":"#c22dd5","colorSecondary":"#473793","logoUrl":"https://cdn.grid.gg/assets/team-logos/b17e066388a7a20e2b6468f443e3e3d3","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ELC1oLCw=="},{"node":{"id":"7","name":"AGO","colorPrimary":"#dc267f","colorSecondary":"#726180","logoUrl":"https://cdn.grid.gg/assets/team-logos/82913104ea8c389fb963c7a8f1334e04","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ALC1oLCw=="},{"node":{"id":"8","name":"HAVU","colorPrimary":"#81b532","colorSecondary":"#726180","logoUrl":"https://cdn.grid.gg/assets/team-logos/187ae38297a7ae519f65855b361aadd9","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC08LC1oLCw=="},{"node":{"id":"9","name":"Tricked","colorPrimary":"#FFB000","colorSecondary":"#CB71D7","logoUrl":"https://cdn.grid.gg/assets/team-logos/8db24a06c111c59535309b06697d1775","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC04LC1oLCw=="},{"node":{"id":"10","name":"LDLC","colorPrimary":"#00539a","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/a29ece218de87ed86de3195086a5c3e5","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZHCwtaCws="},{"node":{"id":"11","name":"expert","colorPrimary":"#ff7548","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/78a3ceff8008991c82c95610871257b6","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZGCwtaCws="},{"node":{"id":"12","name":"Vexed","colorPrimary":"#a2191f","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/97fabfaefb2359b20ed1356e5d73f4da","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZFCwtaCws="},{"node":{"id":"14","name":"EURONICS Gaming","colorPrimary":"#fbc817","colorSecondary":"#0072c3","logoUrl":"https://cdn.grid.gg/assets/team-logos/1ff3e1514f001f370a821b074a280636","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZDCwtaCws="},{"node":{"id":"15","name":"Forward Gaming","colorPrimary":"#00b6cb","colorSecondary":"#dc267f","logoUrl":"https://cdn.grid.gg/assets/team-logos/b62a457863d805021c798e92fef83043","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZCCwtaCws="},{"node":{"id":"16","name":"J.Storm","colorPrimary":"#9b82f3","colorSecondary":"#831b4c","logoUrl":"https://cdn.grid.gg/assets/team-logos/ae2b4e2fb08ab17250b1c1a3b6e25443","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZBCwtaCws="},{"node":{"id":"17","name":"Team Xolotl","colorPrimary":"#726180","colorSecondary":"#750e13","logoUrl":"https://cdn.grid.gg/assets/team-logos/b1d0701db26594be8177e2d2374c7af4","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZACwtaCws="},{"node":{"id":"18","name":"gg and gg","colorPrimary":"#fe8500","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/a149d3ccd3d48ea6879425725f406084","title":{"id":"2","name":"Defense of the Ancie ...
# 2024-11-05 22:09:52,588 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0JOCwtaCws=", "first": 50}}
# 2024-11-05 22:09:53,271 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"60","name":"No Creativity","colorPrimary":"#da1e28","colorSecondary":"#5a3ec8","logoUrl":"https://cdn.grid.gg/assets/team-logos/48d96c2392d740d6220cad170280499f","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FHCwtaCws="},{"node":{"id":"61","name":"PAVAGA JUNIOR","colorPrimary":"#da1e28","colorSecondary":"#81b532","logoUrl":"https://cdn.grid.gg/assets/team-logos/5bbe911548c15678fd3e16552d02b787","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FGCwtaCws="},{"node":{"id":"62","name":"Black Hornets Gaming","colorPrimary":"#00884b","colorSecondary":"#00884b","logoUrl":"https://cdn.grid.gg/assets/team-logos/0986b35c9c4039f03ac5f1bd1d7714c5","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FFCwtaCws="},{"node":{"id":"63","name":"Winstrike Team","colorPrimary":"#d33c87","colorSecondary":"#00539a","logoUrl":"https://cdn.grid.gg/assets/team-logos/84077df225b1ea1d0f9c95e2e29cd5b8","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FECwtaCws="},{"node":{"id":"64","name":"ex-3DMAX","colorPrimary":"#da1e28","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/3b9d3671cfafc0ede7cf26ad952393db","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FDCwtaCws="},{"node":{"id":"65","name":"Team Ancient","colorPrimary":"#da1e28","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/26d06645ff3049e0b839e0db567c6876","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FCCwtaCws="},{"node":{"id":"67","name":"ex-Fragsters","colorPrimary":"#00aa5e","colorSecondary":"#71cddd","logoUrl":"https://cdn.grid.gg/assets/team-logos/dbc223bb8b30695913a9f2dde883d81e","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FACwtaCws="},{"node":{"id":"70","name":"NoChance","colorPrimary":"#726180","colorSecondary":"#831b4c","logoUrl":"https://cdn.grid.gg/assets/team-logos/01286e00c8dc272ab7a0b84abac95891","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0BHCwtaCws="},{"node":{"id":"71","name":"OFFSET Esports","colorPrimary":"#726180","colorSecondary":"#0072c3","logoUrl":"https://cdn.grid.gg/assets/team-logos/fd96d3f2c16c5e450ebe204e04357e94","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0BGCwtaCws="},{"node":{"id":"73","name":"pro100","colorPrimary":"#7732bb","colorSecondary":"#750e13","logoUrl":"https://cdn.grid.gg/assets/team-logos/d882a9423e62862f624123d6fa0b06e6","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0BECwtaCws="},{"node":{"id":"74","name":"AKOPALIPSA","colorPrimary":"#473793","colorSecondary":"#750e13","logoUrl":"https://cdn.grid.gg/assets/team-logos/9c83dc6f8b3383bd3be7e6d174c6a4dc","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0BDCwtaCws="},{"node":{"id":"75","name":"Team Endpoint","colorPrimary":"#05bf6f","colorSecondary":"#3c6df0","logoUrl":"https://cdn.grid.gg/assets/team-logos/3483b9e48f70690786e2e00129cdaede","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0BCCwtaCws="},{"node":{"id":"76","name":"Team Unique","colorPrimary":"#00539a","colorSecondary":"#726180","logoUrl":"https://cdn.grid.gg/assets/team-logos/87c237dd26bb2fc22a64c0072655b13b","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0BBCwtaCws="},{"node":{"id":"77","name":"Syman Gaming","colorPrimary":"#00539a","colorSecondary":"#a2191f","logoUrl":"https://cdn.grid.gg/assets/team-logos/247135bc3295eb8d284d5c3cc498559b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0BACwtaCws="},{"node":{"id":"78","name":"Astralis","colorPrimary":"#fa4d56","colorSecondary":"#95d13c","logoUrl":"https://cdn.grid.gg/assets/team-logos/2e7204b9f0c86ce0ee42c781d93b32f5","title":{"id": ...
# 2024-11-05 22:09:55,603 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0ZERwsLWgsL", "first": 50}}
# 2024-11-05 22:09:56,303 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"131","name":"Team Adroit","colorPrimary":"#12a3b4","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/c5efb5f2b51af5e305a3ed02941935b5","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZERgsLWgsL"},{"node":{"id":"132","name":"Aachen City Esports","colorPrimary":"#fbc817","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/5020b84409e09b2f7eabc2bb2357e508","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZERQsLWgsL"},{"node":{"id":"133","name":"Wind and Rain","colorPrimary":"#fe6100","colorSecondary":"#00884b","logoUrl":"https://cdn.grid.gg/assets/team-logos/e8867628361991fdb080817b6182445e","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZERAsLWgsL"},{"node":{"id":"134","name":"Hippomaniacs","colorPrimary":"#e39d14","colorSecondary":"#33b1ff","logoUrl":"https://cdn.grid.gg/assets/team-logos/ab97f5b269dcea5d52abeb30d4ca64da","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZEQwsLWgsL"},{"node":{"id":"135","name":"EgoBoys","colorPrimary":"#fbc817","colorSecondary":"#a2191f","logoUrl":"https://cdn.grid.gg/assets/team-logos/b65a98e74374860a72fd8b8610c41e19","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZEQgsLWgsL"},{"node":{"id":"138","name":"Team Anvorgesa","colorPrimary":"#e39d14","colorSecondary":"#fbc817","logoUrl":"https://cdn.grid.gg/assets/team-logos/c2f8fc471b2bcca9a2447641558837ed","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZETwsLWgsL"},{"node":{"id":"139","name":"Sirius","colorPrimary":"#0072c3","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/d007bcb6964a3203499d9e46da0dad2f","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZETgsLWgsL"},{"node":{"id":"141","name":"HellRaisers","colorPrimary":"#da1e28","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/194cac8dd80ca9d5e03e19a6961531bb","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZDRgsLWgsL"},{"node":{"id":"142","name":"Aristocracy","colorPrimary":"#da1e28","colorSecondary":"#fbc817","logoUrl":"https://cdn.grid.gg/assets/team-logos/a12e88acae4bc037d80240830948598e","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZDRQsLWgsL"},{"node":{"id":"145","name":"HellRaisers Esports","colorPrimary":"#da1e28","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/49bb3c3dd85cf64ba4c10029f9c20bc8","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZDQgsLWgsL"},{"node":{"id":"147","name":"TeamOne","colorPrimary":"#9fa7a7","colorSecondary":"#93791b","logoUrl":"https://cdn.grid.gg/assets/team-logos/ef5699c0d4446a17e87a23a38122e482","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZDQAsLWgsL"},{"node":{"id":"148","name":"Singularity","colorPrimary":"#726180","colorSecondary":"#00884b","logoUrl":"https://cdn.grid.gg/assets/team-logos/6d9c88fc3d474ae8fa0d05ba0a4661e6","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZDTwsLWgsL"},{"node":{"id":"150","name":"CR4ZY","colorPrimary":"#da1e28","colorSecondary":"#71cddd","logoUrl":"https://cdn.grid.gg/assets/team-logos/16b0f88ee243de34c21aefbd97f4fb65","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZCRwsLWgsL"},{"node":{"id":"154","name":"Unique","colorPrimary":"#00539a","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/33b00498eb985dff50b09142a46a8e09","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0ZCQwsLWgsL"},{"node":{"id":"155","name":"Aster","colorPrimary":"#00539a","colorSecondary":"#726180","logoUrl":"https://cdn.grid.gg/assets/team-logos/8dfd1832a8fbc3ad89ec147e7aa02351","title":{"id":"2","name":"Defense of the Anc ...
# 2024-11-05 22:09:58,609 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0ZOQgsLWgsL", "first": 50}}
# 2024-11-05 22:09:59,310 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"196","name":"Future Perfect","colorPrimary":"#ff7548","colorSecondary":"#fbc817","logoUrl":"https://cdn.grid.gg/assets/team-logos/47f92d449f065431d9b5af679d8d2ba0","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZOQQsLWgsL"},{"node":{"id":"197","name":"Ha MaSSe","colorPrimary":"#3151b7","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/053867c0c75d29c2cae316b3315fc46b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZOQAsLWgsL"},{"node":{"id":"198","name":"NorBant","colorPrimary":"#fe8500","colorSecondary":"#602797","logoUrl":"https://cdn.grid.gg/assets/team-logos/6effa1cc80ba0e1c0b790f13d58183d8","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZOTwsLWgsL"},{"node":{"id":"199","name":"Adwokacik","colorPrimary":"#b69419","colorSecondary":"#7732bb","logoUrl":"https://cdn.grid.gg/assets/team-logos/8800362661c6f82195d1cfa297f9aa93","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0ZOTgsLWgsL"},{"node":{"id":"200","name":"Ad Hoc","colorPrimary":"#da1e28","colorSecondary":"#00aa5e","logoUrl":"https://cdn.grid.gg/assets/team-logos/6c80152ba5657d979377185fb2d61b65","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VHRwsLWgsL"},{"node":{"id":"202","name":"Buaksib","colorPrimary":"#726180","colorSecondary":"#3c6df0","logoUrl":"https://cdn.grid.gg/assets/team-logos/950f27849905937efe4035a4352590da","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VHRQsLWgsL"},{"node":{"id":"205","name":"Empire","colorPrimary":"#9fa7a7","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/0fa9eca48b72adcff0e757994f10e2e7","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VHQgsLWgsL"},{"node":{"id":"207","name":"Namega","colorPrimary":"#726180","colorSecondary":"#cb71d7","logoUrl":"https://cdn.grid.gg/assets/team-logos/969dcd2f696e605bab931c84ca770ea1","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VHQAsLWgsL"},{"node":{"id":"208","name":"Fierce","colorPrimary":"#fe8500","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/4454bf0434e57e59cce2f93efcacd063","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VHTwsLWgsL"},{"node":{"id":"209","name":"paryvodnikov","colorPrimary":"#726180","colorSecondary":"#93791b","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VHTgsLWgsL"},{"node":{"id":"210","name":"Dracarys","colorPrimary":"#da1e28","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/20fa422f61603d0fd7d49a2febbbdd01","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VGRwsLWgsL"},{"node":{"id":"211","name":"Espada","colorPrimary":"#0072c3","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/a6b4d21ec3ecbf06128eb8070bab05fb","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VGRgsLWgsL"},{"node":{"id":"212","name":"potatosquad","colorPrimary":"#9c6d1e","colorSecondary":"#5b8121","logoUrl":"https://cdn.grid.gg/assets/team-logos/90bb4459a926b55839386c11a6799fb2","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VGRQsLWgsL"},{"node":{"id":"213","name":"GoldenGitte","colorPrimary":"#fbc817","colorSecondary":"#814b19","logoUrl":"https://cdn.grid.gg/assets/team-logos/9dabcb9f0ea8c77d65f55806895cab3f","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VGRAsLWgsL"},{"node":{"id":"214","name":"One More Time","colorPrimary":"#da1e28","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive ...
# 2024-11-05 22:10:01,617 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0VDTgsLWgsL", "first": 50}}
# 2024-11-05 22:10:02,271 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"251","name":"PRIES Gaming","colorPrimary":"#d8ae18","colorSecondary":"#750e13","logoUrl":"https://cdn.grid.gg/assets/team-logos/8e323958c466fd7e3781456f20b53096","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCRgsLWgsL"},{"node":{"id":"252","name":"Positive Guys","colorPrimary":"#95d13c","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/b04aca3f65e5593e428c758ac6808e99","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCRQsLWgsL"},{"node":{"id":"253","name":"REDCODE","colorPrimary":"#da1e28","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/32aa5e614d82b1ca646e8df13bf32f2b","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCRAsLWgsL"},{"node":{"id":"254","name":"UNITED","colorPrimary":"#fbc817","colorSecondary":"#814b19","logoUrl":"https://cdn.grid.gg/assets/team-logos/28ac587b4de2a4208ab977100d775e49","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCQwsLWgsL"},{"node":{"id":"255","name":"Cyber Dogs","colorPrimary":"#da1e28","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/7b57df6167cf77b0dab83b19fb430e91","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCQgsLWgsL"},{"node":{"id":"257","name":"Burning Fire","colorPrimary":"#da1e28","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/24025a02e02fd7e0e3b7c5f804cb295a","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCQAsLWgsL"},{"node":{"id":"258","name":"Fried Pudges","colorPrimary":"#dc267f","colorSecondary":"#00b6cb","logoUrl":"https://cdn.grid.gg/assets/team-logos/d3190684ea675a3b7212271f88bcc78f","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCTwsLWgsL"},{"node":{"id":"259","name":"Beastcoast","colorPrimary":"#00b6cb","colorSecondary":"#1192e8","logoUrl":"https://cdn.grid.gg/assets/team-logos/cb7fc44c8198ef3370967113e6ca817e","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VCTgsLWgsL"},{"node":{"id":"260","name":"Sadim","colorPrimary":"#95d13c","colorSecondary":"#3151b7","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VBRwsLWgsL"},{"node":{"id":"261","name":"BC","colorPrimary":"#3c6df0","colorSecondary":"#71cddd","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VBRgsLWgsL"},{"node":{"id":"262","name":"Pepegas","colorPrimary":"#71237c","colorSecondary":"#750e13","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VBRQsLWgsL"},{"node":{"id":"263","name":"SKADE","colorPrimary":"#71cddd","colorSecondary":"#726180","logoUrl":"https://cdn.grid.gg/assets/team-logos/25a2eaed8f9bc5f0c693b8f26ace7020","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VBRAsLWgsL"},{"node":{"id":"267","name":"ex-Epsilon","colorPrimary":"#00539a","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/3a6711ffc472bc8a4e368aaa1da13cd7","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VBQAsLWgsL"},{"node":{"id":"268","name":"TENSAR","colorPrimary":"#00aa5e","colorSecondary":"#57d785","logoUrl":"https://cdn.grid.gg/assets/team-logos/3ffeafdf8f17546f9d82f73b23f2a1a9","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0VBTwsLWgsL"},{"node":{"id":"270","name":"Invictus Gaming","colorPrimary":"#726180","colorSecondary":"#0947d7","logoUrl":"https://cdn.grid.gg/assets/team-logos/ee76de259dd63ba2c512e2471bde7f7e","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0VARwsLWgsL"},{"node":{"id":"271","name":"Look for Smile","colorPrimary":"#72 ...
# 2024-11-05 22:10:04,626 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0RHTgsLWgsL", "first": 50}}
# 2024-11-05 22:10:05,278 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"310","name":"Fighting PandaS","colorPrimary":"#cb71d7","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/9d1ff5ab3ff44c5082fb38e2d2a4c794","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGRwsLWgsL"},{"node":{"id":"311","name":"Revive","colorPrimary":"#fbc817","colorSecondary":"#b69419","logoUrl":"https://cdn.grid.gg/assets/team-logos/270fed899c5e902e487a4be58816261c","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGRgsLWgsL"},{"node":{"id":"312","name":"FTD.A","colorPrimary":"#da1e28","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/cf286b59d8ec4093981f361f47acb1ca","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGRQsLWgsL"},{"node":{"id":"313","name":"FTD.B","colorPrimary":"#da1e28","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/595eded940d8b2534d7de7325bbd2add","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGRAsLWgsL"},{"node":{"id":"314","name":"Hero","colorPrimary":"#726180","colorSecondary":"#9753e1","logoUrl":"https://cdn.grid.gg/assets/team-logos/39e1055129012cce3f6bc8c71415b64d","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGQwsLWgsL"},{"node":{"id":"316","name":"Revenge Gaming","colorPrimary":"#da1e28","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/2e8cec49714e546f3e9d8f86fb3047fa","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGQQsLWgsL"},{"node":{"id":"317","name":"Wolf","colorPrimary":"#95d13c","colorSecondary":"#a2191f","logoUrl":"https://cdn.grid.gg/assets/team-logos/c9988c9f6e53bf565af6ac13c87529e7","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGQAsLWgsL"},{"node":{"id":"318","name":"Voyager","colorPrimary":"#da1e28","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/14460b849e166e97fbbc87d82cdec7d5","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RGTwsLWgsL"},{"node":{"id":"319","name":"Hard Legion","colorPrimary":"#ff7548","colorSecondary":"#ff7548","logoUrl":"https://cdn.grid.gg/assets/team-logos/a78608832d48c22af09a6f48e1435b2f","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0RGTgsLWgsL"},{"node":{"id":"320","name":"Gentlemen","colorPrimary":"#ff7548","colorSecondary":"#c64b00","logoUrl":"https://cdn.grid.gg/assets/team-logos/f113f5e966af834ef1889b18e0f30bd2","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0RFRwsLWgsL"},{"node":{"id":"321","name":"Syntax","colorPrimary":"#da1e28","colorSecondary":"#3c6df0","logoUrl":"https://cdn.grid.gg/assets/team-logos/27d5e6b969db98afa5de91b965f5b17a","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0RFRgsLWgsL"},{"node":{"id":"322","name":"AHQ","colorPrimary":"#ea1f29","colorSecondary":"#5e6868","logoUrl":"https://cdn.grid.gg/assets/team-logos/f3dc0e9c236529ee68c75fa253337230","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0RFRQsLWgsL"},{"node":{"id":"323","name":"Ikarus","colorPrimary":"#da1e28","colorSecondary":"#fbc817","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0RFRAsLWgsL"},{"node":{"id":"324","name":"NASR","colorPrimary":"#ff509e","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/d2acdc66046c23182cd59b2d9767784b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0RFQwsLWgsL"},{"node":{"id":"325","name":"LAZE","colorPrimary":"#726180","colorSecondary":"#95d13c","logoUrl":"https://cdn.grid.gg/assets/team-logos/e39fb05ebcfd147e4d9b545dd33b664a","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0RFQgsLWgsL"},{"node":{"id":"326"," ...
# 2024-11-05 22:10:07,632 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0NFRwsLWgsL", "first": 50}}
# 2024-11-05 22:10:08,334 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"422","name":"Flamengo eSports","colorPrimary":"#f3202b","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/6764a472629393045eac0881c560995b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NFRQsLWgsL"},{"node":{"id":"424","name":"Royal Youth","colorPrimary":"#fbc817","colorSecondary":"#db7c00","logoUrl":"https://cdn.grid.gg/assets/team-logos/216d07767f9f5ba9f98afb7ccd835982","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NFQwsLWgsL"},{"node":{"id":"425","name":"Lowkey Esports","colorPrimary":"#da1e28","colorSecondary":"#3151b7","logoUrl":"https://cdn.grid.gg/assets/team-logos/936b10e5f35b3f0d445cbcc687137819","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0NFQgsLWgsL"},{"node":{"id":"426","name":"Isurus Gaming","colorPrimary":"#0072c3","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/ec516e83a1a12dc0da6ce04cf4e2c1aa","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NFQQsLWgsL"},{"node":{"id":"428","name":"V3 Esports","colorPrimary":"#00884b","colorSecondary":"#00aa5e","logoUrl":"https://cdn.grid.gg/assets/team-logos/cc3ac4a53683ba43bcdf45d95874c90a","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NFTwsLWgsL"},{"node":{"id":"433","name":"Unsold Stuff Gaming","colorPrimary":"#dc267f","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/2473e9a28b3809b42ab7de94811c4de7","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NERAsLWgsL"},{"node":{"id":"434","name":"Dire Wolves","colorPrimary":"#00884b","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/45d630b357b5e25fae4da5b875ab6e13","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NEQwsLWgsL"},{"node":{"id":"435","name":"Chiefs","colorPrimary":"#1192e8","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/cc63355e08d0f48e40ebfb354da2e49d","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NEQgsLWgsL"},{"node":{"id":"436","name":"Axis Empire","colorPrimary":"#7732bb","colorSecondary":"#c22dd5","logoUrl":"https://cdn.grid.gg/assets/team-logos/537ee7b4ae904b260efc0a2032df6eff","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NEQQsLWgsL"},{"node":{"id":"437","name":"Liyab Esports","colorPrimary":"#0072c3","colorSecondary":"#71cddd","logoUrl":"https://cdn.grid.gg/assets/team-logos/57cd491e3296157c3325f3404482647b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NEQAsLWgsL"},{"node":{"id":"438","name":"WIN Esports","colorPrimary":"#726180","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/2de3d696c7c848d85c48b7b1abdadae5","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NETwsLWgsL"},{"node":{"id":"439","name":"Team Flash","colorPrimary":"#fe8500","colorSecondary":"#fe6100","logoUrl":"https://cdn.grid.gg/assets/team-logos/d07982863788d8527ee521bd182b225e","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NETgsLWgsL"},{"node":{"id":"440","name":"Dashing Buffalo","colorPrimary":"#da1e28","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/02fa0206e463f54e997f0c181c655ea9","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NDRwsLWgsL"},{"node":{"id":"442","name":"FTV Esports","colorPrimary":"#726180","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/eeeeff9a5bc07216beb0f28944f39ad7","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NDRQsLWgsL"},{"node":{"id":"443","name":"QTV Gaming","colorPrimary":"#da1e28","colorSecondary":"#00884b","logoUrl":"https://cdn.grid.gg/assets/te ...
# 2024-11-05 22:10:10,634 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0NPRgsLWgsL", "first": 50}}
# 2024-11-05 22:10:11,324 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"482","name":"Finest","colorPrimary":"#726180","colorSecondary":"#0072c3","logoUrl":"https://cdn.grid.gg/assets/team-logos/451e35d5f4a93067935b66d46b282379","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NPRQsLWgsL"},{"node":{"id":"483","name":"Firemix","colorPrimary":"#73a22c","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NPRAsLWgsL"},{"node":{"id":"484","name":"Gaming Hub","colorPrimary":"#da1e28","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/0ba556e71c2c8bce0ead15d31ad0b36b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NPQwsLWgsL"},{"node":{"id":"485","name":"BL4ZE eSports","colorPrimary":"#e39d14","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/33c2eb6fdd5f03689c92419eb7d7062a","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NPQgsLWgsL"},{"node":{"id":"486","name":"og3od eSports","colorPrimary":"#da1e28","colorSecondary":"#00884b","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NPQQsLWgsL"},{"node":{"id":"487","name":"Team Jordan","colorPrimary":"#00884b","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/d7550d66b7a444f4caba6c2e49e0a536","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0NPQAsLWgsL"},{"node":{"id":"488","name":"AdMatay","colorPrimary":"#1192e8","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0NPTwsLWgsL"},{"node":{"id":"489","name":"ARCY","colorPrimary":"#726180","colorSecondary":"#fbc817","logoUrl":"https://cdn.grid.gg/assets/team-logos/35a5489d0bb481014a81d35c4b7069dd","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NPTgsLWgsL"},{"node":{"id":"490","name":"PRINCEADIL","colorPrimary":"#5a3ec8","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NORwsLWgsL"},{"node":{"id":"491","name":"The Dice","colorPrimary":"#3151b7","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/352580bc8595e2bb081218c56614d533","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NORgsLWgsL"},{"node":{"id":"492","name":"Defusekids","colorPrimary":"#3151b7","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/1a6791ff31b9d0b50892c21025eb9de3","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NORQsLWgsL"},{"node":{"id":"493","name":"Owned","colorPrimary":"#3c6df0","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NORAsLWgsL"},{"node":{"id":"494","name":"Team Brute","colorPrimary":"#ff7548","colorSecondary":"#8c9696","logoUrl":"https://cdn.grid.gg/assets/team-logos/6c7bf2fd5b6747e50de46b33fcb99f83","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0NOQwsLWgsL"},{"node":{"id":"496","name":"Meraki Gaming","colorPrimary":"#ec222d","colorSecondary":"#fa4d56","logoUrl":"https://cdn.grid.gg/assets/team-logos/0b2c2f348b2105f97f536ea5239907f7","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0NOQQsLWgsL"},{"node":{"id":"497","name":"Whoops","colorPrimary":"#00aa5e","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/a6bb56e2d6d99f7b6deb7056b77f8231","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0NOQAsLWgsL"},{"node":{"id":"498","name":"Linger","colorPrimary":"#fbc ...
# 2024-11-05 22:10:13,639 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0JEQQsLWgsL", "first": 50}}
# 2024-11-05 22:10:14,325 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"537","name":"Modus Unity","colorPrimary":"#00539a","colorSecondary":"#33b1ff","logoUrl":"https://cdn.grid.gg/assets/team-logos/8dde2d43ca59ae8d157b6f7be54ee9a2","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JEQAsLWgsL"},{"node":{"id":"538","name":"MITH","colorPrimary":"#fbc817","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/eb4462f8cf645da36b5a8be1b55185c0","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JETwsLWgsL"},{"node":{"id":"539","name":"Project X","colorPrimary":"#fbc817","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/4abe708acd308db5e2f7fddc38e3298b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JETgsLWgsL"},{"node":{"id":"541","name":"RADNICKI","colorPrimary":"#726180","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/61125510d8b4006fd3cbc966a4cb0194","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JDRgsLWgsL"},{"node":{"id":"542","name":"SG.pro","colorPrimary":"#726180","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/9843f7edf2b12ab18f62b7a37f10e930","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JDRQsLWgsL"},{"node":{"id":"543","name":"Titanz","colorPrimary":"#726180","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JDRAsLWgsL"},{"node":{"id":"544","name":"iSellPower","colorPrimary":"#726180","colorSecondary":"#dc267f","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JDQwsLWgsL"},{"node":{"id":"545","name":"Nigma Galaxy","colorPrimary":"#71237c","colorSecondary":"#0072c3","logoUrl":"https://cdn.grid.gg/assets/team-logos/ff75444079fa77753039a7952604aefe","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JDQgsLWgsL"},{"node":{"id":"547","name":"HZ","colorPrimary":"#fbc817","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/5391b49bd42dab036c603295b1ddf870","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JDQAsLWgsL"},{"node":{"id":"548","name":"Hard4U","colorPrimary":"#da1e28","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/9da0b043e1ffa1913e9fac987bfab1fb","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JDTwsLWgsL"},{"node":{"id":"549","name":"FPL-1","colorPrimary":"#6f7878","colorSecondary":"#e39d14","logoUrl":"https://cdn.grid.gg/assets/team-logos/2f9696cb9b7087c915273a2a794a33e3","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JDTgsLWgsL"},{"node":{"id":"550","name":"FPL-2","colorPrimary":"#e39d14","colorSecondary":"#6f7878","logoUrl":"https://cdn.grid.gg/assets/team-logos/879635ca6cdc552fc012cf6cfa636c7e","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JCRwsLWgsL"},{"node":{"id":"551","name":"Axis","colorPrimary":"#33b1ff","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/1b3a3919d40e1a8c136d2a6476ff4030","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JCRgsLWgsL"},{"node":{"id":"552","name":"Skin Ogres","colorPrimary":"#da1e28","colorSecondary":"#00aa5e","logoUrl":"https://cdn.grid.gg/assets/team-logos/c237a1ccb5e20737e1fac8a3c4572fa3","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0JCRQsLWgsL"},{"node":{"id":"553","name":"Team Moriarty","colorPrimary":"#5a3ec8","colorSecondary":"#95d13c","logoUrl":"https://cdn.grid.gg/assets/team-logos/45ee5733b43b83d42c007fec3c23aefc","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JCRAsLWgsL"},{"n ...
# 2024-11-05 22:10:16,644 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0FGRgsLWgsL", "first": 50}}
# 2024-11-05 22:10:17,347 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"612","name":"W7M Gaming","colorPrimary":"#726180","colorSecondary":"#dc267f","logoUrl":"https://cdn.grid.gg/assets/team-logos/972e33dfbd9339b14050ee3d50afed32","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FGRQsLWgsL"},{"node":{"id":"614","name":"Redemption POA","colorPrimary":"#00884b","colorSecondary":"#57d785","logoUrl":"https://cdn.grid.gg/assets/team-logos/f07ec3966055af771d67c9dc6872335f","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FGQwsLWgsL"},{"node":{"id":"615","name":"Rysix","colorPrimary":"#0072c3","colorSecondary":"#71cddd","logoUrl":"https://cdn.grid.gg/assets/team-logos/a6a037beea598811d23d774acdd6457b","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FGQgsLWgsL"},{"node":{"id":"616","name":"Team Scrawberry","colorPrimary":"#726180","colorSecondary":"#fa4d56","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FGQQsLWgsL"},{"node":{"id":"617","name":"The New Top","colorPrimary":"#473793","colorSecondary":"#ff7548","logoUrl":"https://cdn.grid.gg/assets/team-logos/e426ccb5d5b8c5654708fe797c9e78ff","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FGQAsLWgsL"},{"node":{"id":"618","name":"Dark Knight","colorPrimary":"#726180","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/995775588aee27c672aa970c40be9fb0","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FGTwsLWgsL"},{"node":{"id":"619","name":"Longinus","colorPrimary":"#008673","colorSecondary":"#da1e28","logoUrl":"https://cdn.grid.gg/assets/team-logos/36942f4e2882786827ee7a07b565b647","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FGTgsLWgsL"},{"node":{"id":"620","name":"Team IO","colorPrimary":"#1192e8","colorSecondary":"#71cddd","logoUrl":"https://cdn.grid.gg/assets/team-logos/354978b29154fbd1165afb1ecceebbac","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FFRwsLWgsL"},{"node":{"id":"621","name":"Zoomies","colorPrimary":"#da1e28","colorSecondary":"#7732bb","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FFRgsLWgsL"},{"node":{"id":"622","name":"NoPing Esports","colorPrimary":"#00884b","colorSecondary":"#00aa5e","logoUrl":"https://cdn.grid.gg/assets/team-logos/dbf9a77d1664918cd125514254308cd1","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FFRQsLWgsL"},{"node":{"id":"623","name":"Team Aspirations","colorPrimary":"#473793","colorSecondary":"#9320a2","logoUrl":"https://cdn.grid.gg/assets/team-logos/749700c4d913ca79519fc8ac5afb0f8f","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FFRAsLWgsL"},{"node":{"id":"624","name":"Team Meteor","colorPrimary":"#5a3ec8","colorSecondary":"#33b1ff","logoUrl":"https://cdn.grid.gg/assets/team-logos/3160e0f290f4d1671a13040894b9765a","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FFQwsLWgsL"},{"node":{"id":"625","name":"business associates","colorPrimary":"#3151b7","colorSecondary":"#3151b7","logoUrl":"https://cdn.grid.gg/assets/team-logos/419c644c61afe39f2ffe4d9829cab501","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0FFQgsLWgsL"},{"node":{"id":"626","name":"E-Gaming","colorPrimary":"#3151b7","colorSecondary":"#9fa7a7","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FFQQsLWgsL"},{"node":{"id":"627","name":"NLG","colorPrimary":"#726180","colorSecondary":"#3151b7","logoUrl":"https://cdn.grid.gg/assets/team-logos/38169c3545cf5407dea106174782e9d2","title":{"id":"1","name":"Counter Strike: Global Offensive"}},"cursor":"PjMLC1oLC0FFQAsLWgsL"},{"node":{"id":"628","n ...
# 2024-11-05 22:10:19,654 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0FATgsLWgsL", "first": 50}}
# ...
# 2024-11-05 22:17:11,728 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0JETkVGCwtaCws=", "first": 50}}
# 2024-11-05 22:17:12,417 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"53930","name":"CW","nameShortened":"CW","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkRHCwtaCws="},{"node":{"id":"53931","name":"ALLINERS","nameShortened":"ALLINERS","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkRGCwtaCws="},{"node":{"id":"53932","name":"Team Aether","nameShortened":"","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkRFCwtaCws="},{"node":{"id":"53933","name":"LFS","nameShortened":"LFS","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JETkRECwtaCws="},{"node":{"id":"53934","name":"AVULUS","nameShortened":"","colorPrimary":"#81B532","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/ec40839d172b4d065e2e85aa12fcc1cb","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JETkRDCwtaCws="},{"node":{"id":"53935","name":"ALLINNERS","nameShortened":"ALLINNERS","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkRCCwtaCws="},{"node":{"id":"53936","name":"DASH","nameShortened":"","colorPrimary":"#FBC817","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/587abe1aafccd1bbba7c9187460ee5d0","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkRBCwtaCws="},{"node":{"id":"53937","name":"Team Next Level","nameShortened":"Team Next Level","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkRACwtaCws="},{"node":{"id":"53938","name":"G2 Ares","nameShortened":"G2 Ares","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkRPCwtaCws="},{"node":{"id":"53939","name":"Favbet Team","nameShortened":"Favbet Team","colorPrimary":"#FF509E","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/bdb14db65422221c00107850f44cebb6","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkROCwtaCws="},{"node":{"id":"53946","name":"Energy Esports","nameShortened":"Energy Esports","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JETkNBCwtaCws="},{"node":{"id":"53947","name":"Pantheon","nameShortened":"Pantheon","colorPrimary":"#DA1E28","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/831f08f7c767b379c10d297bed750bf8","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JETkNACwtaCws="},{"node":{"id":"53950","name":"Ex-Sport","nameShortened":"Ex-Sport","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkJHCwtaCws="},{"node":{"id":"53951","name":"Nitro","nameShortened":"Nitro","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JETkJGCwtaCws="},{"node":{"id":"53955","name":"TNL","nameShortened":"TNL","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title ...
# 2024-11-05 22:17:14,740 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0JDR0RCCwtaCws=", "first": 50}}
# 2024-11-05 22:17:15,422 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"54036","name":"Team Stariy_Bog","nameShortened":"Team Stariy_Bog","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JDR0RBCwtaCws="},{"node":{"id":"54037","name":"Team Recrent","nameShortened":"Team Recrent","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JDR0RACwtaCws="},{"node":{"id":"54038","name":"Team RostikFaceKid","nameShortened":"Team RostikFaceKid","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JDR0RPCwtaCws="},{"node":{"id":"54039","name":"PCIFIC Esports","nameShortened":"PCIFIC Esports","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0ROCwtaCws="},{"node":{"id":"54040","name":"Spotless","nameShortened":"Spotless","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0NHCwtaCws="},{"node":{"id":"54041","name":"Team Storm","nameShortened":"Team Storm","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JDR0NGCwtaCws="},{"node":{"id":"54054","name":"CAPIVARAS","nameShortened":"CAPIVARAS","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0JDCwtaCws="},{"node":{"id":"54055","name":"TheKillaz","nameShortened":"TheKillaz","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0JCCwtaCws="},{"node":{"id":"54056","name":"PEAK FE","nameShortened":"PEAK FE","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0JBCwtaCws="},{"node":{"id":"54057","name":"Atrix","nameShortened":"Atrix","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0JACwtaCws="},{"node":{"id":"54058","name":"Into the Storm","nameShortened":"","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"2","name":"Defense of the Ancients 2"}},"cursor":"PjMLC1oLC0JDR0JPCwtaCws="},{"node":{"id":"54059","name":"inSanitY Female","nameShortened":"inSanitY Fe","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0JOCwtaCws="},{"node":{"id":"54062","name":"PeeP","nameShortened":"PeeP","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0FFCwtaCws="},{"node":{"id":"54063","name":"Molotov","nameShortened":"Molotov","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDR0FECwtaCws="},{"node":{"id":"54064","name":"Drillas","nameShortened":"Drillas","colorPrimary":"#3C6DF0","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/8a65252535e3cec535e0fdcf ...
# 2024-11-05 22:17:17,756 - INFO - >>> {"query": "query GetTeams($first: Int!, $after: Cursor) {\n  teams(first: $first, after: $after) {\n    edges {\n      node {\n        id\n        name\n        nameShortened\n        colorPrimary\n        colorSecondary\n        logoUrl\n        title {\n          id\n          name\n        }\n      }\n      cursor\n    }\n    pageInfo {\n      hasNextPage\n      endCursor\n    }\n  }\n}", "variables": {"after": "PjMLC1oLC0JDRkVFCwtaCws=", "first": 50}}
# 2024-11-05 22:17:18,415 - INFO - <<< {"data":{"teams":{"edges":[{"node":{"id":"54123","name":"Amped eSports","nameShortened":"","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkVECwtaCws="},{"node":{"id":"54124","name":"Slugy's Shekel Squad","nameShortened":"","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkVDCwtaCws="},{"node":{"id":"54125","name":"Leftovers","nameShortened":"LO","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkVCCwtaCws="},{"node":{"id":"54126","name":"Talaintanse","nameShortened":"TAL","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkVBCwtaCws="},{"node":{"id":"54127","name":"CarritoSpain","nameShortened":"CTS","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkVACwtaCws="},{"node":{"id":"54128","name":"SweetBonanzers","nameShortened":"SBZ","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkVPCwtaCws="},{"node":{"id":"54129","name":"Coxos","nameShortened":"CXS","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkVOCwtaCws="},{"node":{"id":"54130","name":"Fox Academy","nameShortened":"FXA","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkRHCwtaCws="},{"node":{"id":"54139","name":"kubixPulse","nameShortened":"KXP","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkROCwtaCws="},{"node":{"id":"54147","name":"ShindeN","nameShortened":"SHD","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkNACwtaCws="},{"node":{"id":"54148","name":"Game Hunters","nameShortened":"GH","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkNPCwtaCws="},{"node":{"id":"54149","name":"Tropa do Taco","nameShortened":"TDT","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkNOCwtaCws="},{"node":{"id":"54155","name":"Bestia Academy","nameShortened":"","colorPrimary":"#8C9696","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/f4bd9f6321ae3c817e6015fdbeffef7d","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkJCCwtaCws="},{"node":{"id":"54156","name":"America Esports","nameShortened":"America Esports","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkJBCwtaCws="},{"node":{"id":"54157","name":"Galorys Academy","nameShortened":"Galorys Academy","colorPrimary":"#5b6f7e","colorSecondary":"#ffffff","logoUrl":"https://cdn.grid.gg/assets/team-logos/generic","title":{"id":"28","name":"Counter Strike 2"}},"cursor":"PjMLC1oLC0JDRkJACwtaCws= ...
# 2024-11-05 22:17:18,419 - ERROR - Error collecting team data: 'node'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:188, in GridCollector.get_teams(self)
#     187 for edge in self._paginated_query(query, {}, self.central_client):
# --> 188     team = edge['node']
#     189     teams.append({
#     190         'id': team['id'],
#     191         'name': team['name'],
#    (...)
#     194         'logo_url': team['logoUrl']
#     195     })
#
# KeyError: 'node'
#
# During handling of the above exception, another exception occurred:
#
# GridAPIError                              Traceback (most recent call last)
# Cell In[6], line 4
#       2 try:
#       3     logging.info("Collecting team data...")
# ----> 4     teams_df = collector.get_teams()
#       5     logging.info(f"Collected {len(teams_df)} teams")
#       7     # Get unique teams from matches
#
# File c:\Users\Chaos\Desktop\Repo's\homework\VictorVis2.0\grid_collector\src\collector\grid_collector.py:199, in GridCollector.get_teams(self)
#     197     return pd.DataFrame(teams)
#     198 except Exception as e:
# --> 199     raise handle_api_error(e)
#
# GridAPIError: 'node'

# %%
# Collect Player Data
try:
    logging.info("Collecting player data for teams in recent matches...")
    all_players = []
    all_player_stats = []
    
    # Only get rosters for teams that have played recently
    for team_id in match_team_ids:
        try:
            # Get team roster
            roster_df = collector.get_team_roster(team_id)
            all_players.extend(roster_df.to_dict('records'))
            
            # Get stats for each player
            for player_id in roster_df['player_id']:
                try:
                    stats_df = collector.get_player_statistics(player_id)
                    if stats_df is not None:
                        stats_df['player_id'] = player_id
                        all_player_stats.append(stats_df)
                except Exception as e:
                    logging.warning(f"Error collecting stats for player {player_id}: {str(e)}")
                    continue
                    
        except Exception as e:
            logging.warning(f"Error collecting roster for team {team_id}: {str(e)}")
            continue
    
    # Convert to DataFrames
    players_df = pd.DataFrame(all_players)
    player_stats_df = pd.concat(all_player_stats, ignore_index=True) if all_player_stats else pd.DataFrame()
    
    logging.info(f"Collected data for {len(players_df)} players")
    logging.info(f"Collected statistics for {len(player_stats_df)} players")
    
    # Display sample data
    print("\nSample of players:")
    print(players_df.head())
    
    if not player_stats_df.empty:
        print("\nSample of player statistics:")
        print(player_stats_df.head())
except Exception as e:
    logging.error(f"Error in player data collection: {str(e)}")
    raise
# Out:
# 2024-11-05 21:57:28,899 - INFO - Collecting player data for teams in recent matches...
# 2024-11-05 21:57:28,900 - ERROR - Error in player data collection: name 'match_team_ids' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 all_player_stats = []
#       7 # Only get rosters for teams that have played recently
# ----> 8 for team_id in match_team_ids:
#       9     try:
#      10         # Get team roster
#      11         roster_df = collector.get_team_roster(team_id)
#
# NameError: name 'match_team_ids' is not defined

# %%
# Save All Data
try:
    # Create output directory
    output_dir = 'data'
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    output_dir = os.path.join(output_dir, timestamp)
    os.makedirs(output_dir, exist_ok=True)
    
    # Save all DataFrames
    tournaments_df.to_csv(f'{output_dir}/tournaments.csv', index=False)
    matches_df.to_csv(f'{output_dir}/matches.csv', index=False)
    teams_df.to_csv(f'{output_dir}/teams.csv', index=False)
    players_df.to_csv(f'{output_dir}/players.csv', index=False)
    if not player_stats_df.empty:
        player_stats_df.to_csv(f'{output_dir}/player_stats.csv', index=False)
    
    logging.info(f"All data saved successfully to {output_dir}")
    
    # Print summary
    print("\nData Collection Summary:")
    print(f"Tournaments: {len(tournaments_df)}")
    print(f"Matches: {len(matches_df)}")
    print(f"Teams: {len(teams_df)}")
    print(f"Players: {len(players_df)}")
    print(f"Player Statistics: {len(player_stats_df)}")
except Exception as e:
    logging.error(f"Error saving data: {str(e)}")
    raise
